# %%
import sys
sys.path.append("../src")

from utils.chembl_rescue import rescue_from_chembl, load_or_init_chembl_cache, save_chembl_cache
from utils.molecule_cleanup import classify_relationship, resolve_molecule_type
from utils.pubchem_utils import fetch_pubchem_cid_from_chembl, check_peptide_by_pubchem, process_id, load_or_init_pubchem_cache, save_pubchem_cache
from utils.cache import should_download, file_mtime

import chembl_downloader
import re
import pandas as pd
import time
import os
import subprocess
from datetime import datetime, timezone
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
from IPython.core.magic import register_cell_magic  # Needed for %%skip Jupyter cell magic

@register_cell_magic
def skip(line, cell):
    """A cell magic that skips execution of the cell body."""
    print("Skipped cell")

DATA_DIR = Path("../data")
DF_FILE = DATA_DIR / "df_chembl.csv"
PARQUET_FILE = DATA_DIR / "sql_chembl_cache.parquet"
META_FILE = DATA_DIR / ".cache_meta.json"
if should_download(DF_FILE, PARQUET_FILE, META_FILE):
    print("Downloading cache files hosted on Google Drive...")
    os.makedirs(DATA_DIR, exist_ok=True)
    result = subprocess.run(["bash", "../get_cache.sh"], capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print("Errors:", result.stderr)
else:
    print("Local cache is up to date.")
# Out:
# Local cache is up to date.

# %%
sql_chembl_cache_path = "../data/sql_chembl_cache.parquet"

sql_chembl = """
SELECT
    a.pchembl_value AS "pChEMBL",
    a.potential_duplicate AS "Duplicate? (1/0)",
    a.data_validity_comment AS "Data validity comment",
    ass.chembl_id AS "Assay ChEMBL ID",
    ass.confidence_score,
    dm.mechanism_of_action AS "MOA",
    dm.direct_interaction AS "Direct interaction (1/0)?",
    dm.disease_efficacy AS "Disease efficacy (1/0)?",
    md.chembl_id AS "Molecule ChEMBL ID",
    md.pref_name AS "Preferred name",
    md.molecule_type AS "Molecule type",
    md.max_phase AS "Max phase",
    md.availability_type AS "Availability (2/1/0/-1/-2)?",
    md.therapeutic_flag AS "Therapeutic (1/0)?",
    md.first_in_class AS "First-in-class (1/0/-1)?",
    md.chemical_probe AS "Chemical probe (1/0)?",
    md.orphan AS "Orphan (1/0/-1)?",
    cs.canonical_smiles AS "Canonical SMILES",
    cp.full_mwt AS "Molecular weight of full compound",
    cp.full_molformula AS "Molecular formula of full compound",
    md_parent.chembl_id AS "Parent compound ChEMBL ID",
    md_parent.molecule_type AS parent_molecule_type,
    md_active.chembl_id AS "Active ingredient ChEMBL ID",
    mh.molregno,
    mh.parent_molregno,
    mh.active_molregno,
    td.chembl_id AS "Target ChEMBL ID"
FROM activities a
LEFT JOIN assays ass ON a.assay_id = ass.assay_id
LEFT JOIN target_dictionary td ON ass.tid = td.tid
LEFT JOIN drug_mechanism dm ON a.molregno = dm.molregno
LEFT JOIN molecule_dictionary md ON a.molregno = md.molregno
LEFT JOIN compound_structures cs ON md.molregno = cs.molregno
LEFT JOIN compound_properties cp ON cs.molregno = cp.molregno
LEFT JOIN molecule_hierarchy mh ON md.molregno = mh.molregno
LEFT JOIN molecule_dictionary md_parent ON mh.parent_molregno = md_parent.molregno
LEFT JOIN molecule_dictionary md_active ON mh.active_molregno = md_active.molregno
WHERE a.pchembl_value IS NOT NULL
  AND td.target_type = 'SINGLE PROTEIN'
  AND td.organism = 'Homo sapiens';
"""
if os.path.exists(sql_chembl_cache_path):
    print("Loading cached ChEMBL data...")
    df_raw = pd.read_parquet(sql_chembl_cache_path)
    print("Data loaded.")
else:
    print("Running SQL query...")
    df_raw = chembl_downloader.query(sql_chembl)
    print("Query complete. Saving to cache...")
    df_raw.to_parquet(sql_chembl_cache_path, index=False)
    print("Save complete.")

for col in df_raw.columns:
    print('\nColumn:', df_raw[col].value_counts(dropna=False).head(10))  # Show top 10 frequent values
# Out:
# Loading cached ChEMBL data...
# Data loaded.
#
# Column: pChEMBL
# 4.40    62704
# 4.50    52019
# 4.60    51015
# 4.45    41123
# 4.90    40848
# 4.80    37562
# 5.00    37292
# 4.55    35516
# 4.70    30871
# 4.85    26617
# Name: count, dtype: int64
#
# Column: Duplicate? (1/0)
# 0    2005843
# 1      95016
# Name: count, dtype: int64
#
# Column: Data validity comment
# None                  2100539
# Manually validated        320
# Name: count, dtype: int64
#
# Column: Assay ChEMBL ID
# CHEMBL1614458    76019
# CHEMBL1614421    49886
# CHEMBL1613914    39824
# CHEMBL1614544    36448
# CHEMBL1613842    33737
# CHEMBL1614038    24248
# CHEMBL1614502    24121
# CHEMBL1614079    23084
# CHEMBL1613838    22000
# CHEMBL1614250    20674
# Name: count, dtype: int64
#
# Column: confidence_score
# 9    1623093
# 8     477766
# Name: count, dtype: int64
#
# Column: MOA
# None                                                     1961774
# Tyrosine-protein kinase receptor FLT3 inhibitor             7102
# Stem cell growth factor receptor inhibitor                  4698
# Tyrosine-protein kinase receptor RET inhibitor              3658
# Platelet-derived growth factor receptor inhibitor           3641
# Vascular endothelial growth factor receptor inhibitor       3599
# Carbonic anhydrase II inhibitor                             3245
# Carbonic anhydrase IV inhibitor                             3064
# Serotonin 2a (5-HT2a) receptor antagonist                   2876
# Carbonic anhydrase I inhibitor                              2794
# Name: count, dtype: int64
#
# Column: Direct interaction (1/0)?
# NaN    1961774
# 1.0     139085
# Name: count, dtype: int64
#
# Column: Disease efficacy (1/0)?
# NaN    1961774
# 1.0     139085
# Name: count, dtype: int64
#
# Column: Molecule ChEMBL ID
# CHEMBL535        11025
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3360
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2448
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: Preferred name
# None             1879423
# SUNITINIB          11025
# ACETAZOLAMIDE       8632
# VORINOSTAT          5840
# LESTAURTINIB        5088
# MIDOSTAURIN         3385
# VANDETANIB          3360
# DOVITINIB           2660
# FORETINIB           2592
# ALVOCIDIB           2448
# Name: count, dtype: int64
#
# Column: Molecule type
# Small molecule     1852733
# Unknown             155576
# None                 74645
# Protein              17860
# Oligosaccharide         40
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Max phase
#  NaN    1918899
#  4.0     111910
#  2.0      31593
#  3.0      24677
#  1.0      10744
# -1.0       2908
#  0.5        128
# Name: count, dtype: int64
#
# Column: Availability (2/1/0/-1/-2)?
# -1.0    1898877
#  NaN      97788
#  1.0      93271
#  0.0       4223
# -2.0       4090
#  2.0       2610
# Name: count, dtype: int64
#
# Column: Therapeutic (1/0)?
# 0    1990748
# 1     110111
# Name: count, dtype: int64
#
# Column: First-in-class (1/0/-1)?
# -1    1918899
#  0     172021
#  1       9939
# Name: count, dtype: int64
#
# Column: Chemical probe (1/0)?
# 0    2086672
# 1      14187
# Name: count, dtype: int64
#
# Column: Orphan (1/0/-1)?
# -1    1918899
#  0     174942
#  1       7018
# Name: count, dtype: int64
#
# Column: Canonical SMILES
# CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C                                        11025
# CC(=O)Nc1nnc(S(N)(=O)=O)s1                                                                      8632
# O=C(CCCCCCC(=O)Nc1ccccc1)NO                                                                     5840
# C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)CNC4=O                              5088
# CO[C@@H]1[C@H](N(C)C(=O)c2ccccc2)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4     3385
# COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1                                             3360
# CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1                                         2660
# None                                                                                            2628
# COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1                        2592
# CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@H](O)C1                                     2448
# Name: count, dtype: int64
#
# Column: Molecular weight of full compound
# 398.48    11369
# 222.25     8844
# 264.32     6053
# 439.47     5362
# 570.65     3444
# 475.36     3418
# 392.44     3092
# 466.54     2794
# 401.85     2692
# NaN        2628
# Name: count, dtype: int64
#
# Column: Molecular formula of full compound
# C22H27FN4O2      11140
# C4H6N4O3S2        8632
# C14H20N2O3        5912
# C26H21N3O4        5152
# C35H30N4O4        3387
# C22H24BrFN4O2     3379
# C21H21FN6O        2746
# None              2628
# C34H34F2N4O6      2592
# C21H20ClNO5       2543
# Name: count, dtype: int64
#
# Column: Parent compound ChEMBL ID
# CHEMBL535        11033
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3367
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2448
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: parent_molecule_type
# Small molecule     1854239
# Unknown             155036
# None                 73668
# Protein              17868
# Oligosaccharide         43
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Active ingredient ChEMBL ID
# CHEMBL535        11033
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3367
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2450
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: molregno
# 13048     11025
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3360
# 494834     2660
# 692959     2592
# 14366      2448
# 373381     2188
# Name: count, dtype: int64
#
# Column: parent_molregno
# 13048     11033
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3367
# 494834     2660
# 692959     2592
# 14366      2448
# 373381     2188
# Name: count, dtype: int64
#
# Column: active_molregno
# 13048     11033
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3367
# 494834     2660
# 692959     2592
# 14366      2450
# 373381     2188
# Name: count, dtype: int64
#
# Column: Target ChEMBL ID
# CHEMBL1293224    95232
# CHEMBL3577       76494
# CHEMBL1293226    40146
# CHEMBL1293235    36863
# CHEMBL2608       35167
# CHEMBL1293232    33837
# CHEMBL340        29020
# CHEMBL1963       28951
# CHEMBL4096       26274
# CHEMBL1293255    24701
# Name: count, dtype: int64

# %%
df_raw = df_raw[df_raw["Duplicate? (1/0)"] != 1].copy()  # Drop likely duplicates 
active_ingredients = set(df_raw.loc[df_raw["molregno"] != df_raw["active_molregno"], "active_molregno"])  # Flag prodrugs
df_raw["Active ingredient of prodrug?"] = df_raw["molregno"].apply(
    lambda x: "Yes" if x in active_ingredients else "No"
)
df_raw["Molecule type"] = df_raw.apply(resolve_molecule_type, axis=1)  # Resolve molecule type

# Identify molecules needing rescue
df_dropped = df_raw[df_raw["Molecule type"].isna()].copy()  
dropped_ids = df_dropped["Molecule ChEMBL ID"].dropna().unique().tolist()

# Load or initialise cache
cache_path = "../data/df_rescued_cache.csv"
rescue_cache, _ = load_or_init_chembl_cache(cache_path)

rescued_rows = []
unrecoverable_ids = []
for chembl_id in dropped_ids:
    if chembl_id in rescue_cache:
        row = rescue_cache[chembl_id]
        rescued = (chembl_id, row["Rescued Formula"], row["Rescued SMILES"], row["Rescued Name"], row["Rescued MW"])
        source = "CACHE"
    else:
        rescued = rescue_from_chembl(chembl_id)
        time.sleep(0.5)
        rescue_cache[chembl_id] = {
            "Molecule ChEMBL ID": chembl_id,
            "Rescued Formula": rescued[1],
            "Rescued SMILES": rescued[2],
            "Rescued Name": rescued[3],
            "Rescued MW": rescued[4]
        }
        source = "SCRAPED"
    if any(pd.notna(v) for v in rescued[1:]):
        print(f"[{source}] Rescued {chembl_id}: Formula={rescued[1]}, SMILES={rescued[2]}, Name={rescued[3]}, MW={rescued[4]}")
    else:
        unrecoverable_ids.append(chembl_id)
    rescued_rows.append(rescued)

# Save updated cache
save_chembl_cache(rescue_cache, cache_path)

# Merge rescued data into df_raw
rescue_cols = ["Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW"]
df_rescued = pd.DataFrame(rescued_rows, columns=[
    "Molecule ChEMBL ID", "Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW"
])
if not df_rescued.empty:
    # Remove existing rescue columns if they exist before merging again
    for col in rescue_cols:
        if col in df_raw.columns:
            df_raw.drop(columns=col, inplace=True)
    df_raw = df_raw.merge(df_rescued, on="Molecule ChEMBL ID", how="left")

# Ensure rescue columns exist before combine_first for idempotency
for col in rescue_cols:
    if col not in df_raw.columns:
        df_raw[col] = pd.NA

# Proceed with safe combine
df_raw["Molecular formula of full compound"] = df_raw["Molecular formula of full compound"].combine_first(df_raw["Rescued Formula"])
df_raw["Canonical SMILES"] = df_raw["Canonical SMILES"].combine_first(df_raw["Rescued SMILES"])
df_raw["Preferred name"] = df_raw["Preferred name"].combine_first(df_raw["Rescued Name"])
df_raw["Molecular weight of full compound"] = df_raw["Molecular weight of full compound"].combine_first(df_raw["Rescued MW"])

# Re-resolve molecule type after rescue
df_raw["Molecule type"] = df_raw.apply(resolve_molecule_type, axis=1)

# Final filtering
final_dropped_df = df_raw[df_raw["Molecule type"].isna()]
final_dropped_ids = final_dropped_df["Molecule ChEMBL ID"].dropna().unique()
pd.Series(final_dropped_ids).to_csv("../data/final_dropped_ids.csv", index=False)
print(
    f"Dropped {final_dropped_df.shape[0]} activity rows where Molecule type was None and unrecoverable.\n"
    f"This translates to {final_dropped_ids.shape[0]} unique molecules dropped."
)

# Clean final dataset and save into df_chembl
columns_to_drop = [
    "parent_molecule_type", "molregno", "parent_molregno", "active_molregno",
    "Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW", "Duplicate? (1/0)"
]
df_chembl = df_raw.drop(columns=columns_to_drop, errors="ignore")
for col in df_chembl.columns:
    print('\nColumn:', col)
    print(df_chembl[col].value_counts(dropna=False).head(10))
df_chembl.to_csv("../data/df_chembl.csv", index=False)
# Out:
# [CACHE] Rescued CHEMBL3138733: Formula=H34Cl6N14O2Ru3, SMILES=nan, Name=nan, MW=778.3
# [CACHE] Rescued CHEMBL5086057: Formula=C95H131Cu2IN20O27S2, SMILES=nan, Name=nan, MW=2303.72
# [CACHE] Rescued CHEMBL5087277: Formula=C97H127Cu2IN20O27S2, SMILES=nan, Name=nan, MW=2323.71
# [CACHE] Rescued CHEMBL5089315: Formula=C97H128Cu2IN21O26S2, SMILES=nan, Name=nan, MW=2322.73
# [CACHE] Rescued CHEMBL5087925: Formula=C98H131Cu2N21O26S2, SMILES=nan, Name=nan, MW=2210.86
# [CACHE] Rescued CHEMBL5092357: Formula=C31H46Cu2IN5O10, SMILES=nan, Name=nan, MW=903.11
# [CACHE] Rescued CHEMBL5196854: Formula=C21H14FN5O2V, SMILES=nan, Name=nan, MW=438.32
# Dropped 1133 activity rows where Molecule type was None and unrecoverable.
# This translates to 508 unique molecules dropped.
#
# Column: pChEMBL
# pChEMBL
# 4.40    62635
# 4.50    51983
# 4.60    50865
# 4.45    41109
# 4.90    40808
# 4.80    37485
# 5.00    36934
# 4.55    35441
# 4.70    30743
# 4.85    26539
# Name: count, dtype: int64
#
# Column: Data validity comment
# Data validity comment
# None                  2005523
# Manually validated        320
# Name: count, dtype: int64
#
# Column: Assay ChEMBL ID
# Assay ChEMBL ID
# CHEMBL1614458    76019
# CHEMBL1614421    49886
# CHEMBL1613914    39824
# CHEMBL1614544    36448
# CHEMBL1613842    33737
# CHEMBL1614038    24248
# CHEMBL1614502    24121
# CHEMBL1614079    23084
# CHEMBL1613838    22000
# CHEMBL1614250    20674
# Name: count, dtype: int64
#
# Column: confidence_score
# confidence_score
# 9    1557186
# 8     448657
# Name: count, dtype: int64
#
# Column: MOA
# MOA
# None                                                       1906225
# Tyrosine-protein kinase receptor FLT3 inhibitor               4985
# Stem cell growth factor receptor inhibitor                    3108
# Vascular endothelial growth factor receptor inhibitor         2816
# Platelet-derived growth factor receptor inhibitor             2601
# Serotonin 2a (5-HT2a) receptor antagonist                     2378
# Tyrosine-protein kinase receptor RET inhibitor                2371
# Vascular endothelial growth factor receptor 2 inhibitor       1674
# Epidermal growth factor receptor erbB1 inhibitor              1597
# Tyrosine-protein kinase JAK2 inhibitor                        1508
# Name: count, dtype: int64
#
# Column: Direct interaction (1/0)?
# Direct interaction (1/0)?
# NaN    1906225
# 1.0      99618
# Name: count, dtype: int64
#
# Column: Disease efficacy (1/0)?
# Disease efficacy (1/0)?
# NaN    1906225
# 1.0      99618
# Name: count, dtype: int64
#
# Column: Molecule ChEMBL ID
# Molecule ChEMBL ID
# CHEMBL535        6417
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2338
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1638
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Preferred name
# Preferred name
# NaN              1834016
# SUNITINIB           6417
# LESTAURTINIB        3180
# VORINOSTAT          2948
# VANDETANIB          2338
# FORETINIB           2124
# DOVITINIB           1970
# STAUROSPORINE       1780
# ALVOCIDIB           1638
# BOSUTINIB           1600
# Name: count, dtype: int64
#
# Column: Molecule type
# Molecule type
# Small molecule     1765023
# TBD                 224221
# Protein              15418
# None                  1133
# Oligosaccharide         43
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Max phase
# Max phase
#  NaN    1869202
#  4.0      79322
#  2.0      26563
#  3.0      18653
#  1.0       9404
# -1.0       2580
#  0.5        119
# Name: count, dtype: int64
#
# Column: Availability (2/1/0/-1/-2)?
# Availability (2/1/0/-1/-2)?
# -1.0    1847377
#  NaN      85853
#  1.0      62980
# -2.0       3675
#  0.0       3562
#  2.0       2396
# Name: count, dtype: int64
#
# Column: Therapeutic (1/0)?
# Therapeutic (1/0)?
# 0    1928198
# 1      77645
# Name: count, dtype: int64
#
# Column: First-in-class (1/0/-1)?
# First-in-class (1/0/-1)?
# -1    1869202
#  0     129749
#  1       6892
# Name: count, dtype: int64
#
# Column: Chemical probe (1/0)?
# Chemical probe (1/0)?
# 0    1993896
# 1      11947
# Name: count, dtype: int64
#
# Column: Orphan (1/0/-1)?
# Orphan (1/0/-1)?
# -1    1869202
#  0     132102
#  1       4539
# Name: count, dtype: int64
#
# Column: Canonical SMILES
# Canonical SMILES
# CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C                           6417
# C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)CNC4=O                3180
# O=C(CCCCCCC(=O)Nc1ccccc1)NO                                                       2948
# NaN                                                                               2613
# COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1                               2338
# COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1          2124
# CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1                           1970
# CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4    1780
# CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@H](O)C1                       1638
# COc1cc(Nc2c(C#N)cnc3cc(OCCCN4CCN(C)CC4)c(OC)cc23)c(Cl)cc1Cl                       1600
# Name: count, dtype: int64
#
# Column: Molecular weight of full compound
# Molecular weight of full compound
# 398.48    6752
# 439.47    3451
# 264.32    3157
# NaN       2601
# 475.36    2396
# 392.44    2392
# 466.54    2386
# 632.66    2141
# 332.41    2122
# 401.85    1876
# Name: count, dtype: int64
#
# Column: Molecular formula of full compound
# Molecular formula of full compound
# C22H27FN4O2      6531
# C26H21N3O4       3243
# C14H20N2O3       3018
# NaN              2601
# C22H24BrFN4O2    2357
# C34H34F2N4O6     2124
# C21H21FN6O       2054
# C28H26N4O3       2053
# C20H20N4O        1745
# C21H20ClNO5      1733
# Name: count, dtype: int64
#
# Column: Parent compound ChEMBL ID
# Parent compound ChEMBL ID
# CHEMBL535        6425
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2345
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1638
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Active ingredient ChEMBL ID
# Active ingredient ChEMBL ID
# CHEMBL535        6425
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2345
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1639
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Target ChEMBL ID
# Target ChEMBL ID
# CHEMBL1293224    95229
# CHEMBL3577       76482
# CHEMBL1293226    40132
# CHEMBL1293235    36863
# CHEMBL2608       35163
# CHEMBL1293232    33836
# CHEMBL1963       28951
# CHEMBL340        28814
# CHEMBL4096       26273
# CHEMBL1293255    24691
# Name: count, dtype: int64
#
# Column: Active ingredient of prodrug?
# Active ingredient of prodrug?
# No     1952897
# Yes      52946
# Name: count, dtype: int64

# %%
# %%skip
#
# df_chembl = pd.read_csv("../data/df_chembl.csv")
# unique_chembl_ids = (
#     df_chembl[df_chembl["Molecule type"] == "TBD"]["Molecule ChEMBL ID"]
#     .dropna()
#     .drop_duplicates()
#     .tolist()
# )
#
# cache_path = "../data/pubchem_peptide_inference_cache.csv"
# if os.path.exists(cache_path):
#     df_cache = pd.read_csv(cache_path)
#     df_cache = df_cache.drop_duplicates("Molecule ChEMBL ID")
#     cached_ids = set(df_cache["Molecule ChEMBL ID"])
# else:
#     df_cache = pd.DataFrame(columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
#     cached_ids = set()
#
# uncached_ids = [chembl_id for chembl_id in unique_chembl_ids if chembl_id not in cached_ids]
# print(f"Total molecules to check: {len(uncached_ids)}")
#
# # Process uncached ChEMBL IDs
# batch_size = 1000
# total_batches = (len(uncached_ids) + batch_size - 1) // batch_size
# new_results = []
# print(f"Total molecules to check: {len(uncached_ids)}")
#
# for i in range(0, len(uncached_ids), batch_size):
#     batch_number = i // batch_size + 1
#     batch = uncached_ids[i:i + batch_size]
#     print(f"Processing batch {batch_number} out of {total_batches} ({len(batch)} molecules)")
#     for chembl_id in batch:
#         cid = fetch_pubchem_cid_from_chembl(chembl_id)
#         is_peptide = check_peptide_by_pubchem(cid) if cid else False
#         timestamp = datetime.utcnow().isoformat()
#         new_results.append((chembl_id, cid, is_peptide, timestamp))
#         time.sleep(0.3)
#     # Append to cache
#     df_new = pd.DataFrame(new_results, columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
#     df_cache = pd.concat([df_cache, df_new], ignore_index=True).drop_duplicates("Molecule ChEMBL ID")
#     df_cache.to_csv(cache_path, index=False)
#     print(f"Added {len(df_new)} entries to cache.")
#     new_results = []
# print("PubChem peptide inference complete.")
# Out:
# Skipped cell

# %%
df_chembl = pd.read_csv("../data/df_chembl.csv", low_memory=False)
unique_chembl_ids = (
    df_chembl[df_chembl["Molecule type"] == "TBD"]["Molecule ChEMBL ID"]
    .dropna()
    .drop_duplicates()
    .tolist()
)

cache_path = "../data/pubchem_peptide_inference_cache.csv"
df_cache, cached_ids = load_or_init_pubchem_cache(cache_path)

uncached_ids = sorted(set(unique_chembl_ids) - cached_ids)
batch_size = 25
max_workers = 10

for i in range(0, len(uncached_ids), batch_size):
    batch = uncached_ids[i:i + batch_size]
    print(f"Processing batch {i//batch_size + 1} of {len(uncached_ids) // batch_size + 1}...")
    new_results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_id, chembl_id) for chembl_id in batch]
        for future in as_completed(futures):
            try:
                new_results.append(future.result())
            except Exception as e:
                print(f"Error: {e}")
    df_new = pd.DataFrame(new_results, columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
    df_cache = pd.concat([df_cache, df_new], ignore_index=True).drop_duplicates("Molecule ChEMBL ID")
    save_pubchem_cache(df_cache, cache_path)
print("PubChem peptide inference complete.")
# Out:
# Processing batch 1 of 1932...
# [CHEMBL5076790] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076791] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076794] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076787] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076801] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076796] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076802] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076804] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076792] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076798] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076791] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076790] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076787] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076794] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076801] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076792] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076804] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076796] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076798] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076802] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076791] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076787] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076790] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076801] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076794] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076792] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076804] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076798] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076802] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076796] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076791] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076787] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076790] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076794] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076801] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076792] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076804] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076796] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076798] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076802] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076787] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076787
# [CHEMBL5076787] CID=None | Peptide=False
# [CHEMBL5076791] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076791
# [CHEMBL5076791] CID=None | Peptide=False
# [CHEMBL5076790] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076790
# [CHEMBL5076790] CID=None | Peptide=False
# [CHEMBL5076794] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076794
# [CHEMBL5076794] CID=None | Peptide=False
# [CHEMBL5076801] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076801
# [CHEMBL5076801] CID=None | Peptide=False
# [CHEMBL5076804] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076804
# [CHEMBL5076804] CID=None | Peptide=False
# [CHEMBL5076802] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076802
# [CHEMBL5076802] CID=None | Peptide=False
# [CHEMBL5076792] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076792
# [CHEMBL5076792] CID=None | Peptide=False
# [CHEMBL5076798] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076798
# [CHEMBL5076798] CID=None | Peptide=False
# [CHEMBL5076796] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076796
# [CHEMBL5076796] CID=None | Peptide=False
# [CHEMBL5076816] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076817] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076820] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076818] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076819] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076831] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076829] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076823] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076821] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076824] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076816] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076820] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076819] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076817] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076818] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076824] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076831] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076821] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076823] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076829] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076820] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076817] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076816] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076819] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076821] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076831] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076823] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076818] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076824] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076829] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076820] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076817] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076816] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076821] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076818] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076824] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076829] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076819] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076831] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076823] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076817] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076817
# [CHEMBL5076817] CID=None | Peptide=False
# [CHEMBL5076820] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076820
# [CHEMBL5076820] CID=None | Peptide=False
# [CHEMBL5076816] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076816
# [CHEMBL5076816] CID=None | Peptide=False
# [CHEMBL5076821] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076821
# [CHEMBL5076821] CID=None | Peptide=False
# [CHEMBL5076818] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076818
# [CHEMBL5076818] CID=None | Peptide=False
# [CHEMBL5076824] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076824
# [CHEMBL5076824] CID=None | Peptide=False
# [CHEMBL5076829] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076829
# [CHEMBL5076829] CID=None | Peptide=False
# [CHEMBL5076832] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076836] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076837] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076845] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076846] Attempt 1/5 failed — 503 Server Busy
#    ↪ Retrying after 1.5 seconds...
# [CHEMBL5076819] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076819
# [CHEMBL5076819] CID=None | Peptide=False
# [CHEMBL5076831] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076831
# [CHEMBL5076831] CID=None | Peptide=False
# [CHEMBL5076823] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076823
# [CHEMBL5076823] CID=None | Peptide=False
# [CHEMBL5076836] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076837] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076832] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076845] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076846] Attempt 2/5 failed — 503 Server Busy
#    ↪ Retrying after 3.0 seconds...
# [CHEMBL5076836] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076832] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076837] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076845] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076846] Attempt 3/5 failed — 503 Server Busy
#    ↪ Retrying after 6.0 seconds...
# [CHEMBL5076836] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076832] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076837] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076845] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076846] Attempt 4/5 failed — 503 Server Busy
#    ↪ Retrying after 12.0 seconds...
# [CHEMBL5076836] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076836
# [CHEMBL5076836] CID=None | Peptide=False
# [CHEMBL5076832] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076832
# [CHEMBL5076832] CID=None | Peptide=False
# [CHEMBL5076846] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076846
# [CHEMBL5076846] CID=None | Peptide=False
# [CHEMBL5076845] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076845
# [CHEMBL5076845] CID=None | Peptide=False
# [CHEMBL5076837] Attempt 5/5 failed — 503 Server Busy
#    ✖ Final failure for CHEMBL5076837
# [CHEMBL5076837] CID=None | Peptide=False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 22
#      20 with ThreadPoolExecutor(max_workers=max_workers) as executor:
#      21     futures = [executor.submit(process_id, chembl_id) for chembl_id in batch]
# ---> 22     for future in as_completed(futures):
#      23         try:
#      24             new_results.append(future.result())
#
# File ~/anaconda3/lib/python3.12/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     238     if wait_timeout < 0:
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#     246     finished = waiter.finished_futures
#
# File ~/anaconda3/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/anaconda3/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
import os
import json
import subprocess
from pathlib import Path
from datetime import datetime

DATA_DIR = Path("../data")
DF_FILE = DATA_DIR / "df_chembl.csv"
PARQUET_FILE = DATA_DIR / "sql_chembl_cache.parquet"
META_FILE = DATA_DIR / ".cache_meta.json"
UPDATE_SCRIPT = Path("../update_cache.sh")

def file_mtime(path):
    return os.path.getmtime(path) if path.exists() else None

def load_meta():
    if META_FILE.exists():
        with open(META_FILE) as f:
            return json.load(f)
    return {}

def save_meta():
    meta = {
        "df_chembl.csv": file_mtime(DF_FILE),
        "sql_chembl_cache.parquet": file_mtime(PARQUET_FILE),
        "updated_at": datetime.utcnow().isoformat()
    }
    with open(META_FILE, "w") as f:
        json.dump(meta, f, indent=2)

def run_update_script():
    print("Running update_cache.sh to upload changed cache files...")
    subprocess.run(["bash", str(UPDATE_SCRIPT)], check=True)

prev_meta = load_meta()
current_meta = {
    "df_chembl.csv": file_mtime(DF_FILE),
    "sql_chembl_cache.parquet": file_mtime(PARQUET_FILE),
}

changed = any(
    prev_meta.get(fname) != current_meta[fname]
    for fname in current_meta
)

if changed:
    run_update_script()
    save_meta()
else:
    print("No changes detected. Skipping upload.")
# Out:
# Running update_cache.sh to upload changed cache files...
# Uploading updated cache files to Google Drive...
# Updating df_chembl.csv...
# Updating 1eu-jaosbrOfSKQ49_duSOB0lmCZlydJe with /home/florion/CompDReAM/data/df_chembl.csv
# File successfully updated
# Id: 1eu-jaosbrOfSKQ49_duSOB0lmCZlydJe
# Name: df_chembl.csv
# Mime: text/csv
# Size: 379.2 MB
# Created: 2025-06-11 14:48:25
# Modified: 2025-06-12 12:34:23
# MD5: fa8157daea19f19e78ec49f6591f81b5
# Shared: True
# Parents: 1mRygsFos3uz1a1xfzNeKEeRWZUxRZJy2
# ViewUrl: https://drive.google.com/file/d/1eu-jaosbrOfSKQ49_duSOB0lmCZlydJe/view?usp=drivesdk
# Updating sql_chembl_cache.parquet...
# Updating 1YP5RBI2H51OYawkhkxPv-uJcd-bPiAzK with /home/florion/CompDReAM/data/sql_chembl_cache.parquet
# File successfully updated
# Id: 1YP5RBI2H51OYawkhkxPv-uJcd-bPiAzK
# Name: sql_chembl_cache.parquet
# Mime: application/octet-stream
# Size: 108 MB
# Created: 2025-06-11 14:48:48
# Modified: 2025-06-12 12:34:26
# MD5: 9e7a1d7707a093d5f3b9618a6b30010a
# Shared: True
# Parents: 1mRygsFos3uz1a1xfzNeKEeRWZUxRZJy2
# ViewUrl: https://drive.google.com/file/d/1YP5RBI2H51OYawkhkxPv-uJcd-bPiAzK/view?usp=drivesdk
# Updating .cache_meta.json...
# Cache metadata file updated: /home/florion/CompDReAM/data/.cache_meta.json
# /tmp/ipykernel_14990/2769149720.py:26: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "updated_at": datetime.utcnow().isoformat()
