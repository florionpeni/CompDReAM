# %%
import sys
sys.path.append("../src")

import utils.skip_magic
from utils.chembl_rescue import rescue_from_chembl, load_or_init_chembl_cache, save_chembl_cache
from utils.molecule_cleanup import classify_relationship, resolve_molecule_type
from utils.pubchem_utils import fetch_pubchem_cid_from_chembl, check_peptide_by_pubchem, process_id, load_or_init_pubchem_cache, save_pubchem_cache
from utils.cache import should_download, file_mtime, load_meta, save_meta, run_update_script

import chembl_downloader
import re
import pandas as pd
import time
import os
import subprocess
from datetime import datetime, timezone
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed

DATA_DIR = Path("../data")
DF_FILE = DATA_DIR / "df_chembl.csv"
PARQUET_FILE = DATA_DIR / "sql_chembl_cache.parquet"
META_FILE = DATA_DIR / ".cache_meta.json"
UPDATE_SCRIPT = Path("../update_cache.sh")
if should_download(DF_FILE, PARQUET_FILE, META_FILE):
    print("Downloading cache files hosted on Google Drive...")
    os.makedirs(DATA_DIR, exist_ok=True)
    result = subprocess.run(["bash", "../get_cache.sh"], capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print("Errors:", result.stderr)
else:
    print("Local cache is up to date.")
# Out:
# Local cache is up to date.

# %%
sql_chembl_cache_path = "../data/sql_chembl_cache.parquet"

sql_chembl = """
SELECT
    a.pchembl_value AS "pChEMBL",
    a.potential_duplicate AS "Duplicate? (1/0)",
    a.data_validity_comment AS "Data validity comment",
    ass.chembl_id AS "Assay ChEMBL ID",
    ass.confidence_score,
    dm.mechanism_of_action AS "MOA",
    dm.direct_interaction AS "Direct interaction (1/0)?",
    dm.disease_efficacy AS "Disease efficacy (1/0)?",
    md.chembl_id AS "Molecule ChEMBL ID",
    md.pref_name AS "Preferred name",
    md.molecule_type AS "Molecule type",
    md.max_phase AS "Max phase",
    md.availability_type AS "Availability (2/1/0/-1/-2)?",
    md.therapeutic_flag AS "Therapeutic (1/0)?",
    md.first_in_class AS "First-in-class (1/0/-1)?",
    md.chemical_probe AS "Chemical probe (1/0)?",
    md.orphan AS "Orphan (1/0/-1)?",
    cs.canonical_smiles AS "Canonical SMILES",
    cp.full_mwt AS "Molecular weight of full compound",
    cp.full_molformula AS "Molecular formula of full compound",
    md_parent.chembl_id AS "Parent compound ChEMBL ID",
    md_parent.molecule_type AS parent_molecule_type,
    md_active.chembl_id AS "Active ingredient ChEMBL ID",
    mh.molregno,
    mh.parent_molregno,
    mh.active_molregno,
    td.chembl_id AS "Target ChEMBL ID"
FROM activities a
LEFT JOIN assays ass ON a.assay_id = ass.assay_id
LEFT JOIN target_dictionary td ON ass.tid = td.tid
LEFT JOIN drug_mechanism dm ON a.molregno = dm.molregno
LEFT JOIN molecule_dictionary md ON a.molregno = md.molregno
LEFT JOIN compound_structures cs ON md.molregno = cs.molregno
LEFT JOIN compound_properties cp ON cs.molregno = cp.molregno
LEFT JOIN molecule_hierarchy mh ON md.molregno = mh.molregno
LEFT JOIN molecule_dictionary md_parent ON mh.parent_molregno = md_parent.molregno
LEFT JOIN molecule_dictionary md_active ON mh.active_molregno = md_active.molregno
WHERE a.pchembl_value IS NOT NULL
  AND td.target_type = 'SINGLE PROTEIN'
  AND td.organism = 'Homo sapiens';
"""
if os.path.exists(sql_chembl_cache_path):
    print("Loading cached ChEMBL data...")
    df_raw = pd.read_parquet(sql_chembl_cache_path)
    print("Data loaded.")
else:
    print("Running SQL query...")
    df_raw = chembl_downloader.query(sql_chembl)
    print("Query complete. Saving to cache...")
    df_raw.to_parquet(sql_chembl_cache_path, index=False)
    print("Save complete.")

for col in df_raw.columns:
    print('\nColumn:', df_raw[col].value_counts(dropna=False).head(10))  # Show top 10 frequent values
# Out:
# Loading cached ChEMBL data...
# Data loaded.
#
# Column: pChEMBL
# 4.40    62704
# 4.50    52019
# 4.60    51015
# 4.45    41123
# 4.90    40848
# 4.80    37562
# 5.00    37292
# 4.55    35516
# 4.70    30871
# 4.85    26617
# Name: count, dtype: int64
#
# Column: Duplicate? (1/0)
# 0    2005843
# 1      95016
# Name: count, dtype: int64
#
# Column: Data validity comment
# None                  2100539
# Manually validated        320
# Name: count, dtype: int64
#
# Column: Assay ChEMBL ID
# CHEMBL1614458    76019
# CHEMBL1614421    49886
# CHEMBL1613914    39824
# CHEMBL1614544    36448
# CHEMBL1613842    33737
# CHEMBL1614038    24248
# CHEMBL1614502    24121
# CHEMBL1614079    23084
# CHEMBL1613838    22000
# CHEMBL1614250    20674
# Name: count, dtype: int64
#
# Column: confidence_score
# 9    1623093
# 8     477766
# Name: count, dtype: int64
#
# Column: MOA
# None                                                     1961774
# Tyrosine-protein kinase receptor FLT3 inhibitor             7102
# Stem cell growth factor receptor inhibitor                  4698
# Tyrosine-protein kinase receptor RET inhibitor              3658
# Platelet-derived growth factor receptor inhibitor           3641
# Vascular endothelial growth factor receptor inhibitor       3599
# Carbonic anhydrase II inhibitor                             3245
# Carbonic anhydrase IV inhibitor                             3064
# Serotonin 2a (5-HT2a) receptor antagonist                   2876
# Carbonic anhydrase I inhibitor                              2794
# Name: count, dtype: int64
#
# Column: Direct interaction (1/0)?
# NaN    1961774
# 1.0     139085
# Name: count, dtype: int64
#
# Column: Disease efficacy (1/0)?
# NaN    1961774
# 1.0     139085
# Name: count, dtype: int64
#
# Column: Molecule ChEMBL ID
# CHEMBL535        11025
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3360
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2448
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: Preferred name
# None             1879423
# SUNITINIB          11025
# ACETAZOLAMIDE       8632
# VORINOSTAT          5840
# LESTAURTINIB        5088
# MIDOSTAURIN         3385
# VANDETANIB          3360
# DOVITINIB           2660
# FORETINIB           2592
# ALVOCIDIB           2448
# Name: count, dtype: int64
#
# Column: Molecule type
# Small molecule     1852733
# Unknown             155576
# None                 74645
# Protein              17860
# Oligosaccharide         40
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Max phase
#  NaN    1918899
#  4.0     111910
#  2.0      31593
#  3.0      24677
#  1.0      10744
# -1.0       2908
#  0.5        128
# Name: count, dtype: int64
#
# Column: Availability (2/1/0/-1/-2)?
# -1.0    1898877
#  NaN      97788
#  1.0      93271
#  0.0       4223
# -2.0       4090
#  2.0       2610
# Name: count, dtype: int64
#
# Column: Therapeutic (1/0)?
# 0    1990748
# 1     110111
# Name: count, dtype: int64
#
# Column: First-in-class (1/0/-1)?
# -1    1918899
#  0     172021
#  1       9939
# Name: count, dtype: int64
#
# Column: Chemical probe (1/0)?
# 0    2086672
# 1      14187
# Name: count, dtype: int64
#
# Column: Orphan (1/0/-1)?
# -1    1918899
#  0     174942
#  1       7018
# Name: count, dtype: int64
#
# Column: Canonical SMILES
# CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C                                        11025
# CC(=O)Nc1nnc(S(N)(=O)=O)s1                                                                      8632
# O=C(CCCCCCC(=O)Nc1ccccc1)NO                                                                     5840
# C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)CNC4=O                              5088
# CO[C@@H]1[C@H](N(C)C(=O)c2ccccc2)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4     3385
# COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1                                             3360
# CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1                                         2660
# None                                                                                            2628
# COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1                        2592
# CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@H](O)C1                                     2448
# Name: count, dtype: int64
#
# Column: Molecular weight of full compound
# 398.48    11369
# 222.25     8844
# 264.32     6053
# 439.47     5362
# 570.65     3444
# 475.36     3418
# 392.44     3092
# 466.54     2794
# 401.85     2692
# NaN        2628
# Name: count, dtype: int64
#
# Column: Molecular formula of full compound
# C22H27FN4O2      11140
# C4H6N4O3S2        8632
# C14H20N2O3        5912
# C26H21N3O4        5152
# C35H30N4O4        3387
# C22H24BrFN4O2     3379
# C21H21FN6O        2746
# None              2628
# C34H34F2N4O6      2592
# C21H20ClNO5       2543
# Name: count, dtype: int64
#
# Column: Parent compound ChEMBL ID
# CHEMBL535        11033
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3367
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2448
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: parent_molecule_type
# Small molecule     1854239
# Unknown             155036
# None                 73668
# Protein              17868
# Oligosaccharide         43
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Active ingredient ChEMBL ID
# CHEMBL535        11033
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3367
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2450
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: molregno
# 13048     11025
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3360
# 494834     2660
# 692959     2592
# 14366      2448
# 373381     2188
# Name: count, dtype: int64
#
# Column: parent_molregno
# 13048     11033
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3367
# 494834     2660
# 692959     2592
# 14366      2448
# 373381     2188
# Name: count, dtype: int64
#
# Column: active_molregno
# 13048     11033
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3367
# 494834     2660
# 692959     2592
# 14366      2450
# 373381     2188
# Name: count, dtype: int64
#
# Column: Target ChEMBL ID
# CHEMBL1293224    95232
# CHEMBL3577       76494
# CHEMBL1293226    40146
# CHEMBL1293235    36863
# CHEMBL2608       35167
# CHEMBL1293232    33837
# CHEMBL340        29020
# CHEMBL1963       28951
# CHEMBL4096       26274
# CHEMBL1293255    24701
# Name: count, dtype: int64

# %%
df_raw = df_raw[df_raw["Duplicate? (1/0)"] != 1].copy()  # Drop likely duplicates 
active_ingredients = set(df_raw.loc[df_raw["molregno"] != df_raw["active_molregno"], "active_molregno"])  # Flag prodrugs
df_raw["Active ingredient of prodrug?"] = df_raw["molregno"].apply(
    lambda x: "Yes" if x in active_ingredients else "No"
)
df_raw["Molecule type"] = df_raw.apply(resolve_molecule_type, axis=1)  # Resolve molecule type

# Identify molecules needing rescue
df_dropped = df_raw[df_raw["Molecule type"].isna()].copy()  
dropped_ids = df_dropped["Molecule ChEMBL ID"].dropna().unique().tolist()

# Load or initialise cache
cache_path = "../data/df_rescued_cache.csv"
rescue_cache, _ = load_or_init_chembl_cache(cache_path)

rescued_rows = []
unrecoverable_ids = []
for chembl_id in dropped_ids:
    if chembl_id in rescue_cache:
        row = rescue_cache[chembl_id]
        rescued = (chembl_id, row["Rescued Formula"], row["Rescued SMILES"], row["Rescued Name"], row["Rescued MW"])
        source = "CACHE"
    else:
        rescued = rescue_from_chembl(chembl_id)
        time.sleep(0.5)
        rescue_cache[chembl_id] = {
            "Molecule ChEMBL ID": chembl_id,
            "Rescued Formula": rescued[1],
            "Rescued SMILES": rescued[2],
            "Rescued Name": rescued[3],
            "Rescued MW": rescued[4]
        }
        source = "SCRAPED"
    if any(pd.notna(v) for v in rescued[1:]):
        print(f"[{source}] Rescued {chembl_id}: Formula={rescued[1]}, SMILES={rescued[2]}, Name={rescued[3]}, MW={rescued[4]}")
    else:
        unrecoverable_ids.append(chembl_id)
    rescued_rows.append(rescued)

# Save updated cache
save_chembl_cache(rescue_cache, cache_path)

# Merge rescued data into df_raw
rescue_cols = ["Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW"]
df_rescued = pd.DataFrame(rescued_rows, columns=[
    "Molecule ChEMBL ID", "Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW"
])
if not df_rescued.empty:
    # Remove existing rescue columns if they exist before merging again
    for col in rescue_cols:
        if col in df_raw.columns:
            df_raw.drop(columns=col, inplace=True)
    df_raw = df_raw.merge(df_rescued, on="Molecule ChEMBL ID", how="left")

# Ensure rescue columns exist before combine_first for idempotency
for col in rescue_cols:
    if col not in df_raw.columns:
        df_raw[col] = pd.NA

# Proceed with safe combine
df_raw["Molecular formula of full compound"] = df_raw["Molecular formula of full compound"].combine_first(df_raw["Rescued Formula"])
df_raw["Canonical SMILES"] = df_raw["Canonical SMILES"].combine_first(df_raw["Rescued SMILES"])
df_raw["Preferred name"] = df_raw["Preferred name"].combine_first(df_raw["Rescued Name"])
df_raw["Molecular weight of full compound"] = df_raw["Molecular weight of full compound"].combine_first(df_raw["Rescued MW"])

# Re-resolve molecule type after rescue
df_raw["Molecule type"] = df_raw.apply(resolve_molecule_type, axis=1)

# Final filtering
final_dropped_df = df_raw[df_raw["Molecule type"].isna()]
final_dropped_ids = final_dropped_df["Molecule ChEMBL ID"].dropna().unique()
pd.Series(final_dropped_ids).to_csv("../data/final_dropped_ids.csv", index=False)
print(
    f"Dropped {final_dropped_df.shape[0]} activity rows where Molecule type was None and unrecoverable.\n"
    f"This translates to {final_dropped_ids.shape[0]} unique molecules dropped."
)

# Clean final dataset and save into df_chembl
columns_to_drop = [
    "parent_molecule_type", "molregno", "parent_molregno", "active_molregno",
    "Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW", "Duplicate? (1/0)"
]
df_chembl = df_raw.drop(columns=columns_to_drop, errors="ignore")
for col in df_chembl.columns:
    print('\nColumn:', col)
    print(df_chembl[col].value_counts(dropna=False).head(10))
df_chembl.to_csv("../data/df_chembl.csv", index=False)
# Out:
# [CACHE] Rescued CHEMBL3138733: Formula=H34Cl6N14O2Ru3, SMILES=nan, Name=nan, MW=778.3
# [CACHE] Rescued CHEMBL5086057: Formula=C95H131Cu2IN20O27S2, SMILES=nan, Name=nan, MW=2303.72
# [CACHE] Rescued CHEMBL5087277: Formula=C97H127Cu2IN20O27S2, SMILES=nan, Name=nan, MW=2323.71
# [CACHE] Rescued CHEMBL5089315: Formula=C97H128Cu2IN21O26S2, SMILES=nan, Name=nan, MW=2322.73
# [CACHE] Rescued CHEMBL5087925: Formula=C98H131Cu2N21O26S2, SMILES=nan, Name=nan, MW=2210.86
# [CACHE] Rescued CHEMBL5092357: Formula=C31H46Cu2IN5O10, SMILES=nan, Name=nan, MW=903.11
# [CACHE] Rescued CHEMBL5196854: Formula=C21H14FN5O2V, SMILES=nan, Name=nan, MW=438.32
# Dropped 1133 activity rows where Molecule type was None and unrecoverable.
# This translates to 508 unique molecules dropped.
#
# Column: pChEMBL
# pChEMBL
# 4.40    62635
# 4.50    51983
# 4.60    50865
# 4.45    41109
# 4.90    40808
# 4.80    37485
# 5.00    36934
# 4.55    35441
# 4.70    30743
# 4.85    26539
# Name: count, dtype: int64
#
# Column: Data validity comment
# Data validity comment
# None                  2005523
# Manually validated        320
# Name: count, dtype: int64
#
# Column: Assay ChEMBL ID
# Assay ChEMBL ID
# CHEMBL1614458    76019
# CHEMBL1614421    49886
# CHEMBL1613914    39824
# CHEMBL1614544    36448
# CHEMBL1613842    33737
# CHEMBL1614038    24248
# CHEMBL1614502    24121
# CHEMBL1614079    23084
# CHEMBL1613838    22000
# CHEMBL1614250    20674
# Name: count, dtype: int64
#
# Column: confidence_score
# confidence_score
# 9    1557186
# 8     448657
# Name: count, dtype: int64
#
# Column: MOA
# MOA
# None                                                       1906225
# Tyrosine-protein kinase receptor FLT3 inhibitor               4985
# Stem cell growth factor receptor inhibitor                    3108
# Vascular endothelial growth factor receptor inhibitor         2816
# Platelet-derived growth factor receptor inhibitor             2601
# Serotonin 2a (5-HT2a) receptor antagonist                     2378
# Tyrosine-protein kinase receptor RET inhibitor                2371
# Vascular endothelial growth factor receptor 2 inhibitor       1674
# Epidermal growth factor receptor erbB1 inhibitor              1597
# Tyrosine-protein kinase JAK2 inhibitor                        1508
# Name: count, dtype: int64
#
# Column: Direct interaction (1/0)?
# Direct interaction (1/0)?
# NaN    1906225
# 1.0      99618
# Name: count, dtype: int64
#
# Column: Disease efficacy (1/0)?
# Disease efficacy (1/0)?
# NaN    1906225
# 1.0      99618
# Name: count, dtype: int64
#
# Column: Molecule ChEMBL ID
# Molecule ChEMBL ID
# CHEMBL535        6417
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2338
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1638
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Preferred name
# Preferred name
# NaN              1834016
# SUNITINIB           6417
# LESTAURTINIB        3180
# VORINOSTAT          2948
# VANDETANIB          2338
# FORETINIB           2124
# DOVITINIB           1970
# STAUROSPORINE       1780
# ALVOCIDIB           1638
# BOSUTINIB           1600
# Name: count, dtype: int64
#
# Column: Molecule type
# Molecule type
# Small molecule     1765023
# TBD                 224221
# Protein              15418
# None                  1133
# Oligosaccharide         43
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Max phase
# Max phase
#  NaN    1869202
#  4.0      79322
#  2.0      26563
#  3.0      18653
#  1.0       9404
# -1.0       2580
#  0.5        119
# Name: count, dtype: int64
#
# Column: Availability (2/1/0/-1/-2)?
# Availability (2/1/0/-1/-2)?
# -1.0    1847377
#  NaN      85853
#  1.0      62980
# -2.0       3675
#  0.0       3562
#  2.0       2396
# Name: count, dtype: int64
#
# Column: Therapeutic (1/0)?
# Therapeutic (1/0)?
# 0    1928198
# 1      77645
# Name: count, dtype: int64
#
# Column: First-in-class (1/0/-1)?
# First-in-class (1/0/-1)?
# -1    1869202
#  0     129749
#  1       6892
# Name: count, dtype: int64
#
# Column: Chemical probe (1/0)?
# Chemical probe (1/0)?
# 0    1993896
# 1      11947
# Name: count, dtype: int64
#
# Column: Orphan (1/0/-1)?
# Orphan (1/0/-1)?
# -1    1869202
#  0     132102
#  1       4539
# Name: count, dtype: int64
#
# Column: Canonical SMILES
# Canonical SMILES
# CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C                           6417
# C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)CNC4=O                3180
# O=C(CCCCCCC(=O)Nc1ccccc1)NO                                                       2948
# NaN                                                                               2613
# COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1                               2338
# COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1          2124
# CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1                           1970
# CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4    1780
# CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@H](O)C1                       1638
# COc1cc(Nc2c(C#N)cnc3cc(OCCCN4CCN(C)CC4)c(OC)cc23)c(Cl)cc1Cl                       1600
# Name: count, dtype: int64
#
# Column: Molecular weight of full compound
# Molecular weight of full compound
# 398.48    6752
# 439.47    3451
# 264.32    3157
# NaN       2601
# 475.36    2396
# 392.44    2392
# 466.54    2386
# 632.66    2141
# 332.41    2122
# 401.85    1876
# Name: count, dtype: int64
#
# Column: Molecular formula of full compound
# Molecular formula of full compound
# C22H27FN4O2      6531
# C26H21N3O4       3243
# C14H20N2O3       3018
# NaN              2601
# C22H24BrFN4O2    2357
# C34H34F2N4O6     2124
# C21H21FN6O       2054
# C28H26N4O3       2053
# C20H20N4O        1745
# C21H20ClNO5      1733
# Name: count, dtype: int64
#
# Column: Parent compound ChEMBL ID
# Parent compound ChEMBL ID
# CHEMBL535        6425
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2345
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1638
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Active ingredient ChEMBL ID
# Active ingredient ChEMBL ID
# CHEMBL535        6425
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2345
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1639
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Target ChEMBL ID
# Target ChEMBL ID
# CHEMBL1293224    95229
# CHEMBL3577       76482
# CHEMBL1293226    40132
# CHEMBL1293235    36863
# CHEMBL2608       35163
# CHEMBL1293232    33836
# CHEMBL1963       28951
# CHEMBL340        28814
# CHEMBL4096       26273
# CHEMBL1293255    24691
# Name: count, dtype: int64
#
# Column: Active ingredient of prodrug?
# Active ingredient of prodrug?
# No     1952897
# Yes      52946
# Name: count, dtype: int64

# %%
# %%skip
#
# df_chembl = pd.read_csv("../data/df_chembl.csv")
# unique_chembl_ids = (
#     df_chembl[df_chembl["Molecule type"] == "TBD"]["Molecule ChEMBL ID"]
#     .dropna()
#     .drop_duplicates()
#     .tolist()
# )
#
# cache_path = "../data/pubchem_peptide_inference_cache.csv"
# if os.path.exists(cache_path):
#     df_cache = pd.read_csv(cache_path)
#     df_cache = df_cache.drop_duplicates("Molecule ChEMBL ID")
#     cached_ids = set(df_cache["Molecule ChEMBL ID"])
# else:
#     df_cache = pd.DataFrame(columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
#     cached_ids = set()
#
# uncached_ids = [chembl_id for chembl_id in unique_chembl_ids if chembl_id not in cached_ids]
# print(f"Total molecules to check: {len(uncached_ids)}")
#
# # Process uncached ChEMBL IDs
# batch_size = 1000
# total_batches = (len(uncached_ids) + batch_size - 1) // batch_size
# new_results = []
# print(f"Total molecules to check: {len(uncached_ids)}")
#
# for i in range(0, len(uncached_ids), batch_size):
#     batch_number = i // batch_size + 1
#     batch = uncached_ids[i:i + batch_size]
#     print(f"Processing batch {batch_number} out of {total_batches} ({len(batch)} molecules)")
#     for chembl_id in batch:
#         cid = fetch_pubchem_cid_from_chembl(chembl_id)
#         is_peptide = check_peptide_by_pubchem(cid) if cid else False
#         timestamp = datetime.utcnow().isoformat()
#         new_results.append((chembl_id, cid, is_peptide, timestamp))
#         time.sleep(0.3)
#     # Append to cache
#     df_new = pd.DataFrame(new_results, columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
#     df_cache = pd.concat([df_cache, df_new], ignore_index=True).drop_duplicates("Molecule ChEMBL ID")
#     df_cache.to_csv(cache_path, index=False)
#     print(f"Added {len(df_new)} entries to cache.")
#     new_results = []
# print("PubChem peptide inference complete.")
# Out:
# Skipped cell

# %%
df_chembl = pd.read_csv("../data/df_chembl.csv", low_memory=False)
unique_chembl_ids = (
    df_chembl[df_chembl["Molecule type"] == "TBD"]["Molecule ChEMBL ID"]
    .dropna()
    .drop_duplicates()
    .tolist()
)

cache_path = "../data/pubchem_peptide_inference_cache.csv"
df_cache, cached_ids = load_or_init_pubchem_cache(cache_path)

uncached_ids = sorted(set(unique_chembl_ids) - cached_ids)
batch_size = 25
max_workers = 4

for i in range(0, len(uncached_ids), batch_size):
    batch = uncached_ids[i:i + batch_size]
    print(f"Processing batch {i//batch_size + 1} of {len(uncached_ids) // batch_size + 1}...")
    new_results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_id, chembl_id) for chembl_id in batch]
        for future in as_completed(futures):
            try:
                new_results.append(future.result())
            except Exception as e:
                print(f"Error: {e}")
    df_new = pd.DataFrame(new_results, columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
    df_cache = pd.concat([df_cache, df_new], ignore_index=True).drop_duplicates("Molecule ChEMBL ID")
    save_pubchem_cache(df_cache, cache_path)
print("PubChem peptide inference complete.")
# Out:
# Processing batch 1 of 1864...
# [CHEMBL5080862] CID=139349505 | Peptide=False
# [CHEMBL5080857] CID=166630442 | Peptide=False
# [CHEMBL5080861] CID=135356032 | Peptide=False
# [CHEMBL5080858] CID=166630443 | Peptide=False
# [CHEMBL5080863] CID=166627309 | Peptide=False
# [CHEMBL5080864] CID=166627310 | Peptide=False
# [CHEMBL5080865] CID=156898862 | Peptide=False
# [CHEMBL5080867] CID=166627312 | Peptide=False
# [CHEMBL5080871] CID=166627437 | Peptide=False
# [CHEMBL5080868] CID=166627313 | Peptide=False
# [CHEMBL5080876] CID=166627593 | Peptide=False
# [CHEMBL5080880] CID=156433443 | Peptide=False
# [CHEMBL5080885] CID=156898699 | Peptide=False
# [CHEMBL5080884] CID=166627681 | Peptide=False
# [CHEMBL5080888] CID=166627684 | Peptide=False
# [CHEMBL5080889] CID=59649405 | Peptide=False
# [CHEMBL5080890] CID=156327125 | Peptide=False
# [CHEMBL5080891] CID=118120539 | Peptide=False
# [CHEMBL5080894] CID=156167160 | Peptide=False[CHEMBL5080897] CID=147406573 | Peptide=False
#
# [CHEMBL5080898] CID=139503431 | Peptide=False
# [CHEMBL5080899] CID=166627862 | Peptide=False
# [CHEMBL5080901] CID=151466390 | Peptide=False
# [CHEMBL5080902] CID=139350738 | Peptide=False
# [CHEMBL5080904] CID=148436013 | Peptide=False
# Processing batch 2 of 1864...
# [CHEMBL5080906] CID=166627865 | Peptide=False
# [CHEMBL5080907] CID=139349971 | Peptide=False
# [CHEMBL5080910] CID=139350985 | Peptide=False
# [CHEMBL5080909] CID=134214752 | Peptide=False
# [CHEMBL5080911] CID=139349613 | Peptide=False
# [CHEMBL5080912] CID=155781127 | Peptide=False
# [CHEMBL5080915] CID=134211789 | Peptide=False
# [CHEMBL5080916] CID=164866815 | Peptide=False
# [CHEMBL5080922] CID=166628311 | Peptide=False
# [CHEMBL5080923] CID=153625454 | Peptide=False
# [CHEMBL5080928] CID=157373511 | Peptide=False
# [CHEMBL5080929] CID=156816026 | Peptide=False
# [CHEMBL5080931] CID=162773067 | Peptide=False
# [CHEMBL5080935] CID=155585757 | Peptide=False
# [CHEMBL5080937] CID=166628563 | Peptide=False
# [CHEMBL5080939] CID=147066920 | Peptide=False
# [CHEMBL5080941] CID=166628565 | Peptide=True
# [CHEMBL5080942] CID=164879147 | Peptide=False
# [CHEMBL5080945] CID=155781263 | Peptide=False
# [CHEMBL5080948] CID=166629770 | Peptide=False
# [CHEMBL5080949] CID=166629771 | Peptide=False
# [CHEMBL5080953] CID=166629774 | Peptide=False
# [CHEMBL5080955] CID=166629776 | Peptide=False
# [CHEMBL5080959] CID=166629778 | Peptide=False
# [CHEMBL5080961] CID=155780796 | Peptide=False
# Processing batch 3 of 1864...
# [CHEMBL5080962] CID=124126393 | Peptide=False
# [CHEMBL5080964] CID=155780876 | Peptide=False
# [CHEMBL5080971] CID=156704954 | Peptide=False
# [CHEMBL5080968] CID=139529674 | Peptide=False
# [CHEMBL5080973] CID=166630225 | Peptide=False
# [CHEMBL5080975] CID=451512 | Peptide=False
# [CHEMBL5080977] CID=155781194 | Peptide=False
# [CHEMBL5080981] CID=156155270 | Peptide=False
# [CHEMBL5080984] CID=166627315 | Peptide=False
# [CHEMBL5080985] CID=162477331 | Peptide=False
# [CHEMBL5080992] CID=148462794 | Peptide=False
# [CHEMBL5080989] CID=155464279 | Peptide=False
# [CHEMBL5080998] CID=166627440 | Peptide=False
# [CHEMBL5080996] CID=166627323 | Peptide=False
# [CHEMBL5081006] CID=146446350 | Peptide=False
# [CHEMBL5081000] CID=130292548 | Peptide=False
# [CHEMBL5081007] CID=166627597 | Peptide=False
# [CHEMBL5081011] CID=166627691 | Peptide=False
# [CHEMBL5081012] CID=134218638 | Peptide=False
# [CHEMBL5081013] CID=166627692 | Peptide=False
# [CHEMBL5081014] CID=165378719 | Peptide=False
# [CHEMBL5081015] CID=166627867 | Peptide=False
# [CHEMBL5081016] CID=156816053 | Peptide=False
# [CHEMBL5081017] CID=155780899 | Peptide=False
# [CHEMBL5081019] CID=166628122 | Peptide=False
# Processing batch 4 of 1864...
# [CHEMBL5081027] CID=166628566 | Peptide=False
# [CHEMBL5081025] CID=166628314 | Peptide=False
# [CHEMBL5081023] CID=166628125 | Peptide=False
# [CHEMBL5081030] CID=129218638 | Peptide=False
# [CHEMBL5081032] CID=155780970 | Peptide=False
# [CHEMBL5081035] CID=155139335 | Peptide=False
# [CHEMBL5081036] CID=155184081 | Peptide=False
# [CHEMBL5081039] CID=155803663 | Peptide=False
# [CHEMBL5081040] CID=166628571 | Peptide=False
# [CHEMBL5081041] CID=155789932 | Peptide=False
# [CHEMBL5081042] CID=166628572 | Peptide=False
# [CHEMBL5081047] CID=166629280 | Peptide=False
# [CHEMBL5081048] CID=162369732 | Peptide=False
# [CHEMBL5081049] CID=156433462 | Peptide=False
# [CHEMBL5081052] CID=155797802 | Peptide=False
# [CHEMBL5081055] CID=96480977 | Peptide=False
# [CHEMBL5081056] CID=124126388 | Peptide=False
# [CHEMBL5081057] CID=166629497 | Peptide=False
# [CHEMBL5081059] CID=139350682 | Peptide=False
# [CHEMBL5081065] CID=166008549 | Peptide=False
# [CHEMBL5081072] CID=166627695 | Peptide=False
# [CHEMBL5081073] CID=166627696 | Peptide=False
# [CHEMBL5081075] CID=141746013 | Peptide=False
# [CHEMBL5081076] CID=166628128 | Peptide=False
# [CHEMBL5081077] CID=166628316 | Peptide=True
# Processing batch 5 of 1864...
# [CHEMBL5081081] CID=166628320 | Peptide=False
# [CHEMBL5081088] CID=166628573 | Peptide=False
# [CHEMBL5081087] CID=139350364 | Peptide=False
# [CHEMBL5081090] CID=155436605 | Peptide=False
# [CHEMBL5081092] CID=147722508 | Peptide=False
# [CHEMBL5081097] CID=166628804 | Peptide=False
# [CHEMBL5081096] CID=166628803 | Peptide=False
# [CHEMBL5081098] CID=166629088 | Peptide=False
# [CHEMBL5081101] CID=139503493 | Peptide=False
# [CHEMBL5081104] CID=166629091 | Peptide=False
# [CHEMBL5081105] CID=163215471 | Peptide=False
# [CHEMBL5081106] CID=166629092 | Peptide=False
# [CHEMBL5081108] CID=156898798 | Peptide=False
# [CHEMBL5081113] CID=156433445 | Peptide=False
# [CHEMBL5081116] CID=166629286 | Peptide=False
# [CHEMBL5081117] CID=156388252 | Peptide=False
# [CHEMBL5081118] CID=156898914 | Peptide=False
# [CHEMBL5081119] CID=155801532 | Peptide=False
# [CHEMBL5081120] CID=155781086 | Peptide=False
# [CHEMBL5081121] CID=166629287 | Peptide=False
# [CHEMBL5081126] CID=166629291 | Peptide=False
# [CHEMBL5081128] CID=166629293 | Peptide=False
# [CHEMBL5081133] CID=126539477 | Peptide=False
# [CHEMBL5081135] CID=10682212 | Peptide=False
# [CHEMBL5081136] CID=164916959 | Peptide=False
# Processing batch 6 of 1864...
# [CHEMBL5081142] CID=166629781 | Peptide=False
# [CHEMBL5081138] CID=155781418 | Peptide=False
# [CHEMBL5081140] CID=154609137 | Peptide=False
# [CHEMBL5081139] CID=166629779 | Peptide=True
# [CHEMBL5081145] CID=166629783 | Peptide=False
# [CHEMBL5081154] CID=137550025 | Peptide=False
# [CHEMBL5081158] CID=166630451 | Peptide=False
# [CHEMBL5081159] CID=137371217 | Peptide=False
# [CHEMBL5081160] CID=166630452 | Peptide=False
# [CHEMBL5081161] CID=148161065 | Peptide=False
# [CHEMBL5081163] CID=156587362 | Peptide=False
# [CHEMBL5081164] CID=166630453 | Peptide=False
# [CHEMBL5081172] CID=46926031 | Peptide=False
# [CHEMBL5081173] CID=146868953 | Peptide=False
# [CHEMBL5081174] CID=166627448 | Peptide=False
# [CHEMBL5081178] CID=166627602 | Peptide=False
# [CHEMBL5081179] CID=166627603 | Peptide=False
# [CHEMBL5081180] CID=166627604 | Peptide=False
# [CHEMBL5081181] CID=150191026 | Peptide=False
# [CHEMBL5081182] CID=155907494 | Peptide=False
# [CHEMBL5081183] CID=126539557 | Peptide=False
# [CHEMBL5081184] CID=154957797 | Peptide=False
# [CHEMBL5081192] CID=156731570 | Peptide=False
# [CHEMBL5081193] CID=134587945 | Peptide=False
# [CHEMBL5081194] CID=166627610 | Peptide=False
# Processing batch 7 of 1864...
# [CHEMBL5081200] CID=166627613 | Peptide=False
# [CHEMBL5081199] CID=166627612 | Peptide=False
# [CHEMBL5081196] CID=146490538 | Peptide=False
# [CHEMBL5081195] CID=139349886 | Peptide=False
# [CHEMBL5081201] CID=155780829 | Peptide=False
# [CHEMBL5081202] CID=58442304 | Peptide=False
# [CHEMBL5081206] CID=166628129 | Peptide=False
# [CHEMBL5081207] CID=156704965 | Peptide=False
# [CHEMBL5081210] CID=138607152 | Peptide=False
# [CHEMBL5081214] CID=90186611 | Peptide=False
# [CHEMBL5081215] CID=166628325 | Peptide=False
# [CHEMBL5081216] CID=166628326 | Peptide=False
# [CHEMBL5081217] CID=122689335 | Peptide=False
# [CHEMBL5081219] CID=166628328 | Peptide=False
# [CHEMBL5081222] CID=134214785 | Peptide=False
# [CHEMBL5081226] CID=135385909 | Peptide=False
# [CHEMBL5081229] CID=153603019 | Peptide=False
# [CHEMBL5081230] CID=166628576 | Peptide=False
# [CHEMBL5081231] CID=137366000 | Peptide=False
# [CHEMBL5081237] CID=166628580 | Peptide=False
# [CHEMBL5081238] CID=166626551 | Peptide=False
# [CHEMBL5081239] CID=155780840 | Peptide=False
# [CHEMBL5081241] CID=153534346 | Peptide=False
# [CHEMBL5081244] CID=166628582 | Peptide=False
# [CHEMBL5081245] CID=166628583 | Peptide=False
# Processing batch 8 of 1864...
# [CHEMBL5081250] CID=137365937 | Peptide=False
# [CHEMBL5081247] CID=166628585 | Peptide=False
# [CHEMBL5081257] CID=146345963 | Peptide=False
# [CHEMBL5081258] CID=164879213 | Peptide=False
# [CHEMBL5081259] CID=166628808 | Peptide=True
# [CHEMBL5081260] CID=166629095 | Peptide=False
# [CHEMBL5081262] CID=166629097 | Peptide=False
# [CHEMBL5081264] CID=163630790 | Peptide=False
# [CHEMBL5081266] CID=156304027 | Peptide=False
# [CHEMBL5081267] CID=166629099 | Peptide=False
# [CHEMBL5081268] CID=166629100 | Peptide=True
# [CHEMBL5081269] CID=166629101 | Peptide=False
# [CHEMBL5081270] CID=166629102 | Peptide=False
# [CHEMBL5081271] CID=166629103 | Peptide=False
# [CHEMBL5081272] CID=166629104 | Peptide=False
# [CHEMBL5081273] CID=166629784 | Peptide=False
# [CHEMBL5081275] CID=166629785 | Peptide=False
# [CHEMBL5081276] CID=162719824 | Peptide=False
# [CHEMBL5081277] CID=156395738 | Peptide=False
# [CHEMBL5081279] CID=166629787 | Peptide=False
# [CHEMBL5081283] CID=166629790 | Peptide=False
# [CHEMBL5081286] CID=139350700 | Peptide=False
# [CHEMBL5081287] CID=166629792 | Peptide=True
# [CHEMBL5081289] CID=166629794 | Peptide=True
# [CHEMBL5081290] CID=139375480 | Peptide=False
# Processing batch 9 of 1864...
# [CHEMBL5081302] CID=166630011 | Peptide=False
# [CHEMBL5081303] CID=166630012 | Peptide=False
# [CHEMBL5081299] CID=166630009 | Peptide=False
# [CHEMBL5081296] CID=156704967 | Peptide=False
# [CHEMBL5081306] CID=166630015 | Peptide=False
# [CHEMBL5081307] CID=154957904 | Peptide=False
# [CHEMBL5081315] CID=71735732 | Peptide=False
# [CHEMBL5081316] CID=166630019 | Peptide=False
# [CHEMBL5081318] CID=135355725 | Peptide=False
# [CHEMBL5081320] CID=166630020 | Peptide=False
# [CHEMBL5081323] CID=166630022 | Peptide=False
# [CHEMBL5081327] CID=155464570 | Peptide=False
# [CHEMBL5081328] CID=166630025 | Peptide=False
# [CHEMBL5081330] CID=166630027 | Peptide=False
# [CHEMBL5081334] CID=137549330 | Peptide=False
# [CHEMBL5081335] CID=166627697 | Peptide=False
# [CHEMBL5081338] CID=139350546 | Peptide=False
# [CHEMBL5081341] CID=166627869 | Peptide=False
# [CHEMBL5081349] CID=166628135 | Peptide=False
# [CHEMBL5081350] CID=50799610 | Peptide=False
# [CHEMBL5081351] CID=146718259 | Peptide=False
# [CHEMBL5081352] CID=139375528 | Peptide=False
# [CHEMBL5081353] CID=166628136 | Peptide=False
# [CHEMBL5081354] CID=50761748 | Peptide=False
# [CHEMBL5081355] CID=166628333 | Peptide=False
# Processing batch 10 of 1864...
# [CHEMBL5081365] CID=153625073 | Peptide=False
# [CHEMBL5081359] CID=154644627 | Peptide=False
# [CHEMBL5081360] CID=139350732 | Peptide=False
# [CHEMBL5081366] CID=156501351 | Peptide=False
# [CHEMBL5081367] CID=166628336 | Peptide=False
# [CHEMBL5081371] CID=166628339 | Peptide=True
# [CHEMBL5081372] CID=166628340 | Peptide=False
# [CHEMBL5081373] CID=166628341 | Peptide=False
# [CHEMBL5081376] CID=166628344 | Peptide=True
# [CHEMBL5081374] CID=166628342 | Peptide=False
# [CHEMBL5081379] CID=166628347 | Peptide=False
# [CHEMBL5081380] CID=135385569 | Peptide=False
# [CHEMBL5081381] CID=164141869 | Peptide=False
# [CHEMBL5081382] CID=155781091 | Peptide=False
# [CHEMBL5081384] CID=166628349 | Peptide=False
# [CHEMBL5081385] CID=137365866 | Peptide=False
# [CHEMBL5081388] CID=166628586 | Peptide=False
# [CHEMBL5081392] CID=139375455 | Peptide=False
# [CHEMBL5081396] CID=166628589 | Peptide=False
# [CHEMBL5081397] CID=162679119 | Peptide=False
# [CHEMBL5081399] CID=166628590 | Peptide=False
# [CHEMBL5081402] CID=137365813 | Peptide=False
# [CHEMBL5081404] CID=135385334 | Peptide=False
# [CHEMBL5081405] CID=166628593 | Peptide=False
# [CHEMBL5081407] CID=166628594 | Peptide=False
# Processing batch 11 of 1864...
# [CHEMBL5081421] CID=166629503 | Peptide=False
# [CHEMBL5081409] CID=166628809 | Peptide=True
# [CHEMBL5081410] CID=166628810 | Peptide=True
# [CHEMBL5081418] CID=156898800 | Peptide=False
# [CHEMBL5081422] CID=166629504 | Peptide=False
# [CHEMBL5081424] CID=166629505 | Peptide=False
# [CHEMBL5081426] CID=4386878 | Peptide=False
# [CHEMBL5081428] CID=155464326 | Peptide=False
# [CHEMBL5081429] CID=155781050 | Peptide=False
# [CHEMBL5081430] CID=166629507 | Peptide=False
# [CHEMBL5081433] CID=166629510 | Peptide=False
# [CHEMBL5081432] CID=166629509 | Peptide=True
# [CHEMBL5081438] CID=156129935 | Peptide=False
# [CHEMBL5081435] CID=124222717 | Peptide=False
# [CHEMBL5081441] CID=38157008 | Peptide=False
# [CHEMBL5081442] CID=166627325 | Peptide=False
# [CHEMBL5081444] CID=153624884 | Peptide=False
# [CHEMBL5081445] CID=50761840 | Peptide=False
# [CHEMBL5081446] CID=166627326 | Peptide=False
# [CHEMBL5081449] CID=134218457 | Peptide=False
# [CHEMBL5081451] CID=139360867 | Peptide=False
# [CHEMBL5081452] CID=166627328 | Peptide=False
# [CHEMBL5081455] CID=118285621 | Peptide=False
# [CHEMBL5081453] CID=166627329 | Peptide=False
# [CHEMBL5081457] CID=166627451 | Peptide=False
# Processing batch 12 of 1864...
# [CHEMBL5081461] CID=155781234 | Peptide=False
# [CHEMBL5081459] CID=166627701 | Peptide=False
# [CHEMBL5081466] CID=166627706 | Peptide=False
# [CHEMBL5081465] CID=156327087 | Peptide=False
# [CHEMBL5081469] CID=166628138 | Peptide=True
# [CHEMBL5081471] CID=166628350 | Peptide=False
# [CHEMBL5081474] CID=166628351 | Peptide=False
# [CHEMBL5081477] CID=152283222 | Peptide=False
# [CHEMBL5081487] CID=163198520 | Peptide=False
# [CHEMBL5081489] CID=166628813 | Peptide=False
# [CHEMBL5081490] CID=141738571 | Peptide=False
# [CHEMBL5081491] CID=155464491 | Peptide=False
# [CHEMBL5081492] CID=717832 | Peptide=False
# [CHEMBL5081493] CID=134218663 | Peptide=False
# [CHEMBL5081497] CID=142380235 | Peptide=False
# [CHEMBL5081498] CID=166629106 | Peptide=False
# [CHEMBL5081500] CID=139503465 | Peptide=False
# [CHEMBL5081501] CID=6520065 | Peptide=False
# [CHEMBL5081502] CID=166629511 | Peptide=False
# [CHEMBL5081503] CID=153625374 | Peptide=False
# [CHEMBL5081505] CID=155808034 | Peptide=False
# [CHEMBL5081506] CID=166629513 | Peptide=False
# [CHEMBL5081507] CID=166629514 | Peptide=False
# [CHEMBL5081508] CID=155436759 | Peptide=False
# [CHEMBL5081509] CID=152784743 | Peptide=False
# Processing batch 13 of 1864...
# [CHEMBL5081514] CID=166008540 | Peptide=False
# [CHEMBL5081512] CID=166629516 | Peptide=False
# [CHEMBL5081515] CID=166629517 | Peptide=False
# [CHEMBL5081513] CID=155352269 | Peptide=False
# [CHEMBL5081517] CID=166629518 | Peptide=False
# [CHEMBL5081520] CID=166629521 | Peptide=False
# [CHEMBL5081522] CID=166629522 | Peptide=False
# [CHEMBL5081523] CID=166629523 | Peptide=False
# [CHEMBL5081525] CID=141738557 | Peptide=False
# [CHEMBL5081526] CID=121389859 | Peptide=False
# [CHEMBL5081532] CID=162763949 | Peptide=False
# [CHEMBL5081534] CID=166630461 | Peptide=False
# [CHEMBL5081537] CID=166630464 | Peptide=False
# [CHEMBL5081538] CID=156825751 | Peptide=False
# [CHEMBL5081540] CID=156326950 | Peptide=False
# [CHEMBL5081543] CID=162773053 | Peptide=False
# [CHEMBL5081545] CID=163249280 | Peptide=False
# [CHEMBL5081547] CID=166627332 | Peptide=False
# [CHEMBL5081556] CID=166627333 | Peptide=False
# [CHEMBL5081557] CID=155899157 | Peptide=False
# [CHEMBL5081562] CID=166627335 | Peptide=False
# [CHEMBL5081565] CID=50760537 | Peptide=False
# [CHEMBL5081567] CID=164866746 | Peptide=False
# [CHEMBL5081570] CID=166627618 | Peptide=False
# [CHEMBL5081571] CID=126733921 | Peptide=False
# Processing batch 14 of 1864...
# [CHEMBL5081573] CID=166627707 | Peptide=True
# [CHEMBL5081576] CID=166627709 | Peptide=False
# [CHEMBL5081574] CID=166627708 | Peptide=False
# [CHEMBL5081575] CID=155436533 | Peptide=False
# [CHEMBL5081578] CID=166627711 | Peptide=True
# [CHEMBL5081582] CID=166627714 | Peptide=False
# [CHEMBL5081583] CID=166627715 | Peptide=False
# [CHEMBL5081586] CID=166627717 | Peptide=False
# [CHEMBL5081587] CID=166627718 | Peptide=False
# [CHEMBL5081591] CID=155781015 | Peptide=False
# [CHEMBL5081596] CID=156898881 | Peptide=False
# [CHEMBL5081600] CID=141716977 | Peptide=False
# [CHEMBL5081601] CID=166628143 | Peptide=False
# [CHEMBL5081603] CID=166628145 | Peptide=False
# [CHEMBL5081604] CID=166628146 | Peptide=False
# [CHEMBL5081606] CID=166628147 | Peptide=False
# [CHEMBL5081608] CID=59268695 | Peptide=False
# [CHEMBL5081612] CID=166628355 | Peptide=False
# [CHEMBL5081615] CID=155781348 | Peptide=False
# [CHEMBL5081617] CID=166628816 | Peptide=False
# [CHEMBL5081620] CID=166628818 | Peptide=False
# [CHEMBL5081621] CID=166628819 | Peptide=True
# [CHEMBL5081624] CID=86340151 | Peptide=False
# [CHEMBL5081630] CID=630507 | Peptide=False
# [CHEMBL5081631] CID=166629107 | Peptide=False
# Processing batch 15 of 1864...
# [CHEMBL5081633] CID=166629109 | Peptide=False
# [CHEMBL5081636] CID=139369977 | Peptide=False
# [CHEMBL5081634] CID=166629110 | Peptide=False
# [CHEMBL5081635] CID=155797797 | Peptide=False
# [CHEMBL5081637] CID=156852021 | Peptide=False
# [CHEMBL5081638] CID=155781306 | Peptide=False
# [CHEMBL5081641] CID=155781465 | Peptide=False
# [CHEMBL5081642] CID=146282327 | Peptide=False
# [CHEMBL5081645] CID=166629526 | Peptide=False
# [CHEMBL5081652] CID=145269567 | Peptide=False
# [CHEMBL5081653] CID=166629800 | Peptide=False
# [CHEMBL5081655] CID=155789962 | Peptide=False
# [CHEMBL5081660] CID=166629803 | Peptide=False
# [CHEMBL5081662] CID=134201305 | Peptide=False
# [CHEMBL5081663] CID=166630468 | Peptide=False
# [CHEMBL5081666] CID=147015739 | Peptide=False
# [CHEMBL5081667] CID=71816486 | Peptide=False
# [CHEMBL5081668] CID=166630470 | Peptide=False
# [CHEMBL5081670] CID=102495967 | Peptide=False
# [CHEMBL5081674] CID=166627726 | Peptide=False
# [CHEMBL5081679] CID=166627727 | Peptide=False
# [CHEMBL5081680] CID=155780997 | Peptide=False
# [CHEMBL5081683] CID=166627728 | Peptide=False
# [CHEMBL5081684] CID=163791763 | Peptide=False
# [CHEMBL5081689] CID=146205049 | Peptide=False
# Processing batch 16 of 1864...
# [CHEMBL5081701] CID=156898919 | Peptide=False
# [CHEMBL5081699] CID=166627879 | Peptide=False
# [CHEMBL5081693] CID=150772483 | Peptide=False
# [CHEMBL5081695] CID=166627875 | Peptide=False
# [CHEMBL5081704] CID=166491805 | Peptide=False
# [CHEMBL5081713] CID=166628357 | Peptide=False
# [CHEMBL5081715] CID=166628360 | Peptide=False
# [CHEMBL5081718] CID=166628361 | Peptide=True
# [CHEMBL5081719] CID=166628362 | Peptide=False
# [CHEMBL5081722] CID=166628364 | Peptide=False
# [CHEMBL5081728] CID=152154425 | Peptide=False
# [CHEMBL5081731] CID=162773044 | Peptide=False
# [CHEMBL5081733] CID=166628369 | Peptide=False
# [CHEMBL5081732] CID=166628368 | Peptide=False
# [CHEMBL5081734] CID=166628370 | Peptide=False
# [CHEMBL5081740] CID=166628825 | Peptide=False
# [CHEMBL5081743] CID=137549028 | Peptide=False
# [CHEMBL5081746] CID=155781305 | Peptide=False
# [CHEMBL5081749] CID=156395623 | Peptide=False
# [CHEMBL5081756] CID=156433463 | Peptide=False
# [CHEMBL5081757] CID=166630037 | Peptide=False
# [CHEMBL5081760] CID=162426815 | Peptide=False
# [CHEMBL5081759] CID=139375444 | Peptide=False
# [CHEMBL5081764] CID=166630473 | Peptide=False
# [CHEMBL5081765] CID=139350654 | Peptide=False
# Processing batch 17 of 1864...
# [CHEMBL5081769] CID=9552528 | Peptide=False
# [CHEMBL5081767] CID=134218524 | Peptide=False
# [CHEMBL5081773] CID=166630477 | Peptide=False
# [CHEMBL5081770] CID=166630474 | Peptide=False
# [CHEMBL5081774] CID=162760083 | Peptide=False
# [CHEMBL5081775] CID=155797793 | Peptide=False
# [CHEMBL5081776] CID=139347014 | Peptide=False
# [CHEMBL5081778] CID=166630478 | Peptide=False
# [CHEMBL5081782] CID=164585648 | Peptide=False
# [CHEMBL5081786] CID=166630481 | Peptide=False
# [CHEMBL5081787] CID=135416229 | Peptide=False
# [CHEMBL5081790] CID=166627337 | Peptide=False
# [CHEMBL5081794] CID=155781395 | Peptide=False
# [CHEMBL5081795] CID=137365717 | Peptide=False
# [CHEMBL5081796] CID=166627729 | Peptide=False
# [CHEMBL5081802] CID=156816283 | Peptide=False
# [CHEMBL5081803] CID=166627732 | Peptide=False
# [CHEMBL5081804] CID=22728016 | Peptide=False
# [CHEMBL5081806] CID=156596355 | Peptide=False
# [CHEMBL5081807] CID=166627734 | Peptide=False
# [CHEMBL5081810] CID=166627736 | Peptide=False
# [CHEMBL5081811] CID=166627737 | Peptide=False
# [CHEMBL5081812] CID=166627738 | Peptide=False
# [CHEMBL5081815] CID=156754670 | Peptide=False
# [CHEMBL5081816] CID=124090518 | Peptide=False
# Processing batch 18 of 1864...
# [CHEMBL5081817] CID=166627739 | Peptide=False
# [CHEMBL5081819] CID=134218885 | Peptide=False
# [CHEMBL5081821] CID=154632940 | Peptide=False
# [CHEMBL5081823] CID=166627883 | Peptide=False
# [CHEMBL5081824] CID=155595352 | Peptide=False
# [CHEMBL5081828] CID=155781004 | Peptide=False
# [CHEMBL5081829] CID=163405364 | Peptide=False
# [CHEMBL5081827] CID=166628375 | Peptide=False
# [CHEMBL5081830] CID=50799976 | Peptide=False
# [CHEMBL5081833] CID=130432732 | Peptide=False
# [CHEMBL5081834] CID=153625168 | Peptide=False
# [CHEMBL5081841] CID=166629528 | Peptide=False
# [CHEMBL5081843] CID=166629530 | Peptide=False
# [CHEMBL5081847] CID=155781245 | Peptide=False
# [CHEMBL5081848] CID=146291720 | Peptide=False
# [CHEMBL5081849] CID=166629532 | Peptide=False
# [CHEMBL5081850] CID=68019804 | Peptide=False
# [CHEMBL5081851] CID=155436636 | Peptide=False
# [CHEMBL5081853] CID=166629804 | Peptide=False
# [CHEMBL5081855] CID=150535119 | Peptide=False[CHEMBL5081854] CID=156816411 | Peptide=False
#
# [CHEMBL5081856] CID=155780825 | Peptide=False
# [CHEMBL5081860] CID=166629807 | Peptide=False
# [CHEMBL5081861] CID=166630039 | Peptide=False
# [CHEMBL5081862] CID=166630040 | Peptide=False
# Processing batch 19 of 1864...
# [CHEMBL5081863] CID=151510018 | Peptide=False
# [CHEMBL5081864] CID=155682846 | Peptide=False
# [CHEMBL5081868] CID=155436728 | Peptide=False
# [CHEMBL5081865] CID=156704950 | Peptide=False
# [CHEMBL5081869] CID=136213312 | Peptide=False
# [CHEMBL5081877] CID=154963854 | Peptide=False
# [CHEMBL5081875] CID=166627455 | Peptide=False
# [CHEMBL5081878] CID=166627457 | Peptide=False
# [CHEMBL5081884] CID=118120219 | Peptide=False
# [CHEMBL5081886] CID=156327073 | Peptide=False
# [CHEMBL5081887] CID=162477321 | Peptide=False
# [CHEMBL5081888] CID=166627623 | Peptide=False
# [CHEMBL5081889] CID=139346971 | Peptide=False
# [CHEMBL5081890] CID=156898991 | Peptide=False
# [CHEMBL5081891] CID=166627624 | Peptide=False
# [CHEMBL5081892] CID=139360687 | Peptide=False
# [CHEMBL5081898] CID=166627885 | Peptide=False
# [CHEMBL5081899] CID=162785111 | Peptide=False
# [CHEMBL5081900] CID=166627886 | Peptide=True
# [CHEMBL5081901] CID=166627887 | Peptide=False
# [CHEMBL5081902] CID=163800258 | Peptide=False
# [CHEMBL5081904] CID=139360648 | Peptide=False
# [CHEMBL5081907] CID=166627891 | Peptide=False
# [CHEMBL5081912] CID=156898667 | Peptide=False
# [CHEMBL5081913] CID=166629113 | Peptide=False
# Processing batch 20 of 1864...
# [CHEMBL5081914] CID=135387020 | Peptide=False
# [CHEMBL5081917] CID=155289352 | Peptide=False
# [CHEMBL5081920] CID=166629116 | Peptide=False
# [CHEMBL5081919] CID=137365547 | Peptide=False
# [CHEMBL5081921] CID=166629296 | Peptide=False
# [CHEMBL5081922] CID=153624839 | Peptide=False
# [CHEMBL5081923] CID=166629297 | Peptide=False
# [CHEMBL5081924] CID=166629298 | Peptide=False
# [CHEMBL5081926] CID=166629534 | Peptide=False
# [CHEMBL5081927] CID=166629535 | Peptide=False
# [CHEMBL5081934] CID=137365722 | Peptide=False
# [CHEMBL5081937] CID=166629541 | Peptide=False
# [CHEMBL5081938] CID=139360473 | Peptide=False
# [CHEMBL5081939] CID=139503406 | Peptide=False
# [CHEMBL5081940] CID=163249314 | Peptide=False
# [CHEMBL5081942] CID=139360802 | Peptide=False
# [CHEMBL5081944] CID=135385343 | Peptide=False
# [CHEMBL5081945] CID=68982770 | Peptide=False
# [CHEMBL5081948] CID=166629543 | Peptide=False
# [CHEMBL5081955] CID=156782568 | Peptide=False
# [CHEMBL5081956] CID=138393371 | Peptide=False
# [CHEMBL5081957] CID=166630484 | Peptide=False
# [CHEMBL5081958] CID=155781346 | Peptide=False
# [CHEMBL5081961] CID=147173428 | Peptide=False
# [CHEMBL5081963] CID=166630487 | Peptide=False
# Processing batch 21 of 1864...
# [CHEMBL5081964] CID=166630488 | Peptide=False
# [CHEMBL5081973] CID=166627342 | Peptide=False
# [CHEMBL5081971] CID=163215449 | Peptide=False
# [CHEMBL5081974] CID=156327072 | Peptide=False
# [CHEMBL5081975] CID=11332190 | Peptide=True
# [CHEMBL5081977] CID=166627343 | Peptide=False
# [CHEMBL5081978] CID=166627344 | Peptide=False
# [CHEMBL5081980] CID=166627345 | Peptide=False
# [CHEMBL5081982] CID=156898683 | Peptide=False
# [CHEMBL5081983] CID=166627347 | Peptide=False
# [CHEMBL5081986] CID=156899010 | Peptide=False
# [CHEMBL5081988] CID=166627893 | Peptide=False
# [CHEMBL5081989] CID=139375551 | Peptide=False
# [CHEMBL5081990] CID=166039044 | Peptide=False
# [CHEMBL5081993] CID=166627895 | Peptide=True
# [CHEMBL5081995] CID=166627896 | Peptide=False
# [CHEMBL5081996] CID=166627897 | Peptide=False
# [CHEMBL5082003] CID=166627902 | Peptide=False
# [CHEMBL5082005] CID=166627903 | Peptide=False
# [CHEMBL5082006] CID=166627904 | Peptide=False
# [CHEMBL5082007] CID=156304108 | Peptide=False
# [CHEMBL5082008] CID=139372631 | Peptide=False
# [CHEMBL5082011] CID=166627906 | Peptide=False
# [CHEMBL5082012] CID=166627907 | Peptide=False
# [CHEMBL5082014] CID=166627908 | Peptide=False
# Processing batch 22 of 1864...
# [CHEMBL5082020] CID=139370581 | Peptide=False
# [CHEMBL5082028] CID=166008570 | Peptide=False
# [CHEMBL5082023] CID=156129507 | Peptide=False
# [CHEMBL5082025] CID=137365545 | Peptide=False
# [CHEMBL5082029] CID=166628605 | Peptide=False
# [CHEMBL5082030] CID=166628606 | Peptide=False
# [CHEMBL5082031] CID=126539128 | Peptide=False
# [CHEMBL5082033] CID=139360487 | Peptide=False
# [CHEMBL5082037] CID=166629546 | Peptide=False
# [CHEMBL5082039] CID=166629548 | Peptide=False
# [CHEMBL5082042] CID=166629550 | Peptide=False
# [CHEMBL5082044] CID=166629551 | Peptide=False
# [CHEMBL5082048] CID=166629553 | Peptide=False
# [CHEMBL5082049] CID=153625420 | Peptide=False
# [CHEMBL5082050] CID=156304010 | Peptide=False
# [CHEMBL5082056] CID=139388865 | Peptide=False
# [CHEMBL5082059] CID=155781012 | Peptide=False
# [CHEMBL5082061] CID=156898678 | Peptide=False
# [CHEMBL5082066] CID=166630493 | Peptide=False
# [CHEMBL5082067] CID=156587341 | Peptide=False
# [CHEMBL5082068] CID=166630494 | Peptide=False
# [CHEMBL5082071] CID=166630497 | Peptide=False
# [CHEMBL5082069] CID=166630495 | Peptide=False
# [CHEMBL5082074] CID=166630499 | Peptide=False
# [CHEMBL5082076] CID=137365931 | Peptide=False
# Processing batch 23 of 1864...
# [CHEMBL5082085] CID=166627911 | Peptide=True[CHEMBL5082083] CID=156304152 | Peptide=False
#
# [CHEMBL5082084] CID=156898573 | Peptide=False
# [CHEMBL5082079] CID=153620070 | Peptide=False
# [CHEMBL5082095] CID=155780817 | Peptide=False
# [CHEMBL5082103] CID=166008681 | Peptide=False
# [CHEMBL5082109] CID=166628608 | Peptide=False
# [CHEMBL5082106] CID=166628380 | Peptide=False
# [CHEMBL5082110] CID=139360539 | Peptide=False
# [CHEMBL5082113] CID=166628611 | Peptide=False
# [CHEMBL5082124] CID=142588372 | Peptide=False
# [CHEMBL5082127] CID=153625485 | Peptide=False
# [CHEMBL5082131] CID=118110608 | Peptide=False
# [CHEMBL5082132] CID=166629303 | Peptide=False
# [CHEMBL5082134] CID=166629555 | Peptide=True
# [CHEMBL5082136] CID=164540797 | Peptide=False
# [CHEMBL5082138] CID=132261079 | Peptide=False
# [CHEMBL5082142] CID=166629813 | Peptide=False
# [CHEMBL5082144] CID=139529670 | Peptide=False
# [CHEMBL5082145] CID=137549337 | Peptide=False
# [CHEMBL5082149] CID=166629816 | Peptide=False
# [CHEMBL5082151] CID=106335411 | Peptide=False
# [CHEMBL5082153] CID=122515195 | Peptide=False
# [CHEMBL5082154] CID=166630235 | Peptide=False
# [CHEMBL5082155] CID=166630236 | Peptide=False
# Processing batch 24 of 1864...
# [CHEMBL5082168] CID=156898679 | Peptide=False
# [CHEMBL5082166] CID=132254541 | Peptide=False
# [CHEMBL5082165] CID=3048549 | Peptide=False
# [CHEMBL5082167] CID=142527981 | Peptide=False
# [CHEMBL5082173] CID=166630501 | Peptide=False
# [CHEMBL5082175] CID=166630503 | Peptide=False
# [CHEMBL5082177] CID=166630505 | Peptide=False
# [CHEMBL5082178] CID=155781447 | Peptide=False
# [CHEMBL5082182] CID=163323748 | Peptide=False
# [CHEMBL5082184] CID=166630510 | Peptide=False
# [CHEMBL5082193] CID=166628382 | Peptide=False
# [CHEMBL5082195] CID=146676947 | Peptide=False
# [CHEMBL5082198] CID=166628386 | Peptide=False
# [CHEMBL5082201] CID=156874359 | Peptide=False
# [CHEMBL5082202] CID=154609160 | Peptide=False
# [CHEMBL5082205] CID=166628389 | Peptide=False
# [CHEMBL5082208] CID=139361151 | Peptide=False
# [CHEMBL5082211] CID=166628826 | Peptide=False
# [CHEMBL5082214] CID=162763978 | Peptide=False
# [CHEMBL5082220] CID=163914476 | Peptide=False
# [CHEMBL5082221] CID=139360828 | Peptide=False
# [CHEMBL5082225] CID=166628832 | Peptide=False
# [CHEMBL5082226] CID=164703389 | Peptide=False
# [CHEMBL5082229] CID=135234638 | Peptide=False
# [CHEMBL5082230] CID=166629558 | Peptide=False
# Processing batch 25 of 1864...
# [CHEMBL5082240] CID=166627913 | Peptide=False
# [CHEMBL5082237] CID=139375783 | Peptide=False
# [CHEMBL5082241] CID=154942405 | Peptide=False
# [CHEMBL5082235] CID=147970687 | Peptide=False
# [CHEMBL5082243] CID=166627915 | Peptide=False
# [CHEMBL5082245] CID=166627916 | Peptide=False
# [CHEMBL5082247] CID=132260651 | Peptide=False
# [CHEMBL5082248] CID=166627917 | Peptide=False
# [CHEMBL5082250] CID=163196365 | Peptide=False
# [CHEMBL5082252] CID=166627920 | Peptide=False
# [CHEMBL5082256] CID=154958335 | Peptide=False
# [CHEMBL5082257] CID=166628391 | Peptide=False
# [CHEMBL5082258] CID=166628392 | Peptide=False
# [CHEMBL5082261] CID=53472335 | Peptide=False
# [CHEMBL5082264] CID=164703390 | Peptide=False
# [CHEMBL5082267] CID=166628836 | Peptide=False
# [CHEMBL5082268] CID=166628837 | Peptide=False
# [CHEMBL5082270] CID=166628839 | Peptide=False
# [CHEMBL5082271] CID=156326980 | Peptide=False
# [CHEMBL5082272] CID=166628840 | Peptide=False
# [CHEMBL5082273] CID=166628841 | Peptide=False
# [CHEMBL5082275] CID=137365704 | Peptide=False
# [CHEMBL5082278] CID=156898581 | Peptide=False
# [CHEMBL5082279] CID=166629117 | Peptide=False
# [CHEMBL5082280] CID=155781479 | Peptide=False
# Processing batch 26 of 1864...
# [CHEMBL5082291] CID=166629306 | Peptide=False[CHEMBL5082287] CID=166629120 | Peptide=False
#
# [CHEMBL5082290] CID=166629305 | Peptide=True
# [CHEMBL5082292] CID=166629561 | Peptide=True
# [CHEMBL5082294] CID=162526532 | Peptide=False
# [CHEMBL5082295] CID=139360491 | Peptide=False
# [CHEMBL5082298] CID=166629564 | Peptide=False
# [CHEMBL5082299] CID=134218433 | Peptide=False
# [CHEMBL5082304] CID=155781309 | Peptide=False
# [CHEMBL5082306] CID=166629567 | Peptide=False
# [CHEMBL5082305] CID=134218649 | Peptide=False
# [CHEMBL5082310] CID=166629819 | Peptide=False
# [CHEMBL5082312] CID=166629820 | Peptide=False
# [CHEMBL5082317] CID=155781187 | Peptide=False
# [CHEMBL5082319] CID=166628395 | Peptide=False
# [CHEMBL5082321] CID=118111314 | Peptide=False
# [CHEMBL5082323] CID=118286035 | Peptide=False
# [CHEMBL5082327] CID=166628616 | Peptide=False
# [CHEMBL5082328] CID=166628617 | Peptide=False
# [CHEMBL5082329] CID=156898975 | Peptide=False
# [CHEMBL5082333] CID=135230883 | Peptide=False
# [CHEMBL5082334] CID=166628843 | Peptide=False
# [CHEMBL5082336] CID=86268374 | Peptide=False
# [CHEMBL5082340] CID=156303963 | Peptide=False
# [CHEMBL5082342] CID=156304155 | Peptide=False
# Processing batch 27 of 1864...
# [CHEMBL5082347] CID=166629124 | Peptide=False
# [CHEMBL5082345] CID=166629122 | Peptide=False
# [CHEMBL5082343] CID=156898561 | Peptide=False
# [CHEMBL5082350] CID=166629307 | Peptide=False
# [CHEMBL5082351] CID=166070114 | Peptide=False
# [CHEMBL5082354] CID=156087785 | Peptide=False
# [CHEMBL5082356] CID=156612913 | Peptide=False
# [CHEMBL5082357] CID=166629310 | Peptide=False
# [CHEMBL5082360] CID=166629312 | Peptide=False
# [CHEMBL5082362] CID=153528600 | Peptide=False
# [CHEMBL5082361] CID=164866521 | Peptide=False
# [CHEMBL5082364] CID=164879165 | Peptide=False
# [CHEMBL5082365] CID=139349882 | Peptide=False
# [CHEMBL5082368] CID=156304146 | Peptide=False
# [CHEMBL5082370] CID=156304078 | Peptide=False
# [CHEMBL5082378] CID=162426827 | Peptide=False
# [CHEMBL5082380] CID=154632901 | Peptide=False
# [CHEMBL5082381] CID=156304060 | Peptide=False
# [CHEMBL5082385] CID=2727598 | Peptide=False
# [CHEMBL5082386] CID=155464472 | Peptide=False
# [CHEMBL5082387] CID=156304058 | Peptide=False
# [CHEMBL5082388] CID=166629569 | Peptide=False
# [CHEMBL5082391] CID=156151694 | Peptide=False
# [CHEMBL5082392] CID=166628405 | Peptide=False
# [CHEMBL5082394] CID=162691958 | Peptide=False
# Processing batch 28 of 1864...
# [CHEMBL5082395] CID=155797808 | Peptide=False
# [CHEMBL5082404] CID=163322219 | Peptide=False
# [CHEMBL5082396] CID=155144633 | Peptide=False
# [CHEMBL5082399] CID=166628407 | Peptide=False
# [CHEMBL5082406] CID=166628410 | Peptide=False
# [CHEMBL5082408] CID=166628412 | Peptide=False
# [CHEMBL5082412] CID=139350912 | Peptide=False
# [CHEMBL5082413] CID=166628415 | Peptide=False
# [CHEMBL5082415] CID=153625428 | Peptide=False
# [CHEMBL5082416] CID=141522689 | Peptide=False
# [CHEMBL5082421] CID=139360840 | Peptide=False
# [CHEMBL5082422] CID=166628419 | Peptide=False
# [CHEMBL5082423] CID=138607165 | Peptide=False
# [CHEMBL5082427] CID=166628422 | Peptide=False
# [CHEMBL5082430] CID=166008560 | Peptide=False
# [CHEMBL5082428] CID=166628423 | Peptide=False
# [CHEMBL5082434] CID=155011462 | Peptide=False
# [CHEMBL5082436] CID=166627781 | Peptide=False
# [CHEMBL5082438] CID=132254984 | Peptide=False
# [CHEMBL5082440] CID=166628201 | Peptide=False
# [CHEMBL5082441] CID=166628202 | Peptide=False
# [CHEMBL5082443] CID=166628203 | Peptide=True
# [CHEMBL5082444] CID=155780830 | Peptide=False
# [CHEMBL5082451] CID=147502230 | Peptide=False
# [CHEMBL5082447] CID=154741374 | Peptide=False
# Processing batch 29 of 1864...
# [CHEMBL5082452] CID=155781101 | Peptide=False
# [CHEMBL5082457] CID=137270975 | Peptide=False
# [CHEMBL5082456] CID=135336012 | Peptide=False
# [CHEMBL5082454] CID=134214670 | Peptide=False
# [CHEMBL5082458] CID=166628619 | Peptide=False
# [CHEMBL5082460] CID=162773104 | Peptide=False
# [CHEMBL5082464] CID=121354301 | Peptide=False
# [CHEMBL5082465] CID=166628622 | Peptide=False
# [CHEMBL5082466] CID=32043730 | Peptide=False
# [CHEMBL5082467] CID=137365619 | Peptide=False
# [CHEMBL5082470] CID=156898600 | Peptide=False
# [CHEMBL5082471] CID=166628624 | Peptide=False
# [CHEMBL5082474] CID=166628626 | Peptide=False[CHEMBL5082472] CID=166628625 | Peptide=False
#
# [CHEMBL5082481] CID=166628631 | Peptide=False
# [CHEMBL5082482] CID=155464626 | Peptide=False
# [CHEMBL5082483] CID=166627783 | Peptide=False
# [CHEMBL5082486] CID=155937517 | Peptide=False
# [CHEMBL5082487] CID=147586960 | Peptide=False
# [CHEMBL5082492] CID=134218777 | Peptide=False
# [CHEMBL5082493] CID=166628210 | Peptide=False
# [CHEMBL5082496] CID=137365618 | Peptide=False
# [CHEMBL5082500] CID=166628212 | Peptide=False
# [CHEMBL5082501] CID=166628213 | Peptide=False
# [CHEMBL5082503] CID=156815719 | Peptide=False
# Processing batch 30 of 1864...
# [CHEMBL5082511] CID=166628435 | Peptide=False
# [CHEMBL5082510] CID=153625383 | Peptide=False
# [CHEMBL5082514] CID=153528592 | Peptide=False
# [CHEMBL5082508] CID=155464532 | Peptide=False
# [CHEMBL5082516] CID=166628634 | Peptide=False
# [CHEMBL5082518] CID=166628635 | Peptide=False
# [CHEMBL5082521] CID=166628636 | Peptide=False
# [CHEMBL5082520] CID=156898551 | Peptide=False
# [CHEMBL5082522] CID=166628637 | Peptide=False
# [CHEMBL5082524] CID=166628639 | Peptide=False
# [CHEMBL5082525] CID=146282394 | Peptide=False
# [CHEMBL5082528] CID=163215431 | Peptide=False
# [CHEMBL5082529] CID=166627785 | Peptide=False
# [CHEMBL5082530] CID=166627786 | Peptide=True
# [CHEMBL5082540] CID=134177775 | Peptide=False
# [CHEMBL5082541] CID=166628439 | Peptide=False
# [CHEMBL5082544] CID=166628442 | Peptide=False
# [CHEMBL5082550] CID=147049210 | Peptide=False
# [CHEMBL5082551] CID=166628218 | Peptide=True
# [CHEMBL5082554] CID=166628640 | Peptide=False
# [CHEMBL5082556] CID=151929932 | Peptide=False
# [CHEMBL5082559] CID=141743417 | Peptide=False
# [CHEMBL5082560] CID=166628644 | Peptide=False
# [CHEMBL5082562] CID=156494843 | Peptide=False
# [CHEMBL5082563] CID=156730855 | Peptide=False
# Processing batch 31 of 1864...
# [CHEMBL5082566] CID=166628447 | Peptide=False
# [CHEMBL5082568] CID=137365737 | Peptide=False
# [CHEMBL5082564] CID=73336294 | Peptide=False
# [CHEMBL5082569] CID=166628448 | Peptide=False
# [CHEMBL5082573] CID=146536737 | Peptide=False
# [CHEMBL5082574] CID=155781380 | Peptide=False
# [CHEMBL5082577] CID=149934848 | Peptide=False
# [CHEMBL5082582] CID=166628645 | Peptide=True
# [CHEMBL5082584] CID=145361255 | Peptide=False
# [CHEMBL5082586] CID=146345948 | Peptide=False
# [CHEMBL5082587] CID=166628849 | Peptide=False
# [CHEMBL5082590] CID=162351819 | Peptide=False
# [CHEMBL5082594] CID=148308203 | Peptide=False
# [CHEMBL5082598] CID=151311438 | Peptide=False
# [CHEMBL5082602] CID=166628648 | Peptide=False
# [CHEMBL5082604] CID=86268371 | Peptide=False
# [CHEMBL5082606] CID=156151321 | Peptide=False
# [CHEMBL5082613] CID=166628219 | Peptide=False
# [CHEMBL5082614] CID=162520326 | Peptide=False
# [CHEMBL5082615] CID=132256194 | Peptide=False
# [CHEMBL5082618] CID=166628650 | Peptide=False
# [CHEMBL5082623] CID=166628652 | Peptide=False
# [CHEMBL5082628] CID=166629127 | Peptide=False
# [CHEMBL5082636] CID=154609164 | Peptide=False
# [CHEMBL5082631] CID=166627995 | Peptide=False
# Processing batch 32 of 1864...
# [CHEMBL5082644] CID=166629132 | Peptide=False
# [CHEMBL5082646] CID=166629133 | Peptide=False
# [CHEMBL5082645] CID=139360956 | Peptide=False
# [CHEMBL5082643] CID=108868700 | Peptide=False
# [CHEMBL5082649] CID=166629135 | Peptide=False
# [CHEMBL5082650] CID=166629136 | Peptide=False
# [CHEMBL5082660] CID=118450657 | Peptide=False
# [CHEMBL5082661] CID=44768892 | Peptide=False
# [CHEMBL5082663] CID=166629139 | Peptide=False
# [CHEMBL5082666] CID=163322274 | Peptide=False
# [CHEMBL5082665] CID=130310087 | Peptide=False
# [CHEMBL5082668] CID=166629141 | Peptide=False
# [CHEMBL5082669] CID=133059988 | Peptide=False
# [CHEMBL5082671] CID=166629143 | Peptide=False
# [CHEMBL5082678] CID=24868196 | Peptide=True
# [CHEMBL5082680] CID=137365841 | Peptide=False
# [CHEMBL5082681] CID=166629324 | Peptide=False
# [CHEMBL5082682] CID=146293670 | Peptide=False
# [CHEMBL5082685] CID=156770697 | Peptide=False
# [CHEMBL5082686] CID=166629326 | Peptide=True
# [CHEMBL5082689] CID=164540976 | Peptide=False
# [CHEMBL5082690] CID=154609161 | Peptide=False
# [CHEMBL5082691] CID=166629328 | Peptide=False
# [CHEMBL5082692] CID=166628220 | Peptide=False
# [CHEMBL5082693] CID=166628221 | Peptide=False
# Processing batch 33 of 1864...
# [CHEMBL5082697] CID=166629570 | Peptide=False
# [CHEMBL5082696] CID=166629329 | Peptide=False
# [CHEMBL5082695] CID=139547658 | Peptide=False
# [CHEMBL5082694] CID=166628222 | Peptide=True
# [CHEMBL5082698] CID=134218762 | Peptide=False
# [CHEMBL5082702] CID=149237533 | Peptide=False
# [CHEMBL5082701] CID=139580322 | Peptide=False
# [CHEMBL5082704] CID=146282481 | Peptide=False
# [CHEMBL5082706] CID=134218767 | Peptide=False
# [CHEMBL5082707] CID=164866706 | Peptide=False
# [CHEMBL5082708] CID=166628457 | Peptide=False
# [CHEMBL5082709] CID=166628458 | Peptide=True
# [CHEMBL5082711] CID=13023375 | Peptide=False
# [CHEMBL5082712] CID=166628858 | Peptide=True
# [CHEMBL5082714] CID=166628860 | Peptide=False
# [CHEMBL5082720] CID=139361007 | Peptide=False
# [CHEMBL5082722] CID=139370622 | Peptide=False
# [CHEMBL5082724] CID=162679329 | Peptide=False
# [CHEMBL5082726] CID=137402762 | Peptide=False
# [CHEMBL5082727] CID=157976432 | Peptide=False
# [CHEMBL5082728] CID=156303957 | Peptide=False
# [CHEMBL5082729] CID=166628867 | Peptide=False[CHEMBL5082732] CID=163196283 | Peptide=False
#
# [CHEMBL5082733] CID=816623 | Peptide=False
# [CHEMBL5082734] CID=166628460 | Peptide=False
# Processing batch 34 of 1864...
# [CHEMBL5082738] CID=166629147 | Peptide=False
# [CHEMBL5082737] CID=153035959 | Peptide=False
# [CHEMBL5082735] CID=166629145 | Peptide=False
# [CHEMBL5082739] CID=166629148 | Peptide=False
# [CHEMBL5082740] CID=166629149 | Peptide=False
# [CHEMBL5082742] CID=156816088 | Peptide=False
# [CHEMBL5082744] CID=166629152 | Peptide=False
# [CHEMBL5082746] CID=155464242 | Peptide=False
# [CHEMBL5082748] CID=166628653 | Peptide=False
# [CHEMBL5082754] CID=156816206 | Peptide=False
# [CHEMBL5082755] CID=146205069 | Peptide=False
# [CHEMBL5082758] CID=154644712 | Peptide=False
# [CHEMBL5082760] CID=89532776 | Peptide=False
# [CHEMBL5082761] CID=166629330 | Peptide=False
# [CHEMBL5082762] CID=139524511 | Peptide=False
# [CHEMBL5082773] CID=166628660 | Peptide=False
# [CHEMBL5082777] CID=156815856 | Peptide=False
# [CHEMBL5082781] CID=166629336 | Peptide=False
# [CHEMBL5082783] CID=166629337 | Peptide=False
# [CHEMBL5082785] CID=166629338 | Peptide=False
# [CHEMBL5082786] CID=163184874 | Peptide=False
# [CHEMBL5082793] CID=163198556 | Peptide=False
# [CHEMBL5082796] CID=166629341 | Peptide=False
# [CHEMBL5082803] CID=155464904 | Peptide=False
# [CHEMBL5082805] CID=139360947 | Peptide=False
# Processing batch 35 of 1864...
# [CHEMBL5082810] CID=137365764 | Peptide=False
# [CHEMBL5082818] CID=166629577 | Peptide=False
# [CHEMBL5082813] CID=134218548 | Peptide=False
# [CHEMBL5082809] CID=139361049 | Peptide=False
# [CHEMBL5082819] CID=166629578 | Peptide=False
# [CHEMBL5082821] CID=166629580 | Peptide=False
# [CHEMBL5082824] CID=162679330 | Peptide=False
# [CHEMBL5082826] CID=156898772 | Peptide=False
# [CHEMBL5082827] CID=155781183 | Peptide=False
# [CHEMBL5082830] CID=155184063 | Peptide=False
# [CHEMBL5082831] CID=118450691 | Peptide=False
# [CHEMBL5082835] CID=139375502 | Peptide=False
# [CHEMBL5082836] CID=166629585 | Peptide=False
# [CHEMBL5082837] CID=165378907 | Peptide=False
# [CHEMBL5082839] CID=166629587 | Peptide=False
# [CHEMBL5082842] CID=155780785 | Peptide=False
# [CHEMBL5082843] CID=166628869 | Peptide=False
# [CHEMBL5082844] CID=166628870 | Peptide=False
# [CHEMBL5082845] CID=156304086 | Peptide=False
# [CHEMBL5082848] CID=166628871 | Peptide=False
# [CHEMBL5082850] CID=166628873 | Peptide=False
# [CHEMBL5082851] CID=139360902 | Peptide=False
# [CHEMBL5082852] CID=153625495 | Peptide=False
# [CHEMBL5082853] CID=156326991 | Peptide=False
# [CHEMBL5082857] CID=155352283 | Peptide=False
# Processing batch 36 of 1864...
# [CHEMBL5082871] CID=154957721 | Peptide=False
# [CHEMBL5082876] CID=166628878 | Peptide=False
# [CHEMBL5082858] CID=2430342 | Peptide=False
# [CHEMBL5082865] CID=166629593 | Peptide=False
# [CHEMBL5082877] CID=137365645 | Peptide=False
# [CHEMBL5082879] CID=166628879 | Peptide=False
# [CHEMBL5082880] CID=166628880 | Peptide=False
# [CHEMBL5082881] CID=164866489 | Peptide=False
# [CHEMBL5082884] CID=166628883 | Peptide=False
# [CHEMBL5082886] CID=156898673 | Peptide=False
# [CHEMBL5082888] CID=156898868 | Peptide=False
# [CHEMBL5082889] CID=139361189 | Peptide=False
# [CHEMBL5082891] CID=134218764 | Peptide=False
# [CHEMBL5082893] CID=118420039 | Peptide=False
# [CHEMBL5082892] CID=166629348 | Peptide=True
# [CHEMBL5082895] CID=166629350 | Peptide=False
# [CHEMBL5082896] CID=156815738 | Peptide=False
# [CHEMBL5082897] CID=139360641 | Peptide=False
# [CHEMBL5082899] CID=166629351 | Peptide=False
# [CHEMBL5082903] CID=166629599 | Peptide=False
# [CHEMBL5082904] CID=132254747 | Peptide=False
# [CHEMBL5082905] CID=86689090 | Peptide=False
# [CHEMBL5082908] CID=139503561 | Peptide=False
# [CHEMBL5082911] CID=155464646 | Peptide=False
# [CHEMBL5082920] CID=166628891 | Peptide=False
# Processing batch 37 of 1864...
# [CHEMBL5082927] CID=139375386 | Peptide=False
# [CHEMBL5082926] CID=162785107 | Peptide=False
# [CHEMBL5082922] CID=149046473 | Peptide=False
# [CHEMBL5082923] CID=154632934 | Peptide=False
# [CHEMBL5082928] CID=166628893 | Peptide=False
# [CHEMBL5082929] CID=166628894 | Peptide=False
# [CHEMBL5082931] CID=166628896 | Peptide=False
# [CHEMBL5082933] CID=118429827 | Peptide=False
# [CHEMBL5082935] CID=156885803 | Peptide=False
# [CHEMBL5082939] CID=166629356 | Peptide=False
# [CHEMBL5082940] CID=166629357 | Peptide=False
# [CHEMBL5082941] CID=18008433 | Peptide=False
# [CHEMBL5082946] CID=166629360 | Peptide=False
# [CHEMBL5082947] CID=166629361 | Peptide=False
# [CHEMBL5082948] CID=155464350 | Peptide=False
# [CHEMBL5082949] CID=166629362 | Peptide=False
# [CHEMBL5082952] CID=166629600 | Peptide=False
# [CHEMBL5082955] CID=166629602 | Peptide=False
# [CHEMBL5082956] CID=118285608 | Peptide=False
# [CHEMBL5082959] CID=166629604 | Peptide=False
# [CHEMBL5082960] CID=166629605 | Peptide=False
# [CHEMBL5082962] CID=913339 | Peptide=False
# [CHEMBL5082963] CID=139503426 | Peptide=False
# [CHEMBL5082964] CID=139503533 | Peptide=False
# [CHEMBL5082968] CID=153625296 | Peptide=False
# Processing batch 38 of 1864...
# [CHEMBL5082973] CID=166629609 | Peptide=False
# [CHEMBL5082977] CID=28951450 | Peptide=False
# [CHEMBL5082978] CID=166587997 | Peptide=False
# [CHEMBL5082969] CID=162396661 | Peptide=False
# [CHEMBL5082980] CID=165379224 | Peptide=False
# [CHEMBL5082981] CID=166629822 | Peptide=True
# [CHEMBL5082983] CID=155801537 | Peptide=False
# [CHEMBL5082986] CID=166628899 | Peptide=False
# [CHEMBL5082988] CID=139346938 | Peptide=False
# [CHEMBL5082989] CID=166628901 | Peptide=False
# [CHEMBL5082990] CID=146282508 | Peptide=False
# [CHEMBL5082992] CID=166628903 | Peptide=False
# [CHEMBL5082993] CID=166628904 | Peptide=False
# [CHEMBL5082994] CID=166628905 | Peptide=False
# [CHEMBL5082996] CID=136862088 | Peptide=False
# [CHEMBL5083001] CID=153550931 | Peptide=False
# [CHEMBL5083002] CID=166628907 | Peptide=False
# [CHEMBL5083006] CID=166628910 | Peptide=False
# [CHEMBL5083009] CID=166629612 | Peptide=True
# [CHEMBL5083010] CID=166629613 | Peptide=False
# [CHEMBL5083012] CID=156129962 | Peptide=False
# [CHEMBL5083014] CID=166629824 | Peptide=False
# [CHEMBL5083015] CID=162351806 | Peptide=False
# [CHEMBL5083016] CID=166629825 | Peptide=False
# [CHEMBL5083020] CID=156672582 | Peptide=False
# Processing batch 39 of 1864...
# [CHEMBL5083021] CID=139350327 | Peptide=False
# [CHEMBL5083027] CID=11573309 | Peptide=False
# [CHEMBL5083025] CID=166629830 | Peptide=False
# [CHEMBL5083023] CID=166629828 | Peptide=False
# [CHEMBL5083028] CID=166629155 | Peptide=False
# [CHEMBL5083031] CID=155781282 | Peptide=False
# [CHEMBL5083033] CID=166629363 | Peptide=False
# [CHEMBL5083034] CID=166629364 | Peptide=False
# [CHEMBL5083035] CID=166629365 | Peptide=False
# [CHEMBL5083036] CID=138607174 | Peptide=False
# [CHEMBL5083037] CID=155336178 | Peptide=False
# [CHEMBL5083053] CID=155920136 | Peptide=False
# [CHEMBL5083054] CID=166629617 | Peptide=False
# [CHEMBL5083056] CID=137365698 | Peptide=False
# [CHEMBL5083058] CID=108276331 | Peptide=False
# [CHEMBL5083059] CID=166629832 | Peptide=False
# [CHEMBL5083060] CID=166008562 | Peptide=False
# [CHEMBL5083064] CID=139349919 | Peptide=False
# [CHEMBL5083068] CID=166629836 | Peptide=False
# [CHEMBL5083072] CID=139360799 | Peptide=False
# [CHEMBL5083073] CID=166630042 | Peptide=False
# [CHEMBL5083075] CID=155781223 | Peptide=False
# [CHEMBL5083076] CID=166630044 | Peptide=False
# [CHEMBL5083079] CID=155464899 | Peptide=False
# [CHEMBL5083080] CID=149487712 | Peptide=False
# Processing batch 40 of 1864...
# [CHEMBL5083088] CID=166629375 | Peptide=True
# [CHEMBL5083082] CID=156155468 | Peptide=False
# [CHEMBL5083093] CID=155464383 | Peptide=False
# [CHEMBL5083087] CID=155585752 | Peptide=False
# [CHEMBL5083094] CID=166629618 | Peptide=False[CHEMBL5083095] CID=166629619 | Peptide=False
#
# [CHEMBL5083108] CID=166629626 | Peptide=False
# [CHEMBL5083102] CID=166629622 | Peptide=False
# [CHEMBL5083113] CID=166629628 | Peptide=False
# [CHEMBL5083114] CID=139350286 | Peptide=False
# [CHEMBL5083117] CID=166629631 | Peptide=False
# [CHEMBL5083118] CID=166629632 | Peptide=False
# [CHEMBL5083121] CID=156304143 | Peptide=False
# [CHEMBL5083122] CID=166629634 | Peptide=False
# [CHEMBL5083123] CID=141738552 | Peptide=False
# [CHEMBL5083125] CID=145900912 | Peptide=False
# [CHEMBL5083128] CID=146291751 | Peptide=False
# [CHEMBL5083131] CID=156433438 | Peptide=False
# [CHEMBL5083134] CID=137365870 | Peptide=False
# [CHEMBL5083135] CID=166630048 | Peptide=False
# [CHEMBL5083136] CID=166630049 | Peptide=False
# [CHEMBL5083138] CID=166629157 | Peptide=True
# [CHEMBL5083139] CID=146366363 | Peptide=False
# [CHEMBL5083140] CID=166629158 | Peptide=False
# [CHEMBL5083143] CID=164946801 | Peptide=False
# Processing batch 41 of 1864...
# [CHEMBL5083149] CID=156059571 | Peptide=False
# [CHEMBL5083157] CID=166629378 | Peptide=False
# [CHEMBL5083150] CID=166629162 | Peptide=False
# [CHEMBL5083146] CID=166629161 | Peptide=False
# [CHEMBL5083158] CID=166629639 | Peptide=True
# [CHEMBL5083159] CID=166629640 | Peptide=False
# [CHEMBL5083162] CID=153625532 | Peptide=False
# [CHEMBL5083163] CID=134218787 | Peptide=False
# [CHEMBL5083165] CID=166629642 | Peptide=False
# [CHEMBL5083166] CID=3894686 | Peptide=False
# [CHEMBL5083168] CID=155464639 | Peptide=False[CHEMBL5083169] CID=156494905 | Peptide=False
#
# [CHEMBL5083172] CID=163215429 | Peptide=False
# [CHEMBL5083178] CID=148891388 | Peptide=False
# [CHEMBL5083183] CID=166629646 | Peptide=False
# [CHEMBL5083184] CID=6508737 | Peptide=False
# [CHEMBL5083185] CID=166629647 | Peptide=False
# [CHEMBL5083186] CID=166629648 | Peptide=False
# ...
# [CHEMBL5091165] CID=155780833 | Peptide=False
# [CHEMBL5091163] CID=166634063 | Peptide=False
# [CHEMBL5091168] CID=166634065 | Peptide=False
# [CHEMBL5091171] CID=134218903 | Peptide=False
# Processing batch 175 of 1864...
# [CHEMBL5091178] CID=166634383 | Peptide=False
# [CHEMBL5091175] CID=166634381 | Peptide=False
# [CHEMBL5091177] CID=139360324 | Peptide=False
# [CHEMBL5091174] CID=162719827 | Peptide=False
# [CHEMBL5091189] CID=153624882 | Peptide=False
# [CHEMBL5091192] CID=166635754 | Peptide=False
# [CHEMBL5091194] CID=166635756 | Peptide=False
# [CHEMBL5091200] CID=166635759 | Peptide=True
# [CHEMBL5091201] CID=134214651 | Peptide=False
# [CHEMBL5091205] CID=166635761 | Peptide=False
# [CHEMBL5091207] CID=166635762 | Peptide=False
# [CHEMBL5091208] CID=156130032 | Peptide=False
# [CHEMBL5091210] CID=166008604 | Peptide=False
# [CHEMBL5091212] CID=156898974 | Peptide=False
# [CHEMBL5091214] CID=146282413 | Peptide=False
# [CHEMBL5091215] CID=139360914 | Peptide=False
# [CHEMBL5091216] CID=162641712 | Peptide=False
# [CHEMBL5091222] CID=141738579 | Peptide=False
# [CHEMBL5091227] CID=146627517 | Peptide=False
# [CHEMBL5091229] CID=156885878 | Peptide=False
# [CHEMBL5091230] CID=166636108 | Peptide=False
# [CHEMBL5091232] CID=166636110 | Peptide=False
# [CHEMBL5091235] CID=155781099 | Peptide=False
# [CHEMBL5091236] CID=166636112 | Peptide=True
# [CHEMBL5091238] CID=162346766 | Peptide=False
# Processing batch 176 of 1864...
# [CHEMBL5091242] CID=156898864 | Peptide=False
# [CHEMBL5091243] CID=166636468 | Peptide=False
# [CHEMBL5091244] CID=164521255 | Peptide=False
# [CHEMBL5091241] CID=166636115 | Peptide=False
# [CHEMBL5091248] CID=153625446 | Peptide=False
# [CHEMBL5091245] CID=166636469 | Peptide=True
# [CHEMBL5091250] CID=156898978 | Peptide=False
# [CHEMBL5091256] CID=162763961 | Peptide=False
# [CHEMBL5091259] CID=156898952 | Peptide=False
# [CHEMBL5091262] CID=166631478 | Peptide=False
# [CHEMBL5091263] CID=156816341 | Peptide=False
# [CHEMBL5091269] CID=166631756 | Peptide=False
# [CHEMBL5091270] CID=166631757 | Peptide=False
# [CHEMBL5091273] CID=153625474 | Peptide=False
# [CHEMBL5091279] CID=156704966 | Peptide=False
# [CHEMBL5091281] CID=156704961 | Peptide=False
# [CHEMBL5091282] CID=166039032 | Peptide=False
# [CHEMBL5091290] CID=166632073 | Peptide=False
# [CHEMBL5091291] CID=166632074 | Peptide=False
# [CHEMBL5091294] CID=155781186 | Peptide=False
# [CHEMBL5091299] CID=166632078 | Peptide=False
# [CHEMBL5091301] CID=164521825 | Peptide=False
# [CHEMBL5091302] CID=165379144 | Peptide=False
# [CHEMBL5091303] CID=148334544 | Peptide=False
# [CHEMBL5091304] CID=149653033 | Peptide=False
# Processing batch 177 of 1864...
# [CHEMBL5091314] CID=155781026 | Peptide=False
# [CHEMBL5091315] CID=146447962 | Peptide=False
# [CHEMBL5091313] CID=156704958 | Peptide=False
# [CHEMBL5091308] CID=134218658 | Peptide=False
# [CHEMBL5091316] CID=166632413 | Peptide=False
# [CHEMBL5091323] CID=130292561 | Peptide=False
# [CHEMBL5091324] CID=136590564 | Peptide=False
# [CHEMBL5091326] CID=155491009 | Peptide=False
# [CHEMBL5091329] CID=155752908 | Peptide=False
# [CHEMBL5091333] CID=154022894 | Peptide=False
# [CHEMBL5091330] CID=166632732 | Peptide=False
# [CHEMBL5091334] CID=166633008 | Peptide=False
# [CHEMBL5091335] CID=166633009 | Peptide=False
# [CHEMBL5091338] CID=139529659 | Peptide=False
# [CHEMBL5091342] CID=72549135 | Peptide=False
# [CHEMBL5091344] CID=155926548 | Peptide=False
# [CHEMBL5091345] CID=139370133 | Peptide=False
# [CHEMBL5091352] CID=166633729 | Peptide=True
# [CHEMBL5091366] CID=134214760 | Peptide=False
# [CHEMBL5091368] CID=164879180 | Peptide=False
# [CHEMBL5091373] CID=166634384 | Peptide=False
# [CHEMBL5091374] CID=155797741 | Peptide=False
# [CHEMBL5091377] CID=130310147 | Peptide=False
# [CHEMBL5091378] CID=134177541 | Peptide=False
# [CHEMBL5091382] CID=139361148 | Peptide=False
# Processing batch 178 of 1864...
# [CHEMBL5091384] CID=163215446 | Peptide=False
# [CHEMBL5091385] CID=166634388 | Peptide=True
# [CHEMBL5091391] CID=166634392 | Peptide=False
# [CHEMBL5091383] CID=154957886 | Peptide=False
# [CHEMBL5091395] CID=166634691 | Peptide=False
# [CHEMBL5091398] CID=146671366 | Peptide=False
# [CHEMBL5091394] CID=166634393 | Peptide=False
# [CHEMBL5091393] CID=134218893 | Peptide=False
# [CHEMBL5091400] CID=166635081 | Peptide=False
# [CHEMBL5091399] CID=132256205 | Peptide=False
# [CHEMBL5091404] CID=134218620 | Peptide=False
# [CHEMBL5091406] CID=134218570 | Peptide=False
# [CHEMBL5091408] CID=139375527 | Peptide=False
# [CHEMBL5091410] CID=166635443 | Peptide=False
# [CHEMBL5091415] CID=166635447 | Peptide=False
# [CHEMBL5091418] CID=162763985 | Peptide=False
# [CHEMBL5091419] CID=166635450 | Peptide=False
# [CHEMBL5091421] CID=166635451 | Peptide=False
# [CHEMBL5091423] CID=166635453 | Peptide=False
# [CHEMBL5091427] CID=156898973 | Peptide=False
# [CHEMBL5091428] CID=148017788 | Peptide=False
# [CHEMBL5091431] CID=139349623 | Peptide=False
# [CHEMBL5091432] CID=148943618 | Peptide=False
# [CHEMBL5091435] CID=139349841 | Peptide=False
# [CHEMBL5091436] CID=155781057 | Peptide=False
# Processing batch 179 of 1864...
# [CHEMBL5091440] CID=139375613 | Peptide=False
# [CHEMBL5091437] CID=156704952 | Peptide=False
# [CHEMBL5091447] CID=166636118 | Peptide=False
# [CHEMBL5091438] CID=166635768 | Peptide=False
# [CHEMBL5091448] CID=3932625 | Peptide=False
# [CHEMBL5091450] CID=142588365 | Peptide=False
# [CHEMBL5091454] CID=156304156 | Peptide=False
# [CHEMBL5091456] CID=166636123 | Peptide=False
# [CHEMBL5091459] CID=164570054 | Peptide=False
# [CHEMBL5091461] CID=91801192 | Peptide=False
# [CHEMBL5091465] CID=166636472 | Peptide=False
# [CHEMBL5091468] CID=154609129 | Peptide=False
# [CHEMBL5091471] CID=166636476 | Peptide=False
# [CHEMBL5091473] CID=166636478 | Peptide=True
# [CHEMBL5091475] CID=164879193 | Peptide=False
# [CHEMBL5091476] CID=152291592 | Peptide=False
# [CHEMBL5091477] CID=155464723 | Peptide=False
# [CHEMBL5091484] CID=156898829 | Peptide=False
# [CHEMBL5091479] CID=53824422 | Peptide=False
# [CHEMBL5091486] CID=137365535 | Peptide=False
# [CHEMBL5091493] CID=153624821 | Peptide=False
# [CHEMBL5091495] CID=163196388 | Peptide=False
# [CHEMBL5091498] CID=166631768 | Peptide=False
# [CHEMBL5091500] CID=164585549 | Peptide=False
# [CHEMBL5091501] CID=162679539 | Peptide=False
# Processing batch 180 of 1864...
# [CHEMBL5091502] CID=166631769 | Peptide=False
# [CHEMBL5091510] CID=135336127 | Peptide=False
# [CHEMBL5091511] CID=166632080 | Peptide=False
# [CHEMBL5091508] CID=166631773 | Peptide=False
# [CHEMBL5091512] CID=156587339 | Peptide=False
# [CHEMBL5091513] CID=166632081 | Peptide=False
# [CHEMBL5091517] CID=146293794 | Peptide=False
# [CHEMBL5091519] CID=166632085 | Peptide=False
# [CHEMBL5091523] CID=166632087 | Peptide=False
# [CHEMBL5091524] CID=166632088 | Peptide=False
# [CHEMBL5091527] CID=166632090 | Peptide=False
# [CHEMBL5091526] CID=166632089 | Peptide=False
# [CHEMBL5091528] CID=156327791 | Peptide=False
# [CHEMBL5091529] CID=155752922 | Peptide=False
# [CHEMBL5091537] CID=166632419 | Peptide=False
# [CHEMBL5091538] CID=137549329 | Peptide=False
# [CHEMBL5091540] CID=124221791 | Peptide=False
# [CHEMBL5091543] CID=166632421 | Peptide=False
# [CHEMBL5091544] CID=166632422 | Peptide=False
# [CHEMBL5091545] CID=166632423 | Peptide=False
# [CHEMBL5091546] CID=147747499 | Peptide=False
# [CHEMBL5091548] CID=149451680 | Peptide=False
# [CHEMBL5091549] CID=156704949 | Peptide=False
# [CHEMBL5091550] CID=166632425 | Peptide=False
# [CHEMBL5091551] CID=166632426 | Peptide=False
# Processing batch 181 of 1864...
# [CHEMBL5091553] CID=166632734 | Peptide=False
# [CHEMBL5091555] CID=139360826 | Peptide=False
# [CHEMBL5091552] CID=166632733 | Peptide=False
# [CHEMBL5091556] CID=166632736 | Peptide=False
# [CHEMBL5091558] CID=166632737 | Peptide=False
# [CHEMBL5091559] CID=154961636 | Peptide=False
# [CHEMBL5091560] CID=166632738 | Peptide=True
# [CHEMBL5091568] CID=166633015 | Peptide=True
# [CHEMBL5091571] CID=147512881 | Peptide=False
# [CHEMBL5091573] CID=139360340 | Peptide=False
# [CHEMBL5091575] CID=151596090 | Peptide=False
# [CHEMBL5091576] CID=154609142 | Peptide=False
# [CHEMBL5091578] CID=155436631 | Peptide=False
# [CHEMBL5091579] CID=153625421 | Peptide=False
# [CHEMBL5091582] CID=145900911 | Peptide=False
# [CHEMBL5091583] CID=166633346 | Peptide=False
# [CHEMBL5091585] CID=162368296 | Peptide=False
# [CHEMBL5091589] CID=166633350 | Peptide=False
# [CHEMBL5091590] CID=166633351 | Peptide=False
# [CHEMBL5091591] CID=156599545 | Peptide=False
# [CHEMBL5091595] CID=155410759 | Peptide=False
# [CHEMBL5091597] CID=139350138 | Peptide=False
# [CHEMBL5091601] CID=137365951 | Peptide=False
# [CHEMBL5091603] CID=166633358 | Peptide=False
# [CHEMBL5091604] CID=166633359 | Peptide=False
# Processing batch 182 of 1864...
# [CHEMBL5091608] CID=166633734 | Peptide=False
# [CHEMBL5091605] CID=166633360 | Peptide=False
# [CHEMBL5091612] CID=166633736 | Peptide=False
# [CHEMBL5091611] CID=166633735 | Peptide=False
# [CHEMBL5091613] CID=155797796 | Peptide=False
# [CHEMBL5091617] CID=139375621 | Peptide=False
# [CHEMBL5091620] CID=156327047 | Peptide=False
# [CHEMBL5091618] CID=147377702 | Peptide=False
# [CHEMBL5091622] CID=166634076 | Peptide=False
# [CHEMBL5091623] CID=166634077 | Peptide=True
# [CHEMBL5091624] CID=139365305 | Peptide=False
# [CHEMBL5091627] CID=166634394 | Peptide=False
# [CHEMBL5091630] CID=156327030 | Peptide=False
# [CHEMBL5091638] CID=166634399 | Peptide=False
# [CHEMBL5091640] CID=166634401 | Peptide=False
# [CHEMBL5091641] CID=166634402 | Peptide=False
# [CHEMBL5091642] CID=166634403 | Peptide=False
# [CHEMBL5091644] CID=135335840 | Peptide=False
# [CHEMBL5091645] CID=166634405 | Peptide=False
# [CHEMBL5091647] CID=166634407 | Peptide=False
# [CHEMBL5091649] CID=156783260 | Peptide=False
# [CHEMBL5091650] CID=134214624 | Peptide=False
# [CHEMBL5091652] CID=166634410 | Peptide=False
# [CHEMBL5091654] CID=166634412 | Peptide=False
# [CHEMBL5091656] CID=164916964 | Peptide=False
# Processing batch 183 of 1864...
# [CHEMBL5091660] CID=166634417 | Peptide=False[CHEMBL5091661] CID=124221790 | Peptide=False
#
# [CHEMBL5091657] CID=166634414 | Peptide=False
# [CHEMBL5091659] CID=166634416 | Peptide=False
# [CHEMBL5091663] CID=163215428 | Peptide=False
# [CHEMBL5091669] CID=166634694 | Peptide=False
# [CHEMBL5091678] CID=166634698 | Peptide=False
# [CHEMBL5091679] CID=166635086 | Peptide=True
# [CHEMBL5091680] CID=166635087 | Peptide=False
# [CHEMBL5091682] CID=166635088 | Peptide=False
# [CHEMBL5091683] CID=166635089 | Peptide=False
# [CHEMBL5091688] CID=145900918 | Peptide=False
# [CHEMBL5091689] CID=166635092 | Peptide=False
# [CHEMBL5091690] CID=139347283 | Peptide=False
# [CHEMBL5091691] CID=155797740 | Peptide=False
# [CHEMBL5091693] CID=166635093 | Peptide=False
# [CHEMBL5091694] CID=166635094 | Peptide=False
# [CHEMBL5091695] CID=166635095 | Peptide=False
# [CHEMBL5091700] CID=166635099 | Peptide=False
# [CHEMBL5091696] CID=166635096 | Peptide=False
# [CHEMBL5091703] CID=166635457 | Peptide=False
# [CHEMBL5091709] CID=139360498 | Peptide=False
# [CHEMBL5091705] CID=166635458 | Peptide=False
# [CHEMBL5091710] CID=154957870 | Peptide=False
# [CHEMBL5091714] CID=166635771 | Peptide=False
# Processing batch 184 of 1864...
# [CHEMBL5091719] CID=155464909 | Peptide=False
# [CHEMBL5091732] CID=153625083 | Peptide=False
# [CHEMBL5091725] CID=166635778 | Peptide=False
# [CHEMBL5091721] CID=166635774 | Peptide=False
# [CHEMBL5091735] CID=166635783 | Peptide=False
# [CHEMBL5091737] CID=166635784 | Peptide=False
# [CHEMBL5091738] CID=139360850 | Peptide=False
# [CHEMBL5091739] CID=155184078 | Peptide=False
# [CHEMBL5091742] CID=139503411 | Peptide=False
# [CHEMBL5091754] CID=166636133 | Peptide=False
# [CHEMBL5091758] CID=27869099 | Peptide=False
# [CHEMBL5091763] CID=139375531 | Peptide=False
# [CHEMBL5091767] CID=137365583 | Peptide=False
# [CHEMBL5091766] CID=156898537 | Peptide=False
# [CHEMBL5091768] CID=166636486 | Peptide=False
# [CHEMBL5091774] CID=166631489 | Peptide=False
# [CHEMBL5091775] CID=166631490 | Peptide=False
# [CHEMBL5091777] CID=139350811 | Peptide=False
# [CHEMBL5091780] CID=166631493 | Peptide=False
# [CHEMBL5091783] CID=166631774 | Peptide=True
# [CHEMBL5091786] CID=166631776 | Peptide=False
# [CHEMBL5091787] CID=122662563 | Peptide=False
# [CHEMBL5091789] CID=141519552 | Peptide=False
# [CHEMBL5091795] CID=164866578 | Peptide=False
# [CHEMBL5091798] CID=166631783 | Peptide=False
# Processing batch 185 of 1864...
# [CHEMBL5091799] CID=156898570 | Peptide=False
# [CHEMBL5091801] CID=139360503 | Peptide=False
# [CHEMBL5091803] CID=166631785 | Peptide=False
# [CHEMBL5091804] CID=166631786 | Peptide=False
# [CHEMBL5091805] CID=166631787 | Peptide=False
# [CHEMBL5091807] CID=156898528 | Peptide=False
# [CHEMBL5091813] CID=166632428 | Peptide=False
# [CHEMBL5091817] CID=166632430 | Peptide=False
# [CHEMBL5091818] CID=162763942 | Peptide=False
# [CHEMBL5091819] CID=166632431 | Peptide=False
# [CHEMBL5091821] CID=166632739 | Peptide=True
# [CHEMBL5091823] CID=121295556 | Peptide=False
# [CHEMBL5091825] CID=141755881 | Peptide=False
# [CHEMBL5091826] CID=153534352 | Peptide=False
# [CHEMBL5091830] CID=156599554 | Peptide=False
# [CHEMBL5091835] CID=166633020 | Peptide=False
# [CHEMBL5091836] CID=155682824 | Peptide=False
# [CHEMBL5091839] CID=166633023 | Peptide=False
# [CHEMBL5091841] CID=155464329 | Peptide=False
# [CHEMBL5091842] CID=166633025 | Peptide=False
# [CHEMBL5091844] CID=134218862 | Peptide=False
# [CHEMBL5091846] CID=166633363 | Peptide=False
# [CHEMBL5091848] CID=166633365 | Peptide=False
# [CHEMBL5091850] CID=166633366 | Peptide=False
# [CHEMBL5091852] CID=139350481 | Peptide=False
# Processing batch 186 of 1864...
# [CHEMBL5091856] CID=166633369 | Peptide=False
# [CHEMBL5091855] CID=164703394 | Peptide=False
# [CHEMBL5091858] CID=166633740 | Peptide=False
# [CHEMBL5091860] CID=156899014 | Peptide=False
# [CHEMBL5091864] CID=130310197 | Peptide=False
# [CHEMBL5091868] CID=166633746 | Peptide=False
# [CHEMBL5091869] CID=162773101 | Peptide=False
# [CHEMBL5091870] CID=139375588 | Peptide=False
# [CHEMBL5091873] CID=155436539 | Peptide=False
# [CHEMBL5091875] CID=166634418 | Peptide=False
# [CHEMBL5091876] CID=166634699 | Peptide=False
# [CHEMBL5091877] CID=162462187 | Peptide=False
# [CHEMBL5091888] CID=163215437 | Peptide=False
# [CHEMBL5091890] CID=166634704 | Peptide=False
# [CHEMBL5091893] CID=166635102 | Peptide=False
# [CHEMBL5091894] CID=148454252 | Peptide=False
# [CHEMBL5091900] CID=166635104 | Peptide=False
# [CHEMBL5091902] CID=134218465 | Peptide=False
# [CHEMBL5091903] CID=164521268 | Peptide=False
# [CHEMBL5091907] CID=166635461 | Peptide=False
# [CHEMBL5091909] CID=166635463 | Peptide=False
# [CHEMBL5091910] CID=129080653 | Peptide=False
# [CHEMBL5091912] CID=166635464 | Peptide=False
# [CHEMBL5091915] CID=156388264 | Peptide=False
# [CHEMBL5091916] CID=2290331 | Peptide=False
# Processing batch 187 of 1864...
# [CHEMBL5091926] CID=148017787 | Peptide=False
# [CHEMBL5091924] CID=166635789 | Peptide=False
# [CHEMBL5091922] CID=146562891 | Peptide=False
# [CHEMBL5091918] CID=153560294 | Peptide=False
# [CHEMBL5091927] CID=166635791 | Peptide=False
# [CHEMBL5091929] CID=72950246 | Peptide=False
# [CHEMBL5091930] CID=156304104 | Peptide=False
# [CHEMBL5091932] CID=134218437 | Peptide=False
# [CHEMBL5091935] CID=166635794 | Peptide=False
# [CHEMBL5091938] CID=127567461 | Peptide=False
# [CHEMBL5091940] CID=141738532 | Peptide=False
# [CHEMBL5091941] CID=139360963 | Peptide=False
# [CHEMBL5091942] CID=152529658 | Peptide=False
# [CHEMBL5091943] CID=23649243 | Peptide=False
# [CHEMBL5091947] CID=151951578 | Peptide=False
# [CHEMBL5091949] CID=166636139 | Peptide=False
# [CHEMBL5091954] CID=166636491 | Peptide=False
# [CHEMBL5091956] CID=139529618 | Peptide=False
# [CHEMBL5091958] CID=153560292 | Peptide=False
# [CHEMBL5091964] CID=166008586 | Peptide=False
# [CHEMBL5091959] CID=24989831 | Peptide=False
# [CHEMBL5091965] CID=166631143 | Peptide=False
# [CHEMBL5091971] CID=122662565 | Peptide=False
# [CHEMBL5091974] CID=166631496 | Peptide=False
# [CHEMBL5091978] CID=166631499 | Peptide=False
# Processing batch 188 of 1864...
# [CHEMBL5091980] CID=166631402 | Peptide=False
# [CHEMBL5091985] CID=166631789 | Peptide=True
# [CHEMBL5091983] CID=166631501 | Peptide=False
# [CHEMBL5091987] CID=166631791 | Peptide=False
# [CHEMBL5091990] CID=155464330 | Peptide=False
# [CHEMBL5091991] CID=166631792 | Peptide=True
# [CHEMBL5091992] CID=139553400 | Peptide=False
# [CHEMBL5091994] CID=154962876 | Peptide=False
# [CHEMBL5091996] CID=166631793 | Peptide=False

# %%
prev_meta = load_meta(META_FILE)
current_meta = {
    "df_chembl.csv": file_mtime(DF_FILE),
    "sql_chembl_cache.parquet": file_mtime(PARQUET_FILE),
}

changed = any(
    prev_meta.get(fname) != current_meta[fname]
    for fname in current_meta
)

if changed:
    run_update_script(UPDATE_SCRIPT)
    save_meta(DF_FILE, PARQUET_FILE, META_FILE)
else:
    print("No changes detected. Skipping upload.")
# Out:
# Running update_cache.sh to upload changed cache files...
# Uploading updated cache files to Google Drive...
# Updating df_chembl.csv...
# Updating 1eu-jaosbrOfSKQ49_duSOB0lmCZlydJe with /home/florion/CompDReAM/data/df_chembl.csv
# File successfully updated
# Id: 1eu-jaosbrOfSKQ49_duSOB0lmCZlydJe
# Name: df_chembl.csv
# Mime: text/csv
# Size: 379.2 MB
# Created: 2025-06-11 14:48:25
# Modified: 2025-06-12 12:34:23
# MD5: fa8157daea19f19e78ec49f6591f81b5
# Shared: True
# Parents: 1mRygsFos3uz1a1xfzNeKEeRWZUxRZJy2
# ViewUrl: https://drive.google.com/file/d/1eu-jaosbrOfSKQ49_duSOB0lmCZlydJe/view?usp=drivesdk
# Updating sql_chembl_cache.parquet...
# Updating 1YP5RBI2H51OYawkhkxPv-uJcd-bPiAzK with /home/florion/CompDReAM/data/sql_chembl_cache.parquet
# File successfully updated
# Id: 1YP5RBI2H51OYawkhkxPv-uJcd-bPiAzK
# Name: sql_chembl_cache.parquet
# Mime: application/octet-stream
# Size: 108 MB
# Created: 2025-06-11 14:48:48
# Modified: 2025-06-12 12:34:26
# MD5: 9e7a1d7707a093d5f3b9618a6b30010a
# Shared: True
# Parents: 1mRygsFos3uz1a1xfzNeKEeRWZUxRZJy2
# ViewUrl: https://drive.google.com/file/d/1YP5RBI2H51OYawkhkxPv-uJcd-bPiAzK/view?usp=drivesdk
# Updating .cache_meta.json...
# Cache metadata file updated: /home/florion/CompDReAM/data/.cache_meta.json
# /tmp/ipykernel_14990/2769149720.py:26: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "updated_at": datetime.utcnow().isoformat()
