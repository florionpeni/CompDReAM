# %%
import sys
sys.path.append("../src")

import os
# Run the script only if either file is missing
if not os.path.exists("../data/df_chembl.csv") or not os.path.exists("../data/sql_chembl_cache.parquet"):
    print("⏳ Downloading cache files...")
    os.system("bash ../get_cache.sh")

from utils.chembl_rescue import rescue_from_chembl, load_or_init_chembl_cache, save_chembl_cache
from utils.molecule_cleanup import classify_relationship, resolve_molecule_type
from utils.pubchem_utils import fetch_pubchem_cid_from_chembl, check_peptide_by_pubchem, process_id, load_or_init_pubchem_cache, save_pubchem_cache

import chembl_downloader
import re
import pandas as pd
import time
from datetime import datetime, timezone
from concurrent.futures import ThreadPoolExecutor, as_completed
from IPython.core.magic import register_cell_magic  # Needed for %%skip Jupyter cell magic

@register_cell_magic
def skip(line, cell):
    """A cell magic that skips execution of the cell body."""
    print("Skipped cell")

# %%
sql_chembl_cache_path = "../data/sql_chembl_cache.parquet"

sql_chembl = """
SELECT
    a.pchembl_value AS "pChEMBL",
    a.potential_duplicate AS "Duplicate? (1/0)",
    a.data_validity_comment AS "Data validity comment",
    ass.chembl_id AS "Assay ChEMBL ID",
    ass.confidence_score,
    dm.mechanism_of_action AS "MOA",
    dm.direct_interaction AS "Direct interaction (1/0)?",
    dm.disease_efficacy AS "Disease efficacy (1/0)?",
    md.chembl_id AS "Molecule ChEMBL ID",
    md.pref_name AS "Preferred name",
    md.molecule_type AS "Molecule type",
    md.max_phase AS "Max phase",
    md.availability_type AS "Availability (2/1/0/-1/-2)?",
    md.therapeutic_flag AS "Therapeutic (1/0)?",
    md.first_in_class AS "First-in-class (1/0/-1)?",
    md.chemical_probe AS "Chemical probe (1/0)?",
    md.orphan AS "Orphan (1/0/-1)?",
    cs.canonical_smiles AS "Canonical SMILES",
    cp.full_mwt AS "Molecular weight of full compound",
    cp.full_molformula AS "Molecular formula of full compound",
    md_parent.chembl_id AS "Parent compound ChEMBL ID",
    md_parent.molecule_type AS parent_molecule_type,
    md_active.chembl_id AS "Active ingredient ChEMBL ID",
    mh.molregno,
    mh.parent_molregno,
    mh.active_molregno,
    td.chembl_id AS "Target ChEMBL ID"
FROM activities a
LEFT JOIN assays ass ON a.assay_id = ass.assay_id
LEFT JOIN target_dictionary td ON ass.tid = td.tid
LEFT JOIN drug_mechanism dm ON a.molregno = dm.molregno
LEFT JOIN molecule_dictionary md ON a.molregno = md.molregno
LEFT JOIN compound_structures cs ON md.molregno = cs.molregno
LEFT JOIN compound_properties cp ON cs.molregno = cp.molregno
LEFT JOIN molecule_hierarchy mh ON md.molregno = mh.molregno
LEFT JOIN molecule_dictionary md_parent ON mh.parent_molregno = md_parent.molregno
LEFT JOIN molecule_dictionary md_active ON mh.active_molregno = md_active.molregno
WHERE a.pchembl_value IS NOT NULL
  AND td.target_type = 'SINGLE PROTEIN'
  AND td.organism = 'Homo sapiens';
"""
if os.path.exists(sql_chembl_cache_path):
    print("Loading cached ChEMBL data...")
    df_raw = pd.read_parquet(sql_chembl_cache_path)
    print("Data loaded.")
else:
    print("Running SQL query...")
    df_raw = chembl_downloader.query(sql_chembl)
    print("Query complete. Saving to cache...")
    df_raw.to_parquet(sql_chembl_cache_path, index=False)
    print("Save complete.")

for col in df_raw.columns:
    print('\nColumn:', df_raw[col].value_counts(dropna=False).head(10))  # Show top 10 frequent values
# Out:
# Loading cached ChEMBL data...
# Data loaded.
#
# Column: pChEMBL
# 4.40    62704
# 4.50    52019
# 4.60    51015
# 4.45    41123
# 4.90    40848
# 4.80    37562
# 5.00    37292
# 4.55    35516
# 4.70    30871
# 4.85    26617
# Name: count, dtype: int64
#
# Column: Duplicate? (1/0)
# 0    2005843
# 1      95016
# Name: count, dtype: int64
#
# Column: Data validity comment
# None                  2100539
# Manually validated        320
# Name: count, dtype: int64
#
# Column: Assay ChEMBL ID
# CHEMBL1614458    76019
# CHEMBL1614421    49886
# CHEMBL1613914    39824
# CHEMBL1614544    36448
# CHEMBL1613842    33737
# CHEMBL1614038    24248
# CHEMBL1614502    24121
# CHEMBL1614079    23084
# CHEMBL1613838    22000
# CHEMBL1614250    20674
# Name: count, dtype: int64
#
# Column: confidence_score
# 9    1623093
# 8     477766
# Name: count, dtype: int64
#
# Column: MOA
# None                                                     1961774
# Tyrosine-protein kinase receptor FLT3 inhibitor             7102
# Stem cell growth factor receptor inhibitor                  4698
# Tyrosine-protein kinase receptor RET inhibitor              3658
# Platelet-derived growth factor receptor inhibitor           3641
# Vascular endothelial growth factor receptor inhibitor       3599
# Carbonic anhydrase II inhibitor                             3245
# Carbonic anhydrase IV inhibitor                             3064
# Serotonin 2a (5-HT2a) receptor antagonist                   2876
# Carbonic anhydrase I inhibitor                              2794
# Name: count, dtype: int64
#
# Column: Direct interaction (1/0)?
# NaN    1961774
# 1.0     139085
# Name: count, dtype: int64
#
# Column: Disease efficacy (1/0)?
# NaN    1961774
# 1.0     139085
# Name: count, dtype: int64
#
# Column: Molecule ChEMBL ID
# CHEMBL535        11025
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3360
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2448
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: Preferred name
# None             1879423
# SUNITINIB          11025
# ACETAZOLAMIDE       8632
# VORINOSTAT          5840
# LESTAURTINIB        5088
# MIDOSTAURIN         3385
# VANDETANIB          3360
# DOVITINIB           2660
# FORETINIB           2592
# ALVOCIDIB           2448
# Name: count, dtype: int64
#
# Column: Molecule type
# Small molecule     1852733
# Unknown             155576
# None                 74645
# Protein              17860
# Oligosaccharide         40
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Max phase
#  NaN    1918899
#  4.0     111910
#  2.0      31593
#  3.0      24677
#  1.0      10744
# -1.0       2908
#  0.5        128
# Name: count, dtype: int64
#
# Column: Availability (2/1/0/-1/-2)?
# -1.0    1898877
#  NaN      97788
#  1.0      93271
#  0.0       4223
# -2.0       4090
#  2.0       2610
# Name: count, dtype: int64
#
# Column: Therapeutic (1/0)?
# 0    1990748
# 1     110111
# Name: count, dtype: int64
#
# Column: First-in-class (1/0/-1)?
# -1    1918899
#  0     172021
#  1       9939
# Name: count, dtype: int64
#
# Column: Chemical probe (1/0)?
# 0    2086672
# 1      14187
# Name: count, dtype: int64
#
# Column: Orphan (1/0/-1)?
# -1    1918899
#  0     174942
#  1       7018
# Name: count, dtype: int64
#
# Column: Canonical SMILES
# CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C                                        11025
# CC(=O)Nc1nnc(S(N)(=O)=O)s1                                                                      8632
# O=C(CCCCCCC(=O)Nc1ccccc1)NO                                                                     5840
# C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)CNC4=O                              5088
# CO[C@@H]1[C@H](N(C)C(=O)c2ccccc2)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4     3385
# COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1                                             3360
# CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1                                         2660
# None                                                                                            2628
# COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1                        2592
# CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@H](O)C1                                     2448
# Name: count, dtype: int64
#
# Column: Molecular weight of full compound
# 398.48    11369
# 222.25     8844
# 264.32     6053
# 439.47     5362
# 570.65     3444
# 475.36     3418
# 392.44     3092
# 466.54     2794
# 401.85     2692
# NaN        2628
# Name: count, dtype: int64
#
# Column: Molecular formula of full compound
# C22H27FN4O2      11140
# C4H6N4O3S2        8632
# C14H20N2O3        5912
# C26H21N3O4        5152
# C35H30N4O4        3387
# C22H24BrFN4O2     3379
# C21H21FN6O        2746
# None              2628
# C34H34F2N4O6      2592
# C21H20ClNO5       2543
# Name: count, dtype: int64
#
# Column: Parent compound ChEMBL ID
# CHEMBL535        11033
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3367
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2448
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: parent_molecule_type
# Small molecule     1854239
# Unknown             155036
# None                 73668
# Protein              17868
# Oligosaccharide         43
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Active ingredient ChEMBL ID
# CHEMBL535        11033
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3367
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2450
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: molregno
# 13048     11025
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3360
# 494834     2660
# 692959     2592
# 14366      2448
# 373381     2188
# Name: count, dtype: int64
#
# Column: parent_molregno
# 13048     11033
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3367
# 494834     2660
# 692959     2592
# 14366      2448
# 373381     2188
# Name: count, dtype: int64
#
# Column: active_molregno
# 13048     11033
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3367
# 494834     2660
# 692959     2592
# 14366      2450
# 373381     2188
# Name: count, dtype: int64
#
# Column: Target ChEMBL ID
# CHEMBL1293224    95232
# CHEMBL3577       76494
# CHEMBL1293226    40146
# CHEMBL1293235    36863
# CHEMBL2608       35167
# CHEMBL1293232    33837
# CHEMBL340        29020
# CHEMBL1963       28951
# CHEMBL4096       26274
# CHEMBL1293255    24701
# Name: count, dtype: int64

# %%
df_raw = df_raw[df_raw["Duplicate? (1/0)"] != 1].copy()  # Drop likely duplicates 
active_ingredients = set(df_raw.loc[df_raw["molregno"] != df_raw["active_molregno"], "active_molregno"])  # Flag prodrugs
df_raw["Active ingredient of prodrug?"] = df_raw["molregno"].apply(
    lambda x: "Yes" if x in active_ingredients else "No"
)
df_raw["Molecule type"] = df_raw.apply(resolve_molecule_type, axis=1)  # Resolve molecule type

# Identify molecules needing rescue
df_dropped = df_raw[df_raw["Molecule type"].isna()].copy()  
dropped_ids = df_dropped["Molecule ChEMBL ID"].dropna().unique().tolist()

# Load or initialise cache
cache_path = "../data/df_rescued_cache.csv"
rescue_cache, _ = load_or_init_chembl_cache(cache_path)

rescued_rows = []
unrecoverable_ids = []
for chembl_id in dropped_ids:
    if chembl_id in rescue_cache:
        row = rescue_cache[chembl_id]
        rescued = (chembl_id, row["Rescued Formula"], row["Rescued SMILES"], row["Rescued Name"], row["Rescued MW"])
        source = "CACHE"
    else:
        rescued = rescue_from_chembl(chembl_id)
        time.sleep(0.5)
        rescue_cache[chembl_id] = {
            "Molecule ChEMBL ID": chembl_id,
            "Rescued Formula": rescued[1],
            "Rescued SMILES": rescued[2],
            "Rescued Name": rescued[3],
            "Rescued MW": rescued[4]
        }
        source = "SCRAPED"
    if any(pd.notna(v) for v in rescued[1:]):
        print(f"[{source}] Rescued {chembl_id}: Formula={rescued[1]}, SMILES={rescued[2]}, Name={rescued[3]}, MW={rescued[4]}")
    else:
        unrecoverable_ids.append(chembl_id)
    rescued_rows.append(rescued)

# Save updated cache
save_chembl_cache(rescue_cache, cache_path)

# Merge rescued data into df_raw
rescue_cols = ["Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW"]
df_rescued = pd.DataFrame(rescued_rows, columns=[
    "Molecule ChEMBL ID", "Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW"
])
if not df_rescued.empty:
    # Remove existing rescue columns if they exist before merging again
    for col in rescue_cols:
        if col in df_raw.columns:
            df_raw.drop(columns=col, inplace=True)
    df_raw = df_raw.merge(df_rescued, on="Molecule ChEMBL ID", how="left")

# Ensure rescue columns exist before combine_first for idempotency
for col in rescue_cols:
    if col not in df_raw.columns:
        df_raw[col] = pd.NA

# Proceed with safe combine
df_raw["Molecular formula of full compound"] = df_raw["Molecular formula of full compound"].combine_first(df_raw["Rescued Formula"])
df_raw["Canonical SMILES"] = df_raw["Canonical SMILES"].combine_first(df_raw["Rescued SMILES"])
df_raw["Preferred name"] = df_raw["Preferred name"].combine_first(df_raw["Rescued Name"])
df_raw["Molecular weight of full compound"] = df_raw["Molecular weight of full compound"].combine_first(df_raw["Rescued MW"])

# Re-resolve molecule type after rescue
df_raw["Molecule type"] = df_raw.apply(resolve_molecule_type, axis=1)

# Final filtering
final_dropped_df = df_raw[df_raw["Molecule type"].isna()]
final_dropped_ids = final_dropped_df["Molecule ChEMBL ID"].dropna().unique()
pd.Series(final_dropped_ids).to_csv("../data/final_dropped_ids.csv", index=False)
print(
    f"Dropped {final_dropped_df.shape[0]} activity rows where Molecule type was None and unrecoverable.\n"
    f"This translates to {final_dropped_ids.shape[0]} unique molecules dropped."
)

# Clean final dataset and save into df_chembl
columns_to_drop = [
    "parent_molecule_type", "molregno", "parent_molregno", "active_molregno",
    "Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW", "Duplicate? (1/0)"
]
df_chembl = df_raw.drop(columns=columns_to_drop, errors="ignore")
for col in df_chembl.columns:
    print('\nColumn:', col)
    print(df_chembl[col].value_counts(dropna=False).head(10))
df_chembl.to_csv("../data/df_chembl.csv", index=False)
# Out:
# [CACHE] Rescued CHEMBL3138733: Formula=H34Cl6N14O2Ru3, SMILES=nan, Name=nan, MW=778.3
# [CACHE] Rescued CHEMBL5086057: Formula=C95H131Cu2IN20O27S2, SMILES=nan, Name=nan, MW=2303.72
# [CACHE] Rescued CHEMBL5087277: Formula=C97H127Cu2IN20O27S2, SMILES=nan, Name=nan, MW=2323.71
# [CACHE] Rescued CHEMBL5089315: Formula=C97H128Cu2IN21O26S2, SMILES=nan, Name=nan, MW=2322.73
# [CACHE] Rescued CHEMBL5087925: Formula=C98H131Cu2N21O26S2, SMILES=nan, Name=nan, MW=2210.86
# [CACHE] Rescued CHEMBL5092357: Formula=C31H46Cu2IN5O10, SMILES=nan, Name=nan, MW=903.11
# [CACHE] Rescued CHEMBL5196854: Formula=C21H14FN5O2V, SMILES=nan, Name=nan, MW=438.32
# Dropped 1133 activity rows where Molecule type was None and unrecoverable.
# This translates to 508 unique molecules dropped.
#
# Column: pChEMBL
# pChEMBL
# 4.40    62635
# 4.50    51983
# 4.60    50865
# 4.45    41109
# 4.90    40808
# 4.80    37485
# 5.00    36934
# 4.55    35441
# 4.70    30743
# 4.85    26539
# Name: count, dtype: int64
#
# Column: Data validity comment
# Data validity comment
# None                  2005523
# Manually validated        320
# Name: count, dtype: int64
#
# Column: Assay ChEMBL ID
# Assay ChEMBL ID
# CHEMBL1614458    76019
# CHEMBL1614421    49886
# CHEMBL1613914    39824
# CHEMBL1614544    36448
# CHEMBL1613842    33737
# CHEMBL1614038    24248
# CHEMBL1614502    24121
# CHEMBL1614079    23084
# CHEMBL1613838    22000
# CHEMBL1614250    20674
# Name: count, dtype: int64
#
# Column: confidence_score
# confidence_score
# 9    1557186
# 8     448657
# Name: count, dtype: int64
#
# Column: MOA
# MOA
# None                                                       1906225
# Tyrosine-protein kinase receptor FLT3 inhibitor               4985
# Stem cell growth factor receptor inhibitor                    3108
# Vascular endothelial growth factor receptor inhibitor         2816
# Platelet-derived growth factor receptor inhibitor             2601
# Serotonin 2a (5-HT2a) receptor antagonist                     2378
# Tyrosine-protein kinase receptor RET inhibitor                2371
# Vascular endothelial growth factor receptor 2 inhibitor       1674
# Epidermal growth factor receptor erbB1 inhibitor              1597
# Tyrosine-protein kinase JAK2 inhibitor                        1508
# Name: count, dtype: int64
#
# Column: Direct interaction (1/0)?
# Direct interaction (1/0)?
# NaN    1906225
# 1.0      99618
# Name: count, dtype: int64
#
# Column: Disease efficacy (1/0)?
# Disease efficacy (1/0)?
# NaN    1906225
# 1.0      99618
# Name: count, dtype: int64
#
# Column: Molecule ChEMBL ID
# Molecule ChEMBL ID
# CHEMBL535        6417
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2338
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1638
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Preferred name
# Preferred name
# NaN              1834016
# SUNITINIB           6417
# LESTAURTINIB        3180
# VORINOSTAT          2948
# VANDETANIB          2338
# FORETINIB           2124
# DOVITINIB           1970
# STAUROSPORINE       1780
# ALVOCIDIB           1638
# BOSUTINIB           1600
# Name: count, dtype: int64
#
# Column: Molecule type
# Molecule type
# Small molecule     1765023
# TBD                 224221
# Protein              15418
# None                  1133
# Oligosaccharide         43
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Max phase
# Max phase
#  NaN    1869202
#  4.0      79322
#  2.0      26563
#  3.0      18653
#  1.0       9404
# -1.0       2580
#  0.5        119
# Name: count, dtype: int64
#
# Column: Availability (2/1/0/-1/-2)?
# Availability (2/1/0/-1/-2)?
# -1.0    1847377
#  NaN      85853
#  1.0      62980
# -2.0       3675
#  0.0       3562
#  2.0       2396
# Name: count, dtype: int64
#
# Column: Therapeutic (1/0)?
# Therapeutic (1/0)?
# 0    1928198
# 1      77645
# Name: count, dtype: int64
#
# Column: First-in-class (1/0/-1)?
# First-in-class (1/0/-1)?
# -1    1869202
#  0     129749
#  1       6892
# Name: count, dtype: int64
#
# Column: Chemical probe (1/0)?
# Chemical probe (1/0)?
# 0    1993896
# 1      11947
# Name: count, dtype: int64
#
# Column: Orphan (1/0/-1)?
# Orphan (1/0/-1)?
# -1    1869202
#  0     132102
#  1       4539
# Name: count, dtype: int64
#
# Column: Canonical SMILES
# Canonical SMILES
# CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C                           6417
# C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)CNC4=O                3180
# O=C(CCCCCCC(=O)Nc1ccccc1)NO                                                       2948
# NaN                                                                               2613
# COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1                               2338
# COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1          2124
# CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1                           1970
# CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4    1780
# CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@H](O)C1                       1638
# COc1cc(Nc2c(C#N)cnc3cc(OCCCN4CCN(C)CC4)c(OC)cc23)c(Cl)cc1Cl                       1600
# Name: count, dtype: int64
#
# Column: Molecular weight of full compound
# Molecular weight of full compound
# 398.48    6752
# 439.47    3451
# 264.32    3157
# NaN       2601
# 475.36    2396
# 392.44    2392
# 466.54    2386
# 632.66    2141
# 332.41    2122
# 401.85    1876
# Name: count, dtype: int64
#
# Column: Molecular formula of full compound
# Molecular formula of full compound
# C22H27FN4O2      6531
# C26H21N3O4       3243
# C14H20N2O3       3018
# NaN              2601
# C22H24BrFN4O2    2357
# C34H34F2N4O6     2124
# C21H21FN6O       2054
# C28H26N4O3       2053
# C20H20N4O        1745
# C21H20ClNO5      1733
# Name: count, dtype: int64
#
# Column: Parent compound ChEMBL ID
# Parent compound ChEMBL ID
# CHEMBL535        6425
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2345
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1638
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Active ingredient ChEMBL ID
# Active ingredient ChEMBL ID
# CHEMBL535        6425
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2345
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1639
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Target ChEMBL ID
# Target ChEMBL ID
# CHEMBL1293224    95229
# CHEMBL3577       76482
# CHEMBL1293226    40132
# CHEMBL1293235    36863
# CHEMBL2608       35163
# CHEMBL1293232    33836
# CHEMBL1963       28951
# CHEMBL340        28814
# CHEMBL4096       26273
# CHEMBL1293255    24691
# Name: count, dtype: int64
#
# Column: Active ingredient of prodrug?
# Active ingredient of prodrug?
# No     1952897
# Yes      52946
# Name: count, dtype: int64

# %%
# %%skip
#
# df_chembl = pd.read_csv("../data/df_chembl.csv")
# unique_chembl_ids = (
#     df_chembl[df_chembl["Molecule type"] == "TBD"]["Molecule ChEMBL ID"]
#     .dropna()
#     .drop_duplicates()
#     .tolist()
# )
#
# cache_path = "../data/pubchem_peptide_inference_cache.csv"
# if os.path.exists(cache_path):
#     df_cache = pd.read_csv(cache_path)
#     df_cache = df_cache.drop_duplicates("Molecule ChEMBL ID")
#     cached_ids = set(df_cache["Molecule ChEMBL ID"])
# else:
#     df_cache = pd.DataFrame(columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
#     cached_ids = set()
#
# uncached_ids = [chembl_id for chembl_id in unique_chembl_ids if chembl_id not in cached_ids]
# print(f"Total molecules to check: {len(uncached_ids)}")
#
# # Process uncached ChEMBL IDs
# batch_size = 1000
# total_batches = (len(uncached_ids) + batch_size - 1) // batch_size
# new_results = []
# print(f"Total molecules to check: {len(uncached_ids)}")
#
# for i in range(0, len(uncached_ids), batch_size):
#     batch_number = i // batch_size + 1
#     batch = uncached_ids[i:i + batch_size]
#     print(f"Processing batch {batch_number} out of {total_batches} ({len(batch)} molecules)")
#     for chembl_id in batch:
#         cid = fetch_pubchem_cid_from_chembl(chembl_id)
#         is_peptide = check_peptide_by_pubchem(cid) if cid else False
#         timestamp = datetime.utcnow().isoformat()
#         new_results.append((chembl_id, cid, is_peptide, timestamp))
#         time.sleep(0.3)
#     # Append to cache
#     df_new = pd.DataFrame(new_results, columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
#     df_cache = pd.concat([df_cache, df_new], ignore_index=True).drop_duplicates("Molecule ChEMBL ID")
#     df_cache.to_csv(cache_path, index=False)
#     print(f"Added {len(df_new)} entries to cache.")
#     new_results = []
# print("PubChem peptide inference complete.")
# Out:
# Skipped cell

# %%
df_chembl = pd.read_csv("../data/df_chembl.csv", low_memory=False)
unique_chembl_ids = (
    df_chembl[df_chembl["Molecule type"] == "TBD"]["Molecule ChEMBL ID"]
    .dropna()
    .drop_duplicates()
    .tolist()
)

cache_path = "../data/pubchem_peptide_inference_cache.csv"
df_cache, cached_ids = load_or_init_pubchem_cache(cache_path)

uncached_ids = sorted(set(unique_chembl_ids) - cached_ids)
batch_size = 25
max_workers = 10

for i in range(0, len(uncached_ids), batch_size):
    batch = uncached_ids[i:i + batch_size]
    print(f"Processing batch {i//batch_size + 1} of {len(uncached_ids) // batch_size + 1}...")
    new_results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_id, chembl_id) for chembl_id in batch]
        for future in as_completed(futures):
            try:
                new_results.append(future.result())
            except Exception as e:
                print(f"Error: {e}")
    df_new = pd.DataFrame(new_results, columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
    df_cache = pd.concat([df_cache, df_new], ignore_index=True).drop_duplicates("Molecule ChEMBL ID")
    save_pubchem_cache(df_cache, cache_path)
print("PubChem peptide inference complete.")
# Out:
# Processing batch 1 of 3026...
# CID fetch failed for CHEMBL4436683 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4436683/cids/JSON
# CID fetch failed for CHEMBL2108106 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2108106/cids/JSON
# CID fetch failed for CHEMBL2108117 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2108117/cids/JSON
# [CHEMBL4438288] CID=16065353 | Peptide=False
# [CHEMBL4435399] CID=155511338 | Peptide=False
# [CHEMBL4439422] CID=155513758 | Peptide=False
# [CHEMBL4434865] CID=155510683 | Peptide=False
# [CHEMBL4439634] CID=155513742 | Peptide=False
# [CHEMBL4435048] CID=134463701 | Peptide=False
# [CHEMBL4439201] CID=68440 | Peptide=False
# [CHEMBL4441682] CID=2840527 | Peptide=False
# [CHEMBL4442805] CID=155516171 | Peptide=False
# [CHEMBL4442771] CID=155516037 | Peptide=False
# [CHEMBL4442330] CID=16065630 | Peptide=False
# [CHEMBL4442570] CID=155515868 | Peptide=False
# [CHEMBL4441423] CID=71523377 | Peptide=False
# CID fetch failed for CHEMBL2108106 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2108106/cids/JSON
# CID fetch failed for CHEMBL2108117 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2108117/cids/JSON
# [CHEMBL4441501] CID=65128 | Peptide=False
# CID fetch failed for CHEMBL4443524 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4443524/cids/JSON
# CID fetch failed for CHEMBL4444068 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4444068/cids/JSON
# [CHEMBL4436683] CID=155512018 | Peptide=False
# [CHEMBL4444356] CID=155517242 | Peptide=False
# [CHEMBL4445340] CID=155517814 | Peptide=False
# [CHEMBL4445443] CID=56592447 | Peptide=False
# [CHEMBL4445920] CID=155518275 | Peptide=False
# [CHEMBL4445802] CID=155518193 | Peptide=False
# [CHEMBL4445985] CID=155518202 | Peptide=False
# [CHEMBL4443524] CID=122644519 | Peptide=False
# [CHEMBL4444068] CID=155517197 | Peptide=False
# CID fetch failed for CHEMBL2108106 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2108106/cids/JSON
# [CHEMBL2108106] CID=None | Peptide=False
# CID fetch failed for CHEMBL2108117 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2108117/cids/JSON
# [CHEMBL2108117] CID=None | Peptide=False
# Processing batch 2 of 3026...
# CID fetch failed for CHEMBL4449823 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4449823/cids/JSON
# CID fetch failed for CHEMBL4449755 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4449755/cids/JSON
# CID fetch failed for CHEMBL4451056 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4451056/cids/JSON
# [CHEMBL4447474] CID=155519217 | Peptide=False
# [CHEMBL4446467] CID=155518513 | Peptide=False
# [CHEMBL4448475] CID=139373943 | Peptide=False
# [CHEMBL4449485] CID=155520721 | Peptide=False
# [CHEMBL4448523] CID=56961886 | Peptide=False
# [CHEMBL4449340] CID=155520878 | Peptide=False
# [CHEMBL4449557] CID=122632882 | Peptide=False
# CID fetch failed for CHEMBL4451474 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4451474/cids/JSON
# [CHEMBL4451085] CID=155521561 | Peptide=False
# [CHEMBL4451577] CID=155521907 | Peptide=False
# [CHEMBL4453068] CID=138513783 | Peptide=False
# [CHEMBL4451889] CID=12913249 | Peptide=False
# [CHEMBL4452280] CID=125848 | Peptide=False
# [CHEMBL4454255] CID=56929814 | Peptide=False
# [CHEMBL4454646] CID=141736095 | Peptide=False
# [CHEMBL4449823] CID=155521301 | Peptide=False
# [CHEMBL4449755] CID=155520674 | Peptide=False
# [CHEMBL4451056] CID=24801247 | Peptide=False
# [CHEMBL4454763] CID=66927429 | Peptide=False
# [CHEMBL4457203] CID=155525893 | Peptide=False
# [CHEMBL4454956] CID=118308375 | Peptide=False
# [CHEMBL4458075] CID=155526596 | Peptide=False
# [CHEMBL4457117] CID=155526084 | Peptide=False
# [CHEMBL4458793] CID=139593251 | Peptide=False
# [CHEMBL4459180] CID=101894468 | Peptide=False
# [CHEMBL4451474] CID=101671063 | Peptide=False
# Processing batch 3 of 3026...
# CID fetch failed for CHEMBL4461458 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4461458/cids/JSON
# CID fetch failed for CHEMBL4461439 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4461439/cids/JSON
# [CHEMBL4460242] CID=85790219 | Peptide=False
# [CHEMBL4460742] CID=102080626 | Peptide=True
# [CHEMBL4459895] CID=126679902 | Peptide=False
# [CHEMBL4460070] CID=39791182 | Peptide=False
# [CHEMBL4463682] CID=102593370 | Peptide=False
# [CHEMBL4463760] CID=155529950 | Peptide=False
# [CHEMBL4461497] CID=155528577 | Peptide=True
# [CHEMBL4461886] CID=139586996 | Peptide=False
# [CHEMBL4464238] CID=134500491 | Peptide=False
# [CHEMBL4464701] CID=155530644 | Peptide=False
# [CHEMBL4465794] CID=155531347 | Peptide=False
# [CHEMBL4465426] CID=129851 | Peptide=False
# [CHEMBL4465826] CID=155531096 | Peptide=True
# [CHEMBL4466322] CID=21778326 | Peptide=False
# [CHEMBL4467224] CID=155532310 | Peptide=False
# [CHEMBL4467327] CID=71542350 | Peptide=False
# CID fetch failed for CHEMBL4467651 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4467651/cids/JSON
# [CHEMBL4467374] CID=246935 | Peptide=False
# [CHEMBL4467500] CID=137553165 | Peptide=False
# [CHEMBL4461439] CID=155528704 | Peptide=False
# [CHEMBL4461458] CID=134500700 | Peptide=False
# [CHEMBL4468753] CID=17965423 | Peptide=False
# [CHEMBL4468057] CID=155532908 | Peptide=False
# [CHEMBL4468731] CID=10646095 | Peptide=False
# [CHEMBL4469440] CID=155533556 | Peptide=False
# [CHEMBL4467651] CID=44188683 | Peptide=False
# Processing batch 4 of 3026...
# CID fetch failed for CHEMBL4472111 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4472111/cids/JSON
# CID fetch failed for CHEMBL4473010 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4473010/cids/JSON
# CID fetch failed for CHEMBL4473314 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4473314/cids/JSON
# [CHEMBL4471300] CID=155534944 | Peptide=False
# [CHEMBL4470526] CID=45838541 | Peptide=False
# [CHEMBL4469552] CID=155533725 | Peptide=False
# [CHEMBL4470825] CID=155534479 | Peptide=False
# [CHEMBL4469905] CID=155534271 | Peptide=False
# [CHEMBL4473598] CID=154730838 | Peptide=False
# [CHEMBL4474844] CID=2748301 | Peptide=False
# [CHEMBL4475458] CID=459803 | Peptide=False
# [CHEMBL4476113] CID=86279165 | Peptide=False
# [CHEMBL4476495] CID=155538270 | Peptide=False
# [CHEMBL4513282] CID=109024602 | Peptide=False
# [CHEMBL4476753] CID=135365181 | Peptide=False
# [CHEMBL4483464] CID=134307251 | Peptide=False
# [CHEMBL4483031] CID=118297748 | Peptide=False
# CID fetch failed for CHEMBL4515649 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4515649/cids/JSON
# CID fetch failed for CHEMBL4515390 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4515390/cids/JSON
# [CHEMBL4513667] CID=3724391 | Peptide=False
# [CHEMBL4473314] CID=53308122 | Peptide=False
# [CHEMBL4472111] CID=139588023 | Peptide=False
# [CHEMBL4473010] CID=155536116 | Peptide=False
# [CHEMBL4514203] CID=155539293 | Peptide=False
# [CHEMBL4513786] CID=91827581 | Peptide=False
# [CHEMBL4514699] CID=134307160 | Peptide=False
# CID fetch failed for CHEMBL4515695 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4515695/cids/JSON
# [CHEMBL4514142] CID=138528 | Peptide=False
# [CHEMBL4515649] CID=155539860 | Peptide=False
# [CHEMBL4515390] CID=136189563 | Peptide=False
# [CHEMBL4515695] CID=16065635 | Peptide=False
# Processing batch 5 of 3026...
# CID fetch failed for CHEMBL4518706 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4518706/cids/JSON
# [CHEMBL4515740] CID=155539833 | Peptide=False
# [CHEMBL4516025] CID=758611 | Peptide=False
# [CHEMBL4518342] CID=155541355 | Peptide=False
# [CHEMBL4516843] CID=155540682 | Peptide=False
# [CHEMBL4517937] CID=155541296 | Peptide=False
# [CHEMBL4516988] CID=91824176 | Peptide=False
# [CHEMBL4516982] CID=57861407 | Peptide=False
# [CHEMBL4516637] CID=16065357 | Peptide=False
# [CHEMBL4516611] CID=9837640 | Peptide=False
# CID fetch failed for CHEMBL4520293 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4520293/cids/JSON
# [CHEMBL4519788] CID=132472236 | Peptide=False
# [CHEMBL4520788] CID=138973681 | Peptide=False
# [CHEMBL4521249] CID=134305904 | Peptide=False
# [CHEMBL4522773] CID=155543618 | Peptide=False
# [CHEMBL4526341] CID=10278851 | Peptide=False
# [CHEMBL4522023] CID=75201659 | Peptide=False
# [CHEMBL4521971] CID=117072548 | Peptide=False
# CID fetch failed for CHEMBL4526351 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4526351/cids/JSON
# CID fetch failed for CHEMBL4526892 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4526892/cids/JSON
# [CHEMBL4522930] CID=23652660 | Peptide=False
# CID fetch failed for CHEMBL4527805 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4527805/cids/JSON
# [CHEMBL4518706] CID=11996298 | Peptide=False
# [CHEMBL4529030] CID=134307517 | Peptide=False
# [CHEMBL4528566] CID=155544938 | Peptide=False
# [CHEMBL4527933] CID=118450728 | Peptide=False
# [CHEMBL4520293] CID=95882507 | Peptide=False
# [CHEMBL4526351] CID=155544007 | Peptide=False
# [CHEMBL4527805] CID=155545357 | Peptide=False
# [CHEMBL4526892] CID=137700029 | Peptide=False
# Processing batch 6 of 3026...
# CID fetch failed for CHEMBL4533529 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4533529/cids/JSON
# CID fetch failed for CHEMBL4533479 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4533479/cids/JSON
# [CHEMBL4530229] CID=138454750 | Peptide=False
# [CHEMBL4530401] CID=155545891 | Peptide=False
# [CHEMBL4532699] CID=118450616 | Peptide=False
# [CHEMBL4530740] CID=58431184 | Peptide=False
# [CHEMBL4530341] CID=71712123 | Peptide=False
# [CHEMBL4531006] CID=135531249 | Peptide=False
# [CHEMBL4532415] CID=66524380 | Peptide=False
# [CHEMBL4531334] CID=132585205 | Peptide=False
# [CHEMBL4534980] CID=95882508 | Peptide=False
# [CHEMBL4535474] CID=137322663 | Peptide=False
# [CHEMBL4536197] CID=137332060 | Peptide=False
# [CHEMBL4538174] CID=145925680 | Peptide=False
# [CHEMBL4538165] CID=118450464 | Peptide=False
# [CHEMBL4536562] CID=155548499 | Peptide=False
# [CHEMBL4537970] CID=138632287 | Peptide=False
# [CHEMBL4536844] CID=155301373 | Peptide=False
# CID fetch failed for CHEMBL4540759 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4540759/cids/JSON
# [CHEMBL4533479] CID=101933292 | Peptide=False
# [CHEMBL4539558] CID=135494293 | Peptide=False
# [CHEMBL4539385] CID=17584764 | Peptide=False
# [CHEMBL4533529] CID=155547374 | Peptide=False
# [CHEMBL4539742] CID=74766530 | Peptide=False
# [CHEMBL4539943] CID=155549686 | Peptide=False
# [CHEMBL4540796] CID=35769758 | Peptide=False
# [CHEMBL4540728] CID=155549857 | Peptide=False
# [CHEMBL4540759] CID=155550034 | Peptide=False
# Processing batch 7 of 3026...
# CID fetch failed for CHEMBL4545488 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4545488/cids/JSON
# [CHEMBL4543737] CID=155552436 | Peptide=False
# [CHEMBL4541968] CID=134307698 | Peptide=False
# [CHEMBL4543856] CID=153295256 | Peptide=False
# [CHEMBL4542380] CID=117072552 | Peptide=False
# [CHEMBL4542873] CID=155551649 | Peptide=False
# [CHEMBL4542499] CID=71725124 | Peptide=False
# [CHEMBL4544784] CID=1800733 | Peptide=False
# [CHEMBL4544901] CID=91664325 | Peptide=False
# [CHEMBL4545194] CID=133145 | Peptide=False
# [CHEMBL4545807] CID=155553652 | Peptide=False
# [CHEMBL4546802] CID=155552454 | Peptide=False
# [CHEMBL4547253] CID=155553381 | Peptide=False
# [CHEMBL4546345] CID=609492 | Peptide=False
# [CHEMBL4548689] CID=56707820 | Peptide=False
# [CHEMBL4547890] CID=642801 | Peptide=False
# [CHEMBL4549229] CID=146202071 | Peptide=False
# [CHEMBL4548972] CID=12489977 | Peptide=False
# [CHEMBL4549667] CID=135309104 | Peptide=False
# [CHEMBL4549681] CID=134307761 | Peptide=False
# [CHEMBL4550273] CID=16065631 | Peptide=False
# [CHEMBL4550999] CID=71345494 | Peptide=False
# [CHEMBL4550896] CID=2812453 | Peptide=False
# [CHEMBL4551344] CID=155555047 | Peptide=False
# [CHEMBL4551546] CID=155555334 | Peptide=False
# [CHEMBL4545488] CID=121322599 | Peptide=False
# Processing batch 8 of 3026...
# CID fetch failed for CHEMBL4552959 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4552959/cids/JSON
# [CHEMBL4551635] CID=155555842 | Peptide=False
# [CHEMBL4551583] CID=134307220 | Peptide=False
# [CHEMBL4552554] CID=59842446 | Peptide=False
# [CHEMBL4552180] CID=124203924 | Peptide=False
# [CHEMBL4552037] CID=134307474 | Peptide=False
# [CHEMBL4552354] CID=155554839 | Peptide=False
# [CHEMBL4552904] CID=1330309 | Peptide=False
# [CHEMBL4553089] CID=15042086 | Peptide=False
# [CHEMBL4551611] CID=2835148 | Peptide=False
# CID fetch failed for CHEMBL4555465 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4555465/cids/JSON
# [CHEMBL4553284] CID=78357808 | Peptide=False
# [CHEMBL4554781] CID=155556478 | Peptide=False
# [CHEMBL4555711] CID=155556859 | Peptide=False
# CID fetch failed for CHEMBL4552959 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4552959/cids/JSON
# [CHEMBL4554226] CID=134500548 | Peptide=False
# [CHEMBL4554703] CID=155556564 | Peptide=False
# [CHEMBL4555217] CID=137375527 | Peptide=False
# [CHEMBL4554938] CID=121499143 | Peptide=False[CHEMBL4555625] CID=118450590 | Peptide=False
#
# CID fetch failed for CHEMBL4556019 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4556019/cids/JSON
# [CHEMBL4556013] CID=74223608 | Peptide=False
# [CHEMBL4556790] CID=155557232 | Peptide=False
# [CHEMBL4557026] CID=155557179 | Peptide=False
# [CHEMBL4558518] CID=155557564 | Peptide=False
# [CHEMBL4558130] CID=155557180 | Peptide=False
# [CHEMBL4555465] CID=12258737 | Peptide=False
# [CHEMBL4556019] CID=134694995 | Peptide=False
# [CHEMBL4552959] CID=137297217 | Peptide=False
# Processing batch 9 of 3026...
# [CHEMBL4558617] CID=134307398 | Peptide=False
# [CHEMBL4559088] CID=134305963 | Peptide=False
# [CHEMBL4560589] CID=155558331 | Peptide=False
# [CHEMBL4559961] CID=122707126 | Peptide=False
# [CHEMBL4560679] CID=124647268 | Peptide=False
# [CHEMBL4561003] CID=118450770 | Peptide=False
# [CHEMBL4560666] CID=134307780 | Peptide=False
# [CHEMBL4561657] CID=16334060 | Peptide=False
# [CHEMBL4561247] CID=134308284 | Peptide=False
# [CHEMBL4560241] CID=56849304 | Peptide=False
# [CHEMBL4562140] CID=56645576 | Peptide=False
# [CHEMBL4563588] CID=58328022 | Peptide=False
# [CHEMBL4563704] CID=57525008 | Peptide=False
# [CHEMBL4564280] CID=122197584 | Peptide=False
# [CHEMBL4564312] CID=118877194 | Peptide=False
# [CHEMBL4565370] CID=91864701 | Peptide=False
# [CHEMBL4565796] CID=155545323 | Peptide=False
# [CHEMBL4566600] CID=155561056 | Peptide=False
# [CHEMBL4565531] CID=122529139 | Peptide=False
# [CHEMBL4567157] CID=135397653 | Peptide=False
# [CHEMBL4567314] CID=155544861 | Peptide=False
# [CHEMBL4567355] CID=155544863 | Peptide=False
# [CHEMBL4567907] CID=101864420 | Peptide=False
# [CHEMBL4568183] CID=155560522 | Peptide=False
# [CHEMBL4568226] CID=134307447 | Peptide=False
# Processing batch 10 of 3026...
# CID fetch failed for CHEMBL4572306 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4572306/cids/JSON
# [CHEMBL4568735] CID=155560620 | Peptide=False
# [CHEMBL4572210] CID=155563095 | Peptide=False
# [CHEMBL4571199] CID=26458355 | Peptide=False
# [CHEMBL4569978] CID=292929 | Peptide=False
# [CHEMBL4569124] CID=12777191 | Peptide=False
# [CHEMBL4568949] CID=937120 | Peptide=False
# [CHEMBL4573176] CID=145721206 | Peptide=False
# [CHEMBL4573938] CID=134307820 | Peptide=False
# [CHEMBL4569890] CID=546059 | Peptide=False
# CID fetch failed for CHEMBL4574407 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4574407/cids/JSON
# [CHEMBL4577237] CID=155554081 | Peptide=False
# [CHEMBL4574448] CID=155564405 | Peptide=False
# [CHEMBL4576555] CID=146673143 | Peptide=False
# [CHEMBL4576110] CID=126365 | Peptide=False
# [CHEMBL4575427] CID=135430346 | Peptide=False
# [CHEMBL4577235] CID=134501222 | Peptide=False
# [CHEMBL4575134] CID=10361692 | Peptide=False
# [CHEMBL4576664] CID=71678022 | Peptide=False
# [CHEMBL4572306] CID=61266940 | Peptide=False
# [CHEMBL4578164] CID=11364870 | Peptide=False
# [CHEMBL4578793] CID=4122616 | Peptide=False
# [CHEMBL4579018] CID=127234 | Peptide=False
# [CHEMBL4579981] CID=72898300 | Peptide=False
# [CHEMBL4580220] CID=134817183 | Peptide=False
# [CHEMBL4580655] CID=16065920 | Peptide=False
# [CHEMBL4574407] CID=2891592 | Peptide=False
# Processing batch 11 of 3026...
# CID fetch failed for CHEMBL4583478 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4583478/cids/JSON
# [CHEMBL4581461] CID=138454303 | Peptide=False
# [CHEMBL4580787] CID=138454780 | Peptide=False
# [CHEMBL4580920] CID=16086823 | Peptide=False
# [CHEMBL4581956] CID=2891824 | Peptide=False
# [CHEMBL4582937] CID=50997601 | Peptide=False
# [CHEMBL4583133] CID=134600183 | Peptide=False
# [CHEMBL4580834] CID=118450730 | Peptide=False
# [CHEMBL4582351] CID=134307705 | Peptide=False
# [CHEMBL4582312] CID=137297214 | Peptide=False
# [CHEMBL4583499] CID=697364 | Peptide=False
# [CHEMBL4584525] CID=71562141 | Peptide=False
# [CHEMBL4584981] CID=155561913 | Peptide=False
# [CHEMBL4585238] CID=2726650 | Peptide=False
# [CHEMBL4584451] CID=137297511 | Peptide=False
# [CHEMBL4585243] CID=118425786 | Peptide=False
# [CHEMBL4584162] CID=16065634 | Peptide=False
# [CHEMBL4585665] CID=134307247 | Peptide=False
# [CHEMBL4585642] CID=101412 | Peptide=False
# [CHEMBL4585781] CID=122497020 | Peptide=False
# [CHEMBL4585739] CID=2901275 | Peptide=False
# [CHEMBL4583478] CID=3036942 | Peptide=False
# [CHEMBL4586225] CID=155567084 | Peptide=False
# [CHEMBL4586794] CID=6451154 | Peptide=False
# [CHEMBL4585920] CID=140309892 | Peptide=False
# [CHEMBL4587433] CID=132274054 | Peptide=False
# Processing batch 12 of 3026...
# CID fetch failed for CHEMBL4591454 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4591454/cids/JSON
# [CHEMBL4588900] CID=59126962 | Peptide=False
# [CHEMBL4587880] CID=134307806 | Peptide=False
# [CHEMBL4590950] CID=155568733 | Peptide=False
# [CHEMBL4590059] CID=134307487 | Peptide=False
# [CHEMBL4589249] CID=155567919 | Peptide=False
# [CHEMBL4589724] CID=155568230 | Peptide=False
# [CHEMBL4591082] CID=155568238 | Peptide=False
# [CHEMBL4591651] CID=155568329 | Peptide=False
# [CHEMBL4591182] CID=3696767 | Peptide=False
# [CHEMBL4592872] CID=155568985 | Peptide=False
# [CHEMBL4593677] CID=24959105 | Peptide=False
# [CHEMBL4594072] CID=118450420 | Peptide=False
# [CHEMBL4594757] CID=155510827 | Peptide=False
# [CHEMBL4595323] CID=155550038 | Peptide=False
# [CHEMBL4594870] CID=155532003 | Peptide=False
# [CHEMBL4595209] CID=134813902 | Peptide=False
# [CHEMBL4595238] CID=130418846 | Peptide=False
# [CHEMBL4595328] CID=132156530 | Peptide=False
# [CHEMBL4591454] CID=155568322 | Peptide=False
# [CHEMBL4595425] CID=135274950 | Peptide=False
# [CHEMBL4596065] CID=155522355 | Peptide=False
# [CHEMBL4596647] CID=155513745 | Peptide=False
# [CHEMBL4596515] CID=67452408 | Peptide=False
# [CHEMBL4596287] CID=73386708 | Peptide=False
# [CHEMBL4596899] CID=155557119 | Peptide=False
# Processing batch 13 of 3026...
# [CHEMBL4597954] CID=139558701 | Peptide=False
# [CHEMBL4598338] CID=155569479 | Peptide=False
# [CHEMBL4630642] CID=156009444 | Peptide=False
# [CHEMBL4598390] CID=118308612 | Peptide=False
# [CHEMBL4597874] CID=137628682 | Peptide=False
# [CHEMBL4598256] CID=155535905 | Peptide=False
# [CHEMBL4597094] CID=155522777 | Peptide=True
# [CHEMBL4630644] CID=154701640 | Peptide=False
# [CHEMBL4633161] CID=135205863 | Peptide=False
# [CHEMBL4633869] CID=122371996 | Peptide=False
# [CHEMBL4634443] CID=156009646 | Peptide=False
# [CHEMBL4634333] CID=156010309 | Peptide=False
# [CHEMBL4634268] CID=154699444 | Peptide=False
# [CHEMBL4636049] CID=156014150 | Peptide=False
# [CHEMBL4597498] CID=155566290 | Peptide=False
# [CHEMBL4635540] CID=156022246 | Peptide=False
# [CHEMBL4634933] CID=135218990 | Peptide=False
# [CHEMBL4636686] CID=135219005 | Peptide=False
# [CHEMBL4637208] CID=132004022 | Peptide=False
# [CHEMBL4637348] CID=9599926 | Peptide=False[CHEMBL4637401] CID=118877433 | Peptide=False
#
# [CHEMBL4638207] CID=156012800 | Peptide=False
# [CHEMBL4638406] CID=156011311 | Peptide=False
# [CHEMBL4638939] CID=138618774 | Peptide=False[CHEMBL4638706] CID=156011208 | Peptide=False
#
# Processing batch 14 of 3026...
# CID fetch failed for CHEMBL4641560 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4641560/cids/JSON
# CID fetch failed for CHEMBL4642294 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4642294/cids/JSON
# [CHEMBL4642079] CID=156016206 | Peptide=False
# [CHEMBL4642183] CID=46009274 | Peptide=False
# [CHEMBL4639460] CID=138674558 | Peptide=False
# [CHEMBL4641038] CID=118679768 | Peptide=False
# [CHEMBL4639113] CID=152078964 | Peptide=False
# [CHEMBL4641226] CID=118418553 | Peptide=False
# [CHEMBL4642346] CID=156017103 | Peptide=False
# [CHEMBL4642052] CID=118094189 | Peptide=False
# CID fetch failed for CHEMBL4642394 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4642394/cids/JSON
# [CHEMBL4642517] CID=136969934 | Peptide=False
# [CHEMBL4642983] CID=155805454 | Peptide=False
# [CHEMBL4643070] CID=156017432 | Peptide=False
# [CHEMBL4643118] CID=101067095 | Peptide=False
# [CHEMBL4644409] CID=156018816 | Peptide=False
# [CHEMBL4643057] CID=137358277 | Peptide=False
# [CHEMBL4644893] CID=137358146 | Peptide=False
# [CHEMBL4642294] CID=156016724 | Peptide=False
# [CHEMBL4645270] CID=156017984 | Peptide=False
# [CHEMBL4645427] CID=124080445 | Peptide=False
# [CHEMBL4644947] CID=309226 | Peptide=False
# [CHEMBL4641560] CID=154134214 | Peptide=False
# [CHEMBL4646064] CID=58335500 | Peptide=False
# [CHEMBL4647456] CID=134194659 | Peptide=False
# [CHEMBL4647642] CID=156021282 | Peptide=False
# [CHEMBL4647387] CID=122540907 | Peptide=False
# [CHEMBL4642394] CID=156017403 | Peptide=False
# Processing batch 15 of 3026...
# [CHEMBL4648477] CID=435840 | Peptide=False
# [CHEMBL4648447] CID=156021193 | Peptide=False
# [CHEMBL4650581] CID=156012479 | Peptide=False
# [CHEMBL4648362] CID=146681130 | Peptide=False
# [CHEMBL4650902] CID=156014888 | Peptide=False
# [CHEMBL4649154] CID=156021653 | Peptide=False
# [CHEMBL4650593] CID=156010086 | Peptide=False
# [CHEMBL4650909] CID=134817177 | Peptide=False
# [CHEMBL4650795] CID=156011026 | Peptide=False
# [CHEMBL4650755] CID=5487427 | Peptide=False
# CID fetch failed for CHEMBL4739871 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4739871/cids/JSON
# [CHEMBL4650998] CID=156014820 | Peptide=False
# CID fetch failed for CHEMBL4739883 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4739883/cids/JSON
# [CHEMBL4651133] CID=11344894 | Peptide=False
# [CHEMBL4739867] CID=162644527 | Peptide=False
# [CHEMBL4739868] CID=162644528 | Peptide=False
# [CHEMBL4739877] CID=162644628 | Peptide=False
# [CHEMBL4739874] CID=162644626 | Peptide=False
# [CHEMBL4739879] CID=146680878 | Peptide=False
# [CHEMBL4739884] CID=126752343 | Peptide=False
# [CHEMBL4739889] CID=162644689 | Peptide=False
# [CHEMBL4739893] CID=162644720 | Peptide=False
# [CHEMBL4739895] CID=162644722 | Peptide=False
# [CHEMBL4739891] CID=162644718 | Peptide=False
# [CHEMBL4739896] CID=129048540 | Peptide=False
# [CHEMBL4739871] CID=162644623 | Peptide=False
# [CHEMBL4739883] CID=162644684 | Peptide=False
# Processing batch 16 of 3026...
# CID fetch failed for CHEMBL4739907 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4739907/cids/JSON
# [CHEMBL4739900] CID=162644725 | Peptide=False
# [CHEMBL4739898] CID=162644724 | Peptide=False
# [CHEMBL4739905] CID=126752349 | Peptide=False
# [CHEMBL4739917] CID=162644759 | Peptide=False
# [CHEMBL4739922] CID=1433661 | Peptide=False
# [CHEMBL4739919] CID=162644781 | Peptide=False
# [CHEMBL4739925] CID=153370945 | Peptide=False
# [CHEMBL4739929] CID=162644785 | Peptide=False[CHEMBL4739932] CID=51357318 | Peptide=False
#
# CID fetch failed for CHEMBL4739951 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4739951/cids/JSON
# [CHEMBL4739933] CID=162644822 | Peptide=False
# [CHEMBL4739937] CID=162644826 | Peptide=False
# [CHEMBL4739944] CID=162644860 | Peptide=False[CHEMBL4739938] CID=162644828 | Peptide=False
#
# [CHEMBL4739955] CID=162644898 | Peptide=False
# [CHEMBL4739945] CID=162644861 | Peptide=False
# CID fetch failed for CHEMBL4739959 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4739959/cids/JSON
# [CHEMBL4739952] CID=156061636 | Peptide=True
# [CHEMBL4739950] CID=134506953 | Peptide=False
# CID fetch failed for CHEMBL4739960 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4739960/cids/JSON
# [CHEMBL4739968] CID=162644940 | Peptide=False
# [CHEMBL4739963] CID=162644904 | Peptide=False
# [CHEMBL4739907] CID=162644728 | Peptide=False
# [CHEMBL4739971] CID=162644943 | Peptide=False
# [CHEMBL4739969] CID=162644941 | Peptide=True
# [CHEMBL4739951] CID=1207444 | Peptide=False
# [CHEMBL4739959] CID=162644902 | Peptide=False
# [CHEMBL4739960] CID=11735699 | Peptide=False
# Processing batch 17 of 3026...
# CID fetch failed for CHEMBL4739996 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4739996/cids/JSON
# [CHEMBL4739973] CID=162644945 | Peptide=False
# [CHEMBL4739978] CID=162644948 | Peptide=False
# [CHEMBL4739975] CID=154622444 | Peptide=False
# [CHEMBL4740022] CID=216008 | Peptide=False
# [CHEMBL4739994] CID=162645036 | Peptide=False
# [CHEMBL4739976] CID=71491247 | Peptide=False
# [CHEMBL4740004] CID=153585650 | Peptide=False
# [CHEMBL4740003] CID=155289395 | Peptide=False
# [CHEMBL4740020] CID=139575810 | Peptide=False
# CID fetch failed for CHEMBL4740049 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740049/cids/JSON
# CID fetch failed for CHEMBL4740037 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740037/cids/JSON
# [CHEMBL4740026] CID=162645133 | Peptide=False
# [CHEMBL4740027] CID=162645134 | Peptide=False
# [CHEMBL4740028] CID=16261240 | Peptide=False
# [CHEMBL4740030] CID=155754721 | Peptide=False
# [CHEMBL4740045] CID=137114022 | Peptide=False
# [CHEMBL4740035] CID=139558722 | Peptide=False
# [CHEMBL4740031] CID=4461490 | Peptide=False
# [CHEMBL4740051] CID=149870563 | Peptide=False
# [CHEMBL4740055] CID=162645185 | Peptide=False
# [CHEMBL4739996] CID=162645038 | Peptide=False
# [CHEMBL4740063] CID=10064199 | Peptide=False
# [CHEMBL4740064] CID=136213660 | Peptide=False
# [CHEMBL4740075] CID=146281806 | Peptide=False
# [CHEMBL4740074] CID=118366970 | Peptide=False
# [CHEMBL4740037] CID=155384878 | Peptide=False
# [CHEMBL4740049] CID=159125654 | Peptide=False
# Processing batch 18 of 3026...
# CID fetch failed for CHEMBL4740081 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740081/cids/JSON
# [CHEMBL4740126] CID=71282667 | Peptide=False
# [CHEMBL4740117] CID=162644795 | Peptide=True
# [CHEMBL4740111] CID=162644772 | Peptide=False
# [CHEMBL4740087] CID=162644690 | Peptide=True
# [CHEMBL4740127] CID=148107755 | Peptide=False
# [CHEMBL4740097] CID=132256715 | Peptide=False
# [CHEMBL4740119] CID=162644832 | Peptide=False
# [CHEMBL4740125] CID=134226884 | Peptide=False
# [CHEMBL4740090] CID=162644692 | Peptide=False
# [CHEMBL4740128] CID=92529079 | Peptide=False
# [CHEMBL4740135] CID=162644910 | Peptide=False
# [CHEMBL4740141] CID=162644951 | Peptide=False
# [CHEMBL4740136] CID=162644911 | Peptide=False
# [CHEMBL4740144] CID=162644953 | Peptide=False
# [CHEMBL4740154] CID=162644991 | Peptide=False
# [CHEMBL4740149] CID=141532336 | Peptide=False
# [CHEMBL4740148] CID=162644957 | Peptide=False
# [CHEMBL4740150] CID=162644958 | Peptide=False
# [CHEMBL4740156] CID=162644993 | Peptide=False
# [CHEMBL4740157] CID=154025209 | Peptide=False
# [CHEMBL4740081] CID=162644642 | Peptide=False
# [CHEMBL4740162] CID=162644994 | Peptide=False
# [CHEMBL4740167] CID=162645058 | Peptide=False
# [CHEMBL4740169] CID=162645060 | Peptide=False
# [CHEMBL4740168] CID=162645059 | Peptide=False
# Processing batch 19 of 3026...
# [CHEMBL4740172] CID=162645062 | Peptide=False
# [CHEMBL4740188] CID=138687825 | Peptide=False
# [CHEMBL4740170] CID=126482550 | Peptide=False
# [CHEMBL4740201] CID=162645146 | Peptide=True
# [CHEMBL4740193] CID=162645114 | Peptide=False
# [CHEMBL4740181] CID=137039450 | Peptide=False
# [CHEMBL4740175] CID=77846675 | Peptide=False
# [CHEMBL4740207] CID=162645190 | Peptide=False
# [CHEMBL4740191] CID=162645112 | Peptide=False
# CID fetch failed for CHEMBL4740228 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740228/cids/JSON
# [CHEMBL4740210] CID=162645193 | Peptide=False
# [CHEMBL4740212] CID=162645195 | Peptide=False
# [CHEMBL4740213] CID=49846136 | Peptide=False
# [CHEMBL4740211] CID=162645194 | Peptide=False
# [CHEMBL4740214] CID=162644529 | Peptide=False
# [CHEMBL4740234] CID=162644647 | Peptide=False
# [CHEMBL4740221] CID=24250013 | Peptide=False
# [CHEMBL4740220] CID=162644535 | Peptide=False
# [CHEMBL4740226] CID=90389598 | Peptide=False
# [CHEMBL4740235] CID=162644648 | Peptide=False
# [CHEMBL4740241] CID=162644652 | Peptide=False
# [CHEMBL4740246] CID=5744885 | Peptide=False
# [CHEMBL4740245] CID=162644657 | Peptide=False
# [CHEMBL4740249] CID=162644696 | Peptide=False
# [CHEMBL4740250] CID=156700976 | Peptide=False
# [CHEMBL4740228] CID=162644596 | Peptide=False
# Processing batch 20 of 3026...
# CID fetch failed for CHEMBL4740285 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740285/cids/JSON
# [CHEMBL4740254] CID=124155226 | Peptide=False
# [CHEMBL4740282] CID=141750311 | Peptide=False
# [CHEMBL4740264] CID=137516487 | Peptide=False
# [CHEMBL4740281] CID=43558917 | Peptide=False
# [CHEMBL4740277] CID=162644775 | Peptide=False
# [CHEMBL4740251] CID=162644697 | Peptide=False
# [CHEMBL4740273] CID=153370920 | Peptide=False
# [CHEMBL4740255] CID=162644700 | Peptide=False
# [CHEMBL4740287] CID=154584181 | Peptide=False
# [CHEMBL4740288] CID=162644798 | Peptide=False
# [CHEMBL4740294] CID=118247752 | Peptide=False
# [CHEMBL4740295] CID=162644804 | Peptide=False
# [CHEMBL4740312] CID=136326241 | Peptide=False
# [CHEMBL4740300] CID=162644836 | Peptide=False
# [CHEMBL4740321] CID=162644919 | Peptide=False
# [CHEMBL4740303] CID=162644839 | Peptide=False
# [CHEMBL4740302] CID=162644838 | Peptide=False
# [CHEMBL4740315] CID=162644915 | Peptide=False
# CID fetch failed for CHEMBL4740323 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740323/cids/JSON
# CID fetch failed for CHEMBL4740324 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740324/cids/JSON
# [CHEMBL4740322] CID=162644920 | Peptide=False
# [CHEMBL4740285] CID=138549887 | Peptide=False
# [CHEMBL4740325] CID=162644923 | Peptide=True
# [CHEMBL4740329] CID=162644959 | Peptide=False
# [CHEMBL4740328] CID=162644926 | Peptide=False
# [CHEMBL4740323] CID=162644921 | Peptide=False
# [CHEMBL4740324] CID=162644922 | Peptide=False
# Processing batch 21 of 3026...
# CID fetch failed for CHEMBL4740364 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740364/cids/JSON
# [CHEMBL4740336] CID=162644965 | Peptide=False
# [CHEMBL4740331] CID=132089053 | Peptide=False
# [CHEMBL4740341] CID=162644967 | Peptide=False
# [CHEMBL4740356] CID=162645119 | Peptide=False
# [CHEMBL4740348] CID=49787174 | Peptide=False
# [CHEMBL4740334] CID=162644963 | Peptide=False
# [CHEMBL4740363] CID=153321121 | Peptide=False
# [CHEMBL4740346] CID=162645073 | Peptide=False
# [CHEMBL4740340] CID=343732 | Peptide=False
# CID fetch failed for CHEMBL4740393 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740393/cids/JSON
# [CHEMBL4740366] CID=162645154 | Peptide=False
# [CHEMBL4740367] CID=141488519 | Peptide=False
# [CHEMBL4740375] CID=122582974 | Peptide=False
# [CHEMBL4740384] CID=162645197 | Peptide=False
# [CHEMBL4740377] CID=153088183 | Peptide=False
# [CHEMBL4740385] CID=162645198 | Peptide=False
# [CHEMBL4740381] CID=139326669 | Peptide=False
# [CHEMBL4740401] CID=118409089 | Peptide=False
# CID fetch failed for CHEMBL4740413 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740413/cids/JSON
# [CHEMBL4740364] CID=162645153 | Peptide=False
# [CHEMBL4740403] CID=162644539 | Peptide=False
# [CHEMBL4740404] CID=129094241 | Peptide=False
# [CHEMBL4740406] CID=162644541 | Peptide=False
# [CHEMBL4740414] CID=162644548 | Peptide=False
# [CHEMBL4740411] CID=162644545 | Peptide=False
# [CHEMBL4740393] CID=155813286 | Peptide=False
# [CHEMBL4740413] CID=162644546 | Peptide=False
# Processing batch 22 of 3026...
# CID fetch failed for CHEMBL4740450 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740450/cids/JSON
# [CHEMBL4740425] CID=162644603 | Peptide=False
# [CHEMBL4740433] CID=146552490 | Peptide=False
# [CHEMBL4740453] CID=162644743 | Peptide=False
# [CHEMBL4740455] CID=162644745 | Peptide=False
# [CHEMBL4740420] CID=162644599 | Peptide=False
# [CHEMBL4740435] CID=141743297 | Peptide=False
# [CHEMBL4740442] CID=162644708 | Peptide=False
# [CHEMBL4740438] CID=162644703 | Peptide=False
# [CHEMBL4740444] CID=162644710 | Peptide=True
# [CHEMBL4740458] CID=162644748 | Peptide=False
# [CHEMBL4740473] CID=162644756 | Peptide=False
# [CHEMBL4740478] CID=162620900 | Peptide=False
# [CHEMBL4740481] CID=137368582 | Peptide=False
# [CHEMBL4740491] CID=153585580 | Peptide=False
# [CHEMBL4740501] CID=146257204 | Peptide=False
# [CHEMBL4740497] CID=85090318 | Peptide=False
# [CHEMBL4740498] CID=126524148 | Peptide=False
# [CHEMBL4740500] CID=162644820 | Peptide=False
# [CHEMBL4740450] CID=138559247 | Peptide=False
# [CHEMBL4740502] CID=162644844 | Peptide=False
# [CHEMBL4740508] CID=4377035 | Peptide=False
# [CHEMBL4740512] CID=162644873 | Peptide=False
# [CHEMBL4740509] CID=162644870 | Peptide=False
# [CHEMBL4740513] CID=162644874 | Peptide=False
# [CHEMBL4740514] CID=162644875 | Peptide=False
# Processing batch 23 of 3026...
# CID fetch failed for CHEMBL4740539 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740539/cids/JSON
# [CHEMBL4740519] CID=153585418 | Peptide=False
# [CHEMBL4740533] CID=162644971 | Peptide=False
# [CHEMBL4740526] CID=162644929 | Peptide=False
# [CHEMBL4740535] CID=162644973 | Peptide=False
# [CHEMBL4740547] CID=162644998 | Peptide=False
# [CHEMBL4740518] CID=132057272 | Peptide=False[CHEMBL4740521] CID=162644880 | Peptide=True
#
# [CHEMBL4740532] CID=86723832 | Peptide=False
# [CHEMBL4740522] CID=141755657 | Peptide=False
# [CHEMBL4740550] CID=97015271 | Peptide=False
# [CHEMBL4740551] CID=162645000 | Peptide=False
# [CHEMBL4740560] CID=162645079 | Peptide=False
# [CHEMBL4740573] CID=162645120 | Peptide=False
# [CHEMBL4740565] CID=145994863 | Peptide=False
# [CHEMBL4740559] CID=162645078 | Peptide=False
# [CHEMBL4740570] CID=152648304 | Peptide=False
# [CHEMBL4740576] CID=156700977 | Peptide=False
# [CHEMBL4740574] CID=137113718 | Peptide=False
# [CHEMBL4740539] CID=162644976 | Peptide=False
# [CHEMBL4740579] CID=162645122 | Peptide=False
# [CHEMBL4740586] CID=162645128 | Peptide=False
# [CHEMBL4740591] CID=162645165 | Peptide=False
# [CHEMBL4740593] CID=162645166 | Peptide=False
# [CHEMBL4740594] CID=162645167 | Peptide=False
# [CHEMBL4740577] CID=155175686 | Peptide=False
# Processing batch 24 of 3026...
# CID fetch failed for CHEMBL4740635 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740635/cids/JSON
# [CHEMBL4740602] CID=162645210 | Peptide=False
# [CHEMBL4740604] CID=162645212 | Peptide=False
# [CHEMBL4740616] CID=129048567 | Peptide=False
# [CHEMBL4740631] CID=162644606 | Peptide=False
# [CHEMBL4740634] CID=162644609 | Peptide=False
# [CHEMBL4740625] CID=162644567 | Peptide=False
# [CHEMBL4740621] CID=162644564 | Peptide=False
# [CHEMBL4740613] CID=162644557 | Peptide=False
# [CHEMBL4740637] CID=162644611 | Peptide=False
# [CHEMBL4740640] CID=122584960 | Peptide=False
# [CHEMBL4740642] CID=162644664 | Peptide=True
# [CHEMBL4740643] CID=162644665 | Peptide=False
# [CHEMBL4740644] CID=59339129 | Peptide=False[CHEMBL4740646] CID=162644666 | Peptide=False
#
# [CHEMBL4740648] CID=162644668 | Peptide=False
# [CHEMBL4740651] CID=10891397 | Peptide=False
# [CHEMBL4740655] CID=162644850 | Peptide=True
# [CHEMBL4740657] CID=137487264 | Peptide=False
# CID fetch failed for CHEMBL4740667 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740667/cids/JSON
# [CHEMBL4740661] CID=162644854 | Peptide=False
# [CHEMBL4740660] CID=162644853 | Peptide=False
# [CHEMBL4740662] CID=42610919 | Peptide=False
# [CHEMBL4740635] CID=154815729 | Peptide=False
# [CHEMBL4740663] CID=162644855 | Peptide=False
# [CHEMBL4740664] CID=162644856 | Peptide=False
# [CHEMBL4740667] CID=162644858 | Peptide=False
# Processing batch 25 of 3026...
# [CHEMBL4740693] CID=162383198 | Peptide=False
# [CHEMBL4740674] CID=162644886 | Peptide=False
# [CHEMBL4740668] CID=162644859 | Peptide=True
# [CHEMBL4740701] CID=162644983 | Peptide=False
# [CHEMBL4740703] CID=162644985 | Peptide=False
# [CHEMBL4740681] CID=162644891 | Peptide=False
# [CHEMBL4740688] CID=162644895 | Peptide=False
# [CHEMBL4740690] CID=162644897 | Peptide=False
# [CHEMBL4740697] CID=71015 | Peptide=False
# CID fetch failed for CHEMBL4740731 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740731/cids/JSON
# [CHEMBL4740704] CID=136213647 | Peptide=False
# [CHEMBL4740678] CID=85090322 | Peptide=False
# [CHEMBL4740707] CID=99724396 | Peptide=False
# [CHEMBL4740715] CID=162645014 | Peptide=False
# [CHEMBL4740719] CID=162645016 | Peptide=False
# [CHEMBL4740720] CID=58459379 | Peptide=False
# [CHEMBL4740717] CID=137019328 | Peptide=False
# [CHEMBL4740722] CID=162645018 | Peptide=False
# [CHEMBL4740734] CID=162645028 | Peptide=False
# [CHEMBL4740736] CID=162645030 | Peptide=False
# [CHEMBL4740735] CID=162645029 | Peptide=False
# [CHEMBL4740741] CID=162645094 | Peptide=False
# [CHEMBL4740750] CID=150454520 | Peptide=False
# [CHEMBL4740752] CID=162645101 | Peptide=False
# [CHEMBL4740761] CID=162645177 | Peptide=False
# [CHEMBL4740731] CID=162645026 | Peptide=False
# Processing batch 26 of 3026...
# CID fetch failed for CHEMBL4740793 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740793/cids/JSON
# [CHEMBL4740775] CID=162645220 | Peptide=False
# [CHEMBL4740781] CID=162645224 | Peptide=False
# [CHEMBL4740786] CID=162644573 | Peptide=False
# [CHEMBL4740783] CID=147946566 | Peptide=False
# [CHEMBL4740787] CID=162644574 | Peptide=False
# [CHEMBL4740767] CID=162645214 | Peptide=False
# [CHEMBL4740776] CID=16735360 | Peptide=False
# [CHEMBL4740788] CID=132075096 | Peptide=False
# [CHEMBL4740785] CID=162644572 | Peptide=False
# [CHEMBL4740795] CID=162644579 | Peptide=False
# [CHEMBL4740805] CID=162644587 | Peptide=False
# [CHEMBL4740797] CID=126523873 | Peptide=False
# [CHEMBL4740821] CID=162644672 | Peptide=False
# [CHEMBL4740802] CID=147376647 | Peptide=False
# [CHEMBL4740820] CID=162644671 | Peptide=False
# [CHEMBL4740803] CID=162644585 | Peptide=False
# [CHEMBL4740824] CID=162644674 | Peptide=False
# [CHEMBL4740812] CID=162644615 | Peptide=False
# [CHEMBL4740793] CID=162644577 | Peptide=False
# [CHEMBL4740827] CID=118374540 | Peptide=False
# [CHEMBL4740829] CID=162644678 | Peptide=False
# [CHEMBL4740830] CID=145371869 | Peptide=False
# [CHEMBL4740843] CID=162646015 | Peptide=False
# [CHEMBL4740842] CID=162644717 | Peptide=False
# [CHEMBL4740836] CID=122598684 | Peptide=False
# Processing batch 27 of 3026...
# CID fetch failed for CHEMBL4740866 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740866/cids/JSON
# CID fetch failed for CHEMBL4740863 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740863/cids/JSON
# [CHEMBL4740854] CID=162646022 | Peptide=False
# [CHEMBL4740860] CID=162646206 | Peptide=False
# [CHEMBL4740848] CID=121269679 | Peptide=False
# [CHEMBL4740844] CID=162646016 | Peptide=False
# [CHEMBL4740862] CID=137110169 | Peptide=False
# [CHEMBL4740865] CID=162646208 | Peptide=False
# [CHEMBL4740873] CID=162646214 | Peptide=False
# [CHEMBL4740875] CID=162646216 | Peptide=False
# [CHEMBL4740878] CID=150933704 | Peptide=False
# [CHEMBL4740879] CID=137041591 | Peptide=False
# [CHEMBL4740882] CID=146314037 | Peptide=False
# [CHEMBL4740858] CID=137113931 | Peptide=False
# [CHEMBL4740898] CID=162646466 | Peptide=False
# [CHEMBL4740889] CID=162646332 | Peptide=False
# [CHEMBL4740894] CID=60328362 | Peptide=False
# [CHEMBL4740899] CID=156775103 | Peptide=False
# CID fetch failed for CHEMBL4740913 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740913/cids/JSON
# [CHEMBL4740900] CID=162646467 | Peptide=False
# [CHEMBL4740901] CID=162646468 | Peptide=True
# [CHEMBL4740908] CID=162646473 | Peptide=False
# [CHEMBL4740912] CID=162646476 | Peptide=False
# [CHEMBL4740866] CID=146315904 | Peptide=False
# [CHEMBL4740863] CID=155715222 | Peptide=False
# [CHEMBL4740916] CID=118374527 | Peptide=False
# [CHEMBL4740910] CID=162646475 | Peptide=False
# [CHEMBL4740913] CID=162646477 | Peptide=False
# Processing batch 28 of 3026...
# CID fetch failed for CHEMBL4740937 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740937/cids/JSON
# CID fetch failed for CHEMBL4740942 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740942/cids/JSON
# [CHEMBL4740923] CID=162646650 | Peptide=False
# [CHEMBL4740949] CID=162647236 | Peptide=False
# [CHEMBL4740926] CID=162646652 | Peptide=False
# [CHEMBL4740934] CID=162646761 | Peptide=False
# [CHEMBL4740950] CID=139558698 | Peptide=False
# [CHEMBL4740944] CID=162538040 | Peptide=False
# [CHEMBL4740932] CID=141351665 | Peptide=False
# [CHEMBL4740945] CID=141736091 | Peptide=False
# [CHEMBL4740955] CID=162647241 | Peptide=False
# [CHEMBL4740957] CID=162647243 | Peptide=False
# [CHEMBL4740956] CID=162647242 | Peptide=False
# [CHEMBL4740960] CID=162647387 | Peptide=False
# [CHEMBL4740971] CID=162647395 | Peptide=False
# [CHEMBL4740965] CID=162647391 | Peptide=False
# [CHEMBL4740961] CID=162647388 | Peptide=False
# [CHEMBL4740968] CID=162647393 | Peptide=False
# CID fetch failed for CHEMBL4740981 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740981/cids/JSON
# CID fetch failed for CHEMBL4740982 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740982/cids/JSON
# [CHEMBL4740976] CID=137111033 | Peptide=False
# CID fetch failed for CHEMBL4740987 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4740987/cids/JSON
# [CHEMBL4740937] CID=162646764 | Peptide=False
# [CHEMBL4740978] CID=254347 | Peptide=False
# [CHEMBL4740980] CID=118409069 | Peptide=False
# [CHEMBL4740942] CID=162646867 | Peptide=False
# [CHEMBL4740988] CID=162645306 | Peptide=False
# [CHEMBL4740981] CID=162645299 | Peptide=False
# [CHEMBL4740982] CID=162645300 | Peptide=False
# [CHEMBL4740987] CID=162645305 | Peptide=False
# Processing batch 29 of 3026...
# CID fetch failed for CHEMBL4741028 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4741028/cids/JSON
# [CHEMBL4741023] CID=162645581 | Peptide=False
# [CHEMBL4740995] CID=51349185 | Peptide=False
# [CHEMBL4741017] CID=162396019 | Peptide=False
# [CHEMBL4741003] CID=66690390 | Peptide=False
# [CHEMBL4741008] CID=1481082 | Peptide=False
# [CHEMBL4740998] CID=162645312 | Peptide=False
# [CHEMBL4741033] CID=162645588 | Peptide=False
# [CHEMBL4741006] CID=56960507 | Peptide=False
# [CHEMBL4741000] CID=162645314 | Peptide=True
# CID fetch failed for CHEMBL4741063 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4741063/cids/JSON
# [CHEMBL4741034] CID=162645589 | Peptide=True
# [CHEMBL4741036] CID=137112317 | Peptide=False
# [CHEMBL4741039] CID=162645593 | Peptide=False
# [CHEMBL4741051] CID=162645892 | Peptide=False
# [CHEMBL4741060] CID=162645899 | Peptide=False
# [CHEMBL4741061] CID=162645900 | Peptide=False
# [CHEMBL4741062] CID=162645901 | Peptide=True
# CID fetch failed for CHEMBL4741076 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4741076/cids/JSON
# CID fetch failed for CHEMBL4741078 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4741078/cids/JSON
# [CHEMBL4741069] CID=153141399 | Peptide=False
# [CHEMBL4741028] CID=155201739 | Peptide=False
# [CHEMBL4741070] CID=162645908 | Peptide=False
# [CHEMBL4741075] CID=162645913 | Peptide=False
# [CHEMBL4741048] CID=40954109 | Peptide=False
# [CHEMBL4741079] CID=162645916 | Peptide=False
# [CHEMBL4741063] CID=124155401 | Peptide=False
# [CHEMBL4741076] CID=67168502 | Peptide=False
# [CHEMBL4741078] CID=162645915 | Peptide=False
# Processing batch 30 of 3026...
# [CHEMBL4741108] CID=162646335 | Peptide=False
# [CHEMBL4741094] CID=14914794 | Peptide=False
# [CHEMBL4741095] CID=162646226 | Peptide=False
# [CHEMBL4741100] CID=137109243 | Peptide=False
# [CHEMBL4741098] CID=162646228 | Peptide=False
# [CHEMBL4741096] CID=162646227 | Peptide=False
# [CHEMBL4741097] CID=141419108 | Peptide=False
# [CHEMBL4741090] CID=162646032 | Peptide=False
# [CHEMBL4741089] CID=162646031 | Peptide=False
# [CHEMBL4741101] CID=162646230 | Peptide=False
# [CHEMBL4741114] CID=162646341 | Peptide=False
# [CHEMBL4741115] CID=162646342 | Peptide=False
# [CHEMBL4741134] CID=71667612 | Peptide=False
# [CHEMBL4741140] CID=162646492 | Peptide=False
# [CHEMBL4741141] CID=134179072 | Peptide=False
# [CHEMBL4741142] CID=162646653 | Peptide=False
# [CHEMBL4741143] CID=162646654 | Peptide=False
# [CHEMBL4741155] CID=162646769 | Peptide=False
# [CHEMBL4741145] CID=162646656 | Peptide=False
# [CHEMBL4741154] CID=162646768 | Peptide=False
# [CHEMBL4741163] CID=162646999 | Peptide=False
# [CHEMBL4741159] CID=54430554 | Peptide=False
# [CHEMBL4741162] CID=162646998 | Peptide=False
# [CHEMBL4741180] CID=162645323 | Peptide=False
# [CHEMBL4741174] CID=118395981 | Peptide=False
# Processing batch 31 of 3026...
# CID fetch failed for CHEMBL4741213 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4741213/cids/JSON
# [CHEMBL4741181] CID=162645324 | Peptide=False[CHEMBL4741196] CID=162645600 | Peptide=False
#
# ...
# [CHEMBL4759531] CID=162658269 | Peptide=False
# [CHEMBL4759471] CID=162657872 | Peptide=True
# [CHEMBL4759518] CID=162658176 | Peptide=False
# Processing batch 243 of 3026...
# CID fetch failed for CHEMBL4759584 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759584/cids/JSON
# [CHEMBL4759576] CID=162658792 | Peptide=False
# [CHEMBL4759563] CID=162658614 | Peptide=False
# [CHEMBL4759591] CID=132071440 | Peptide=False
# [CHEMBL4759549] CID=141488804 | Peptide=False
# [CHEMBL4759581] CID=162657466 | Peptide=False
# [CHEMBL4759554] CID=162658606 | Peptide=False
# [CHEMBL4759566] CID=162658699 | Peptide=False
# [CHEMBL4759579] CID=162658963 | Peptide=False
# [CHEMBL4759587] CID=146444615 | Peptide=False
# CID fetch failed for CHEMBL4759615 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759615/cids/JSON
# [CHEMBL4759600] CID=162657580 | Peptide=True
# [CHEMBL4759592] CID=126508790 | Peptide=False
# [CHEMBL4759603] CID=162657583 | Peptide=False
# [CHEMBL4759620] CID=162371666 | Peptide=False
# [CHEMBL4759625] CID=162657787 | Peptide=False
# [CHEMBL4759623] CID=162657786 | Peptide=False
# [CHEMBL4759611] CID=162657688 | Peptide=False
# CID fetch failed for CHEMBL4759584 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759584/cids/JSON
# [CHEMBL4759606] CID=162657585 | Peptide=False
# [CHEMBL4759628] CID=162657790 | Peptide=False
# [CHEMBL4759630] CID=137110696 | Peptide=False
# [CHEMBL4759629] CID=132257069 | Peptide=False
# [CHEMBL4759633] CID=162657889 | Peptide=False
# [CHEMBL4759641] CID=162657895 | Peptide=False
# [CHEMBL4759640] CID=162657894 | Peptide=False
# [CHEMBL4759615] CID=162657691 | Peptide=False
# [CHEMBL4759584] CID=162657468 | Peptide=False
# Processing batch 244 of 3026...
# [CHEMBL4759645] CID=70979369 | Peptide=False
# [CHEMBL4759655] CID=162658097 | Peptide=True
# [CHEMBL4759652] CID=162658094 | Peptide=False
# [CHEMBL4759676] CID=162658180 | Peptide=False
# [CHEMBL4759664] CID=162658105 | Peptide=False
# [CHEMBL4759665] CID=132021720 | Peptide=False
# [CHEMBL4759666] CID=155757122 | Peptide=False
# [CHEMBL4759650] CID=138513766 | Peptide=False
# [CHEMBL4759663] CID=162658104 | Peptide=False
# [CHEMBL4759680] CID=162658275 | Peptide=True
# [CHEMBL4759685] CID=162658279 | Peptide=False
# [CHEMBL4759667] CID=162658107 | Peptide=False
# [CHEMBL4759690] CID=57524702 | Peptide=False
# [CHEMBL4759695] CID=162658518 | Peptide=False
# [CHEMBL4759692] CID=162658516 | Peptide=False
# [CHEMBL4759697] CID=162658520 | Peptide=False
# [CHEMBL4759705] CID=162658706 | Peptide=False
# [CHEMBL4759704] CID=162658705 | Peptide=False
# [CHEMBL4759701] CID=162658620 | Peptide=False
# [CHEMBL4759711] CID=162658794 | Peptide=False
# [CHEMBL4759727] CID=137113212 | Peptide=False
# [CHEMBL4759730] CID=10108884 | Peptide=False
# [CHEMBL4759728] CID=162658967 | Peptide=False
# [CHEMBL4759724] CID=162658965 | Peptide=False
# [CHEMBL4759732] CID=132060056 | Peptide=False
# Processing batch 245 of 3026...
# CID fetch failed for CHEMBL4759754 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759754/cids/JSON
# CID fetch failed for CHEMBL4759758 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759758/cids/JSON
# [CHEMBL4759740] CID=162657479 | Peptide=False
# [CHEMBL4759737] CID=162657477 | Peptide=False
# [CHEMBL4759748] CID=162657486 | Peptide=False
# [CHEMBL4759734] CID=162657475 | Peptide=False
# [CHEMBL4759743] CID=162657481 | Peptide=False
# [CHEMBL4759751] CID=162657586 | Peptide=False
# [CHEMBL4759733] CID=162657474 | Peptide=False
# [CHEMBL4759747] CID=162657485 | Peptide=False
# [CHEMBL4759769] CID=16311133 | Peptide=False
# [CHEMBL4759778] CID=162658116 | Peptide=False
# [CHEMBL4759781] CID=66686484 | Peptide=False
# [CHEMBL4759787] CID=162658185 | Peptide=False
# [CHEMBL4759782] CID=155721836 | Peptide=False
# [CHEMBL4759791] CID=162658189 | Peptide=False
# [CHEMBL4759784] CID=162658184 | Peptide=False
# [CHEMBL4759786] CID=122669286 | Peptide=False
# CID fetch failed for CHEMBL4759754 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759754/cids/JSON
# CID fetch failed for CHEMBL4759758 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759758/cids/JSON
# [CHEMBL4759797] CID=85963135 | Peptide=False
# [CHEMBL4759798] CID=162658194 | Peptide=False
# [CHEMBL4759800] CID=162658195 | Peptide=False
# [CHEMBL4759802] CID=126593143 | Peptide=False
# [CHEMBL4759810] CID=134401410 | Peptide=False
# [CHEMBL4759817] CID=162658289 | Peptide=False
# [CHEMBL4759814] CID=85090330 | Peptide=False
# [CHEMBL4759754] CID=138558205 | Peptide=False
# [CHEMBL4759758] CID=126714057 | Peptide=False
# Processing batch 246 of 3026...
# CID fetch failed for CHEMBL4759841 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759841/cids/JSON
# [CHEMBL4759819] CID=162658393 | Peptide=False
# [CHEMBL4759820] CID=162658394 | Peptide=False
# [CHEMBL4759827] CID=5704945 | Peptide=False
# [CHEMBL4759834] CID=162475031 | Peptide=False
# [CHEMBL4759833] CID=162658526 | Peptide=False
# [CHEMBL4759832] CID=162658525 | Peptide=False
# [CHEMBL4759824] CID=162658397 | Peptide=False
# [CHEMBL4759839] CID=846141 | Peptide=False
# [CHEMBL4759836] CID=57524937 | Peptide=False
# [CHEMBL4759847] CID=162383166 | Peptide=False
# [CHEMBL4759851] CID=162658623 | Peptide=False
# [CHEMBL4759850] CID=162658622 | Peptide=False
# [CHEMBL4759848] CID=126531179 | Peptide=False
# [CHEMBL4759858] CID=162658712 | Peptide=False
# [CHEMBL4759856] CID=21648335 | Peptide=False
# [CHEMBL4759866] CID=162658717 | Peptide=False
# [CHEMBL4759861] CID=162371654 | Peptide=False
# [CHEMBL4759854] CID=162658710 | Peptide=False
# [CHEMBL4759867] CID=162658718 | Peptide=False
# [CHEMBL4759872] CID=7074259 | Peptide=False
# [CHEMBL4759841] CID=162658530 | Peptide=False
# [CHEMBL4759868] CID=162658719 | Peptide=False
# [CHEMBL4759873] CID=162658801 | Peptide=False
# [CHEMBL4759877] CID=156061816 | Peptide=True
# [CHEMBL4759876] CID=5743371 | Peptide=False
# Processing batch 247 of 3026...
# CID fetch failed for CHEMBL4759893 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759893/cids/JSON
# CID fetch failed for CHEMBL4759886 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759886/cids/JSON
# [CHEMBL4759878] CID=162658802 | Peptide=False
# [CHEMBL4759879] CID=162658804 | Peptide=False
# [CHEMBL4759882] CID=162658806 | Peptide=True
# [CHEMBL4759896] CID=118234443 | Peptide=False
# [CHEMBL4759880] CID=156198715 | Peptide=False
# [CHEMBL4759891] CID=162657380 | Peptide=False
# [CHEMBL4759889] CID=162657379 | Peptide=False
# [CHEMBL4759888] CID=162657378 | Peptide=False
# CID fetch failed for CHEMBL4759917 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759917/cids/JSON
# [CHEMBL4759907] CID=162657389 | Peptide=False
# [CHEMBL4759911] CID=162657489 | Peptide=False
# [CHEMBL4759910] CID=118684967 | Peptide=False
# [CHEMBL4759904] CID=162657387 | Peptide=False
# [CHEMBL4759913] CID=146552991 | Peptide=False
# [CHEMBL4759915] CID=162506733 | Peptide=False
# [CHEMBL4759912] CID=57523080 | Peptide=False
# [CHEMBL4759893] CID=162657382 | Peptide=False
# [CHEMBL4759886] CID=132056883 | Peptide=False
# [CHEMBL4759919] CID=149197347 | Peptide=False
# [CHEMBL4759920] CID=160437590 | Peptide=False
# [CHEMBL4759925] CID=162657988 | Peptide=False
# [CHEMBL4759924] CID=114333318 | Peptide=False
# [CHEMBL4759927] CID=162657990 | Peptide=False
# [CHEMBL4759926] CID=162657989 | Peptide=False
# [CHEMBL4759930] CID=162657992 | Peptide=False
# [CHEMBL4759917] CID=118935130 | Peptide=False
# Processing batch 248 of 3026...
# [CHEMBL4759940] CID=162658198 | Peptide=False
# [CHEMBL4759937] CID=139559352 | Peptide=False
# [CHEMBL4759950] CID=90209609 | Peptide=False
# [CHEMBL4759932] CID=162658118 | Peptide=False
# [CHEMBL4759957] CID=153321108 | Peptide=False
# [CHEMBL4759952] CID=162658401 | Peptide=False
# [CHEMBL4759974] CID=156700975 | Peptide=False
# [CHEMBL4759953] CID=162658402 | Peptide=False
# [CHEMBL4759968] CID=145998133 | Peptide=False
# [CHEMBL4759959] CID=162658406 | Peptide=False
# CID fetch failed for CHEMBL4759997 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4759997/cids/JSON
# CID fetch failed for CHEMBL4760010 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760010/cids/JSON
# [CHEMBL4759975] CID=162658416 | Peptide=False
# CID fetch failed for CHEMBL4760013 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760013/cids/JSON
# [CHEMBL4759980] CID=146538577 | Peptide=False
# [CHEMBL4759992] CID=69670052 | Peptide=False
# [CHEMBL4759993] CID=162658721 | Peptide=False
# [CHEMBL4760004] CID=45889075 | Peptide=False
# [CHEMBL4759991] CID=153585534 | Peptide=False
# [CHEMBL4760014] CID=162658812 | Peptide=False
# [CHEMBL4760027] CID=118320530 | Peptide=False
# [CHEMBL4760047] CID=162657496 | Peptide=False
# [CHEMBL4760028] CID=162657390 | Peptide=False
# [CHEMBL4759989] CID=162658634 | Peptide=False
# [CHEMBL4760053] CID=162657503 | Peptide=False
# [CHEMBL4759997] CID=156095829 | Peptide=False
# [CHEMBL4760013] CID=146558465 | Peptide=False
# [CHEMBL4760010] CID=162658810 | Peptide=False
# Processing batch 249 of 3026...
# CID fetch failed for CHEMBL4760071 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760071/cids/JSON
# [CHEMBL4760090] CID=162657997 | Peptide=False
# [CHEMBL4760074] CID=162657599 | Peptide=False
# [CHEMBL4760064] CID=162657590 | Peptide=False
# [CHEMBL4760076] CID=137040405 | Peptide=False
# [CHEMBL4760082] CID=162657901 | Peptide=False
# [CHEMBL4760058] CID=162657508 | Peptide=False
# [CHEMBL4760080] CID=162657899 | Peptide=False
# [CHEMBL4760089] CID=132056674 | Peptide=False
# [CHEMBL4760056] CID=162657507 | Peptide=False
# CID fetch failed for CHEMBL4760109 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760109/cids/JSON
# [CHEMBL4760095] CID=162658001 | Peptide=False
# [CHEMBL4760098] CID=24794583 | Peptide=False
# [CHEMBL4760103] CID=146635364 | Peptide=False
# [CHEMBL4760105] CID=126720397 | Peptide=False
# [CHEMBL4760101] CID=25144777 | Peptide=False
# [CHEMBL4760102] CID=141488879 | Peptide=False
# [CHEMBL4760108] CID=162658125 | Peptide=False
# [CHEMBL4760106] CID=162658123 | Peptide=False
# [CHEMBL4760110] CID=137116763 | Peptide=False
# [CHEMBL4760111] CID=162658127 | Peptide=False
# [CHEMBL4760112] CID=162658128 | Peptide=False
# [CHEMBL4760071] CID=162657596 | Peptide=False
# [CHEMBL4760122] CID=162658298 | Peptide=False
# [CHEMBL4760118] CID=162658201 | Peptide=False
# [CHEMBL4760120] CID=162658296 | Peptide=True
# [CHEMBL4760109] CID=162658126 | Peptide=False
# Processing batch 250 of 3026...
# CID fetch failed for CHEMBL4760138 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760138/cids/JSON
# [CHEMBL4760127] CID=162658304 | Peptide=True
# [CHEMBL4760123] CID=162658299 | Peptide=False
# [CHEMBL4760126] CID=162658303 | Peptide=False
# [CHEMBL4760153] CID=162658533 | Peptide=False
# [CHEMBL4760133] CID=162658308 | Peptide=True
# [CHEMBL4760131] CID=126488347 | Peptide=False
# [CHEMBL4760128] CID=162658305 | Peptide=False
# [CHEMBL4760141] CID=2839889 | Peptide=False
# [CHEMBL4760143] CID=118320506 | Peptide=False
# [CHEMBL4760156] CID=7121010 | Peptide=False
# [CHEMBL4760159] CID=57524936 | Peptide=False
# [CHEMBL4760165] CID=162658541 | Peptide=False
# [CHEMBL4760192] CID=162658728 | Peptide=False
# [CHEMBL4760176] CID=162658639 | Peptide=False
# [CHEMBL4760182] CID=162658644 | Peptide=False
# [CHEMBL4760183] CID=89444841 | Peptide=False
# [CHEMBL4760170] CID=154654067 | Peptide=False
# [CHEMBL4760164] CID=162658540 | Peptide=False
# [CHEMBL4760198] CID=137109812 | Peptide=False
# [CHEMBL4760193] CID=162658729 | Peptide=False
# [CHEMBL4760138] CID=162658310 | Peptide=False
# [CHEMBL4760200] CID=141488656 | Peptide=False
# [CHEMBL4760204] CID=162658867 | Peptide=True
# [CHEMBL4760211] CID=162657401 | Peptide=False
# [CHEMBL4760220] CID=155192028 | Peptide=False
# Processing batch 251 of 3026...
# CID fetch failed for CHEMBL4760246 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760246/cids/JSON
# [CHEMBL4760244] CID=9827539 | Peptide=False
# [CHEMBL4760233] CID=162657414 | Peptide=False
# [CHEMBL4760227] CID=162657412 | Peptide=False
# [CHEMBL4760226] CID=162657411 | Peptide=False
# [CHEMBL4760231] CID=162515952 | Peptide=False
# [CHEMBL4760228] CID=146424963 | Peptide=False
# [CHEMBL4760236] CID=162657512 | Peptide=False
# [CHEMBL4760222] CID=162657409 | Peptide=False
# [CHEMBL4760255] CID=118395999 | Peptide=False
# [CHEMBL4760259] CID=953741 | Peptide=False
# [CHEMBL4760284] CID=162657797 | Peptide=False
# [CHEMBL4760275] CID=162657712 | Peptide=False
# [CHEMBL4760288] CID=156165769 | Peptide=False
# [CHEMBL4760274] CID=155683338 | Peptide=False
# [CHEMBL4760297] CID=162657904 | Peptide=False
# [CHEMBL4760287] CID=54589397 | Peptide=False
# [CHEMBL4760286] CID=129137287 | Peptide=False
# [CHEMBL4760293] CID=145998145 | Peptide=False
# [CHEMBL4760246] CID=137412267 | Peptide=False
# [CHEMBL4760298] CID=162657905 | Peptide=False
# [CHEMBL4760299] CID=162657906 | Peptide=False
# [CHEMBL4760304] CID=118440466 | Peptide=False
# [CHEMBL4760306] CID=162658202 | Peptide=False
# [CHEMBL4760312] CID=162658315 | Peptide=False
# [CHEMBL4760323] CID=162658428 | Peptide=False
# Processing batch 252 of 3026...
# CID fetch failed for CHEMBL4760367 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760367/cids/JSON
# [CHEMBL4760344] CID=118286447 | Peptide=False
# [CHEMBL4760325] CID=155925936 | Peptide=False
# [CHEMBL4760340] CID=162658550 | Peptide=False
# [CHEMBL4760328] CID=162658432 | Peptide=False
# [CHEMBL4760352] CID=162658655 | Peptide=False
# [CHEMBL4760364] CID=162658875 | Peptide=False
# [CHEMBL4760357] CID=162658733 | Peptide=False
# [CHEMBL4760330] CID=162658434 | Peptide=False
# [CHEMBL4760355] CID=85090335 | Peptide=False
# CID fetch failed for CHEMBL4760373 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760373/cids/JSON
# [CHEMBL4760370] CID=129048510 | Peptide=False
# [CHEMBL4760380] CID=155099253 | Peptide=False
# [CHEMBL4760384] CID=155681503 | Peptide=False
# [CHEMBL4760389] CID=118684960 | Peptide=False
# [CHEMBL4760381] CID=162658890 | Peptide=False
# [CHEMBL4760391] CID=72549795 | Peptide=False
# [CHEMBL4760396] CID=162657532 | Peptide=True
# [CHEMBL4760399] CID=162657535 | Peptide=False
# [CHEMBL4760367] CID=154702045 | Peptide=False
# [CHEMBL4760400] CID=162657536 | Peptide=False
# [CHEMBL4760416] CID=162657611 | Peptide=False
# [CHEMBL4760403] CID=162657601 | Peptide=False
# [CHEMBL4760412] CID=162657608 | Peptide=False
# [CHEMBL4760429] CID=141488856 | Peptide=False
# [CHEMBL4760430] CID=162657803 | Peptide=False
# [CHEMBL4760373] CID=162658882 | Peptide=False
# Processing batch 253 of 3026...
# CID fetch failed for CHEMBL4760449 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760449/cids/JSON
# [CHEMBL4760435] CID=162657807 | Peptide=False
# [CHEMBL4760436] CID=136214328 | Peptide=False
# [CHEMBL4760441] CID=137109909 | Peptide=False
# [CHEMBL4760437] CID=137019232 | Peptide=False
# [CHEMBL4760434] CID=162657806 | Peptide=False
# [CHEMBL4760438] CID=154640734 | Peptide=False
# [CHEMBL4760452] CID=141760502 | Peptide=False
# [CHEMBL4760440] CID=90389713 | Peptide=False
# [CHEMBL4760447] CID=155817683 | Peptide=False
# CID fetch failed for CHEMBL4760472 — 503 Server Error: PUGREST.ServerBusy for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4760472/cids/JSON
# [CHEMBL4760455] CID=162658011 | Peptide=False
