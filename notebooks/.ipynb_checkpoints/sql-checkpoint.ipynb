# %%
import chembl_downloader
import json
import time
import re
import os
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from IPython.core.magic import register_cell_magic  # Needed for %%skip Jupyter cell magic

@register_cell_magic
def skip(line, cell):
    return

sql_chembl_cache_path = "data/sql_chembl_cache.parquet"

sql_chembl = """
SELECT
    a.pchembl_value AS "pChEMBL",
    a.potential_duplicate AS "Duplicate? (1/0)",
    a.data_validity_comment AS "Data validity comment",
    ass.chembl_id AS "Assay ChEMBL ID",
    ass.confidence_score,
    dm.mechanism_of_action AS "MOA",
    dm.direct_interaction AS "Direct interaction (1/0)?",
    dm.disease_efficacy AS "Disease efficacy (1/0)?",
    md.chembl_id AS "Molecule ChEMBL ID",
    md.pref_name AS "Preferred name",
    md.molecule_type AS "Molecule type",
    md.max_phase AS "Max phase",
    md.availability_type AS "Availability (2/1/0/-1/-2)?",
    md.therapeutic_flag AS "Therapeutic (1/0)?",
    md.first_in_class AS "First-in-class (1/0/-1)?",
    md.chemical_probe AS "Chemical probe (1/0)?",
    md.orphan AS "Orphan (1/0/-1)?",
    cs.canonical_smiles AS "Canonical SMILES",
    cp.full_mwt AS "Molecular weight of full compound",
    cp.full_molformula AS "Molecular formula of full compound",
    md_parent.chembl_id AS "Parent compound ChEMBL ID",
    md_parent.molecule_type AS parent_molecule_type,
    md_active.chembl_id AS "Active ingredient ChEMBL ID",
    mh.molregno,
    mh.parent_molregno,
    mh.active_molregno,
    td.chembl_id AS "Target ChEMBL ID"
FROM activities a
LEFT JOIN assays ass ON a.assay_id = ass.assay_id
LEFT JOIN target_dictionary td ON ass.tid = td.tid
LEFT JOIN drug_mechanism dm ON a.molregno = dm.molregno
LEFT JOIN molecule_dictionary md ON a.molregno = md.molregno
LEFT JOIN compound_structures cs ON md.molregno = cs.molregno
LEFT JOIN compound_properties cp ON cs.molregno = cp.molregno
LEFT JOIN molecule_hierarchy mh ON md.molregno = mh.molregno
LEFT JOIN molecule_dictionary md_parent ON mh.parent_molregno = md_parent.molregno
LEFT JOIN molecule_dictionary md_active ON mh.active_molregno = md_active.molregno
WHERE a.pchembl_value IS NOT NULL
  AND td.target_type = 'SINGLE PROTEIN'
  AND td.organism = 'Homo sapiens';
"""
if os.path.exists(sql_chembl_cache_path):
    print("Loading cached ChEMBL data...")
    df_raw = pd.read_parquet(sql_chembl_cache_path)
    print("Data loaded.")
else:
    print("Running SQL query...")
    df_raw = chembl_downloader.query(sql_chembl)
    print("Query complete. Saving to cache...")
    df_raw.to_parquet(sql_chembl_cache_path, index=False)
    print("Save complete.")

for col in df_raw.columns:
    print('\nColumn:', df_raw[col].value_counts(dropna=False).head(10))  # Show top 10 frequent values
# Out:
# Loading cached ChEMBL data...
# Data loaded.
#
# Column: pChEMBL
# 4.40    62704
# 4.50    52019
# 4.60    51015
# 4.45    41123
# 4.90    40848
# 4.80    37562
# 5.00    37292
# 4.55    35516
# 4.70    30871
# 4.85    26617
# Name: count, dtype: int64
#
# Column: Duplicate? (1/0)
# 0    2005843
# 1      95016
# Name: count, dtype: int64
#
# Column: Data validity comment
# None                  2100539
# Manually validated        320
# Name: count, dtype: int64
#
# Column: Assay ChEMBL ID
# CHEMBL1614458    76019
# CHEMBL1614421    49886
# CHEMBL1613914    39824
# CHEMBL1614544    36448
# CHEMBL1613842    33737
# CHEMBL1614038    24248
# CHEMBL1614502    24121
# CHEMBL1614079    23084
# CHEMBL1613838    22000
# CHEMBL1614250    20674
# Name: count, dtype: int64
#
# Column: confidence_score
# 9    1623093
# 8     477766
# Name: count, dtype: int64
#
# Column: MOA
# None                                                     1961774
# Tyrosine-protein kinase receptor FLT3 inhibitor             7102
# Stem cell growth factor receptor inhibitor                  4698
# Tyrosine-protein kinase receptor RET inhibitor              3658
# Platelet-derived growth factor receptor inhibitor           3641
# Vascular endothelial growth factor receptor inhibitor       3599
# Carbonic anhydrase II inhibitor                             3245
# Carbonic anhydrase IV inhibitor                             3064
# Serotonin 2a (5-HT2a) receptor antagonist                   2876
# Carbonic anhydrase I inhibitor                              2794
# Name: count, dtype: int64
#
# Column: Direct interaction (1/0)?
# NaN    1961774
# 1.0     139085
# Name: count, dtype: int64
#
# Column: Disease efficacy (1/0)?
# NaN    1961774
# 1.0     139085
# Name: count, dtype: int64
#
# Column: Molecule ChEMBL ID
# CHEMBL535        11025
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3360
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2448
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: Preferred name
# None             1879423
# SUNITINIB          11025
# ACETAZOLAMIDE       8632
# VORINOSTAT          5840
# LESTAURTINIB        5088
# MIDOSTAURIN         3385
# VANDETANIB          3360
# DOVITINIB           2660
# FORETINIB           2592
# ALVOCIDIB           2448
# Name: count, dtype: int64
#
# Column: Molecule type
# Small molecule     1852733
# Unknown             155576
# None                 74645
# Protein              17860
# Oligosaccharide         40
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Max phase
#  NaN    1918899
#  4.0     111910
#  2.0      31593
#  3.0      24677
#  1.0      10744
# -1.0       2908
#  0.5        128
# Name: count, dtype: int64
#
# Column: Availability (2/1/0/-1/-2)?
# -1.0    1898877
#  NaN      97788
#  1.0      93271
#  0.0       4223
# -2.0       4090
#  2.0       2610
# Name: count, dtype: int64
#
# Column: Therapeutic (1/0)?
# 0    1990748
# 1     110111
# Name: count, dtype: int64
#
# Column: First-in-class (1/0/-1)?
# -1    1918899
#  0     172021
#  1       9939
# Name: count, dtype: int64
#
# Column: Chemical probe (1/0)?
# 0    2086672
# 1      14187
# Name: count, dtype: int64
#
# Column: Orphan (1/0/-1)?
# -1    1918899
#  0     174942
#  1       7018
# Name: count, dtype: int64
#
# Column: Canonical SMILES
# CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C                                        11025
# CC(=O)Nc1nnc(S(N)(=O)=O)s1                                                                      8632
# O=C(CCCCCCC(=O)Nc1ccccc1)NO                                                                     5840
# C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)CNC4=O                              5088
# CO[C@@H]1[C@H](N(C)C(=O)c2ccccc2)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4     3385
# COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1                                             3360
# CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1                                         2660
# None                                                                                            2628
# COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1                        2592
# CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@H](O)C1                                     2448
# Name: count, dtype: int64
#
# Column: Molecular weight of full compound
# 398.48    11369
# 222.25     8844
# 264.32     6053
# 439.47     5362
# 570.65     3444
# 475.36     3418
# 392.44     3092
# 466.54     2794
# 401.85     2692
# NaN        2628
# Name: count, dtype: int64
#
# Column: Molecular formula of full compound
# C22H27FN4O2      11140
# C4H6N4O3S2        8632
# C14H20N2O3        5912
# C26H21N3O4        5152
# C35H30N4O4        3387
# C22H24BrFN4O2     3379
# C21H21FN6O        2746
# None              2628
# C34H34F2N4O6      2592
# C21H20ClNO5       2543
# Name: count, dtype: int64
#
# Column: Parent compound ChEMBL ID
# CHEMBL535        11033
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3367
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2448
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: parent_molecule_type
# Small molecule     1854239
# Unknown             155036
# None                 73668
# Protein              17868
# Oligosaccharide         43
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Active ingredient ChEMBL ID
# CHEMBL535        11033
# CHEMBL20          8632
# CHEMBL98          5840
# CHEMBL603469      5088
# CHEMBL608533      3385
# CHEMBL24828       3367
# CHEMBL522892      2660
# CHEMBL1230609     2592
# CHEMBL428690      2450
# CHEMBL388978      2188
# Name: count, dtype: int64
#
# Column: molregno
# 13048     11025
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3360
# 494834     2660
# 692959     2592
# 14366      2448
# 373381     2188
# Name: count, dtype: int64
#
# Column: parent_molregno
# 13048     11033
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3367
# 494834     2660
# 692959     2592
# 14366      2448
# 373381     2188
# Name: count, dtype: int64
#
# Column: active_molregno
# 13048     11033
# 1125       8632
# 11305      5840
# 597145     5088
# 608601     3385
# 33576      3367
# 494834     2660
# 692959     2592
# 14366      2450
# 373381     2188
# Name: count, dtype: int64
#
# Column: Target ChEMBL ID
# CHEMBL1293224    95232
# CHEMBL3577       76494
# CHEMBL1293226    40146
# CHEMBL1293235    36863
# CHEMBL2608       35167
# CHEMBL1293232    33837
# CHEMBL340        29020
# CHEMBL1963       28951
# CHEMBL4096       26274
# CHEMBL1293255    24701
# Name: count, dtype: int64

# %%
df_raw = df_raw[df_raw["Duplicate? (1/0)"] != 1].copy()

active_ingredients = set(df_raw.loc[df_raw["molregno"] != df_raw["active_molregno"], "active_molregno"])
df_raw["Active ingredient of prodrug?"] = df_raw["molregno"].apply(lambda x: "Yes" if x in active_ingredients else "No")

def classify_relationship(row):
    if pd.isna(row["parent_molregno"]):
        return "No parent info"
    if row["molregno"] == row["parent_molregno"] == row["active_molregno"]:
        return "Parent compound"
    if row["molregno"] != row["parent_molregno"] and row["active_molregno"] == row["parent_molregno"]:
        return "Salt form"
    if row["molregno"] == row["parent_molregno"] and row["active_molregno"] != row["parent_molregno"]:
        return "Prodrug"
    if row["molregno"] != row["parent_molregno"] and row["active_molregno"] != row["parent_molregno"]:
        return "Prodrug salt form"
    return "Other"

df_raw["Relationship"] = df_raw.apply(classify_relationship, axis=1)

def resolve_molecule_type(row):
    mt, mtp = row["Molecule type"], row["parent_molecule_type"]
    if pd.notnull(mt) and mt.lower() != "unknown":
        return mt
    if pd.notnull(mtp) and mtp.lower() != "unknown":
        return mtp
    if any(pd.notnull(row.get(k)) for k in ["Canonical SMILES", "Preferred name", 
                                            "Molecular formula of full compound", 
                                            "Molecular weight of full compound"]):
        return "TBD"
    return None

df_raw["Molecule type"] = df_raw.apply(resolve_molecule_type, axis=1)
df_dropped = df_raw[df_raw["Molecule type"].isna()].copy()
dropped_ids = df_dropped["Molecule ChEMBL ID"].dropna().unique().tolist()

rescued_cache_path = "data/df_rescued_cache.csv"
if os.path.exists(rescued_cache_path):
    df_rescued_cache = pd.read_csv(rescued_cache_path)
    rescued_cache_dict = {row["Molecule ChEMBL ID"]: row for _, row in df_rescued_cache.iterrows()}
else:
    df_rescued_cache = pd.DataFrame(columns=["Molecule ChEMBL ID", "Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW"])
    rescued_cache_dict = {}

def rescue_from_chembl(chembl_id):
    url = f"https://www.ebi.ac.uk/chembl/compound_report_card/{chembl_id}/"
    try:
        response = requests.get(url, timeout=10)
        if response.status_code != 200:
            return (chembl_id, None, None, None, None)
        soup = BeautifulSoup(response.text, "html.parser")
        json_tag = soup.find("script", {"type": "application/ld+json"})
        if not json_tag:
            return (chembl_id, None, None, None, None)
        data = json.loads(json_tag.string)
        formula = data.get("molecularFormula")
        smiles = data.get("smiles")
        name = data.get("name")
        weight = data.get("molecularWeight")
        return (chembl_id, formula, smiles, name, weight)
    except Exception as e:
        print(f"Error for {chembl_id}: {e}")
        return (chembl_id, None, None, None, None)

rescued_rows = []
unrecoverable_ids = []
for chembl_id in dropped_ids:
    if chembl_id in rescued_cache_dict:
        row = rescued_cache_dict[chembl_id]
        rescued = (
            chembl_id, 
            row["Rescued Formula"], 
            row["Rescued SMILES"], 
            row["Rescued Name"], 
            row["Rescued MW"]
        )
    else:
        rescued = rescue_from_chembl(chembl_id)
        time.sleep(0.5)
        rescued_cache_dict[chembl_id] = {
            "Molecule ChEMBL ID": chembl_id,
            "Rescued Formula": rescued[1],
            "Rescued SMILES": rescued[2],
            "Rescued Name": rescued[3],
            "Rescued MW": rescued[4]
        }
    values = [rescued[1], rescued[2], rescued[3], rescued[4]]
    if any([pd.notna(v) and v != 'nan' for v in values]):
        print(f"Rescued {rescued[0]}: Formula={rescued[1]}, SMILES={rescued[2]}, Name={rescued[3]}, MW={rescued[4]}\n")
    else:
        unrecoverable_ids.append(chembl_id)
    rescued_rows.append(rescued)

df_rescued_cache = pd.DataFrame.from_dict(rescued_cache_dict, orient="index")
df_rescued_cache.to_csv(rescued_cache_path, index=False)

df_rescued = pd.DataFrame(rescued_rows, columns=["Molecule ChEMBL ID", "Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW"])
df_raw = df_raw.merge(df_rescued, on="Molecule ChEMBL ID", how="left")
df_raw["Molecular formula of full compound"] = df_raw["Molecular formula of full compound"].combine_first(df_raw["Rescued Formula"])
df_raw["Canonical SMILES"] = df_raw["Canonical SMILES"].combine_first(df_raw["Rescued SMILES"])
df_raw["Preferred name"] = df_raw["Preferred name"].combine_first(df_raw["Rescued Name"])
df_raw["Molecular weight of full compound"] = df_raw["Molecular weight of full compound"].combine_first(df_raw["Rescued MW"])

df_raw["Molecule type"] = df_raw.apply(resolve_molecule_type, axis=1)
final_dropped_df = df_raw[df_raw["Molecule type"].isna()]
final_dropped_ids = final_dropped_df["Molecule ChEMBL ID"].dropna().unique()
pd.Series(final_dropped_ids).to_csv("data/final_dropped_ids.csv", index=False)
n_dropped = final_dropped_df.shape[0]
df_raw = df_raw[df_raw["Molecule type"].notna()].copy()
print(f"Dropped {n_dropped} rows where Molecule type was None and unrecoverable.")

df_chembl = df_raw.drop(columns=[
    "parent_molecule_type", "molregno", "parent_molregno", "active_molregno",
    "Rescued Formula", "Rescued SMILES", "Rescued Name", "Rescued MW", "Duplicate? (1/0)"
])
for col in df_chembl.columns:
    print('\nColumn:', df_chembl[col].value_counts(dropna=False).head(10))  # Show top 10 frequent values
df_chembl.to_csv("data/df_chembl.csv", index=False)
# Out:
# Rescued CHEMBL3138733: Formula=H34Cl6N14O2Ru3, SMILES=nan, Name=nan, MW=778.3
#
# Rescued CHEMBL5086057: Formula=C95H131Cu2IN20O27S2, SMILES=nan, Name=nan, MW=2303.72
#
# Rescued CHEMBL5087277: Formula=C97H127Cu2IN20O27S2, SMILES=nan, Name=nan, MW=2323.71
#
# Rescued CHEMBL5089315: Formula=C97H128Cu2IN21O26S2, SMILES=nan, Name=nan, MW=2322.73
#
# Rescued CHEMBL5087925: Formula=C98H131Cu2N21O26S2, SMILES=nan, Name=nan, MW=2210.86
#
# Rescued CHEMBL5092357: Formula=C31H46Cu2IN5O10, SMILES=nan, Name=nan, MW=903.11
#
# Rescued CHEMBL5196854: Formula=C21H14FN5O2V, SMILES=nan, Name=nan, MW=438.32
#
# Dropped 1133 rows where Molecule type was None and unrecoverable.
#
# Column: pChEMBL
# 4.40    62584
# 4.50    51941
# 4.60    50838
# 4.45    41085
# 4.90    40761
# 4.80    37455
# 5.00    36904
# 4.55    35420
# 4.70    30729
# 4.85    26525
# Name: count, dtype: int64
#
# Column: Data validity comment
# None                  2004390
# Manually validated        320
# Name: count, dtype: int64
#
# Column: Assay ChEMBL ID
# CHEMBL1614458    75995
# CHEMBL1614421    49850
# CHEMBL1613914    39801
# CHEMBL1614544    36428
# CHEMBL1613842    33723
# CHEMBL1614038    24243
# CHEMBL1614502    24116
# CHEMBL1614079    23071
# CHEMBL1613838    21999
# CHEMBL1614250    20661
# Name: count, dtype: int64
#
# Column: confidence_score
# 9    1556454
# 8     448256
# Name: count, dtype: int64
#
# Column: MOA
# None                                                       1905092
# Tyrosine-protein kinase receptor FLT3 inhibitor               4985
# Stem cell growth factor receptor inhibitor                    3108
# Vascular endothelial growth factor receptor inhibitor         2816
# Platelet-derived growth factor receptor inhibitor             2601
# Serotonin 2a (5-HT2a) receptor antagonist                     2378
# Tyrosine-protein kinase receptor RET inhibitor                2371
# Vascular endothelial growth factor receptor 2 inhibitor       1674
# Epidermal growth factor receptor erbB1 inhibitor              1597
# Tyrosine-protein kinase JAK2 inhibitor                        1508
# Name: count, dtype: int64
#
# Column: Direct interaction (1/0)?
# NaN    1905092
# 1.0      99618
# Name: count, dtype: int64
#
# Column: Disease efficacy (1/0)?
# NaN    1905092
# 1.0      99618
# Name: count, dtype: int64
#
# Column: Molecule ChEMBL ID
# CHEMBL535        6417
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2338
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1638
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Preferred name
# NaN              1832883
# SUNITINIB           6417
# LESTAURTINIB        3180
# VORINOSTAT          2948
# VANDETANIB          2338
# FORETINIB           2124
# DOVITINIB           1970
# STAUROSPORINE       1780
# ALVOCIDIB           1638
# BOSUTINIB           1600
# Name: count, dtype: int64
#
# Column: Molecule type
# Small molecule     1765023
# TBD                 224221
# Protein              15418
# Oligosaccharide         43
# Oligonucleotide          5
# Name: count, dtype: int64
#
# Column: Max phase
#  NaN    1868069
#  4.0      79322
#  2.0      26563
#  3.0      18653
#  1.0       9404
# -1.0       2580
#  0.5        119
# Name: count, dtype: int64
#
# Column: Availability (2/1/0/-1/-2)?
# -1.0    1846244
#  NaN      85853
#  1.0      62980
# -2.0       3675
#  0.0       3562
#  2.0       2396
# Name: count, dtype: int64
#
# Column: Therapeutic (1/0)?
# 0    1927065
# 1      77645
# Name: count, dtype: int64
#
# Column: First-in-class (1/0/-1)?
# -1    1868069
#  0     129749
#  1       6892
# Name: count, dtype: int64
#
# Column: Chemical probe (1/0)?
# 0    1992763
# 1      11947
# Name: count, dtype: int64
#
# Column: Orphan (1/0/-1)?
# -1    1868069
#  0     132102
#  1       4539
# Name: count, dtype: int64
#
# Column: Canonical SMILES
# CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C                                        6417
# C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)CNC4=O                             3180
# O=C(CCCCCCC(=O)Nc1ccccc1)NO                                                                    2948
# COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1                                            2338
# COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1                       2124
# CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1                                        1970
# CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4                 1780
# CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@H](O)C1                                    1638
# COc1cc(Nc2c(C#N)cnc3cc(OCCCN4CCN(C)CC4)c(OC)cc23)c(Cl)cc1Cl                                    1600
# CO[C@@H]1[C@H](N(C)C(=O)c2ccccc2)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4    1575
# Name: count, dtype: int64
#
# Column: Molecular weight of full compound
# 398.48    6752
# 439.47    3451
# 264.32    3157
# 475.36    2396
# 392.44    2392
# 466.54    2386
# 632.66    2141
# 332.41    2122
# 401.85    1876
# 222.25    1678
# Name: count, dtype: int64
#
# Column: Molecular formula of full compound
# C22H27FN4O2      6531
# C26H21N3O4       3243
# C14H20N2O3       3018
# C22H24BrFN4O2    2357
# C34H34F2N4O6     2124
# C21H21FN6O       2054
# C28H26N4O3       2053
# C20H20N4O        1745
# C21H20ClNO5      1733
# C21H22Cl2FN5O    1615
# Name: count, dtype: int64
#
# Column: Parent compound ChEMBL ID
# CHEMBL535        6425
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2345
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1638
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Active ingredient ChEMBL ID
# CHEMBL535        6425
# CHEMBL603469     3180
# CHEMBL98         2948
# CHEMBL24828      2345
# CHEMBL1230609    2124
# CHEMBL522892     1970
# CHEMBL388978     1780
# CHEMBL428690     1639
# CHEMBL288441     1600
# CHEMBL608533     1575
# Name: count, dtype: int64
#
# Column: Target ChEMBL ID
# CHEMBL1293224    95175
# CHEMBL3577       76458
# CHEMBL1293226    40109
# CHEMBL1293235    36842
# CHEMBL2608       35160
# CHEMBL1293232    33822
# CHEMBL1963       28934
# CHEMBL340        28773
# CHEMBL4096       26254
# CHEMBL1293255    24686
# Name: count, dtype: int64
#
# Column: Active ingredient of prodrug?
# No     1951764
# Yes      52946
# Name: count, dtype: int64
#
# Column: Relationship
# Parent compound      1927778
# Salt form              74481
# Prodrug                 2263
# Prodrug salt form        188
# Name: count, dtype: int64

# %%
df_chembl = pd.read_csv("data/df_chembl.csv")
unique_chembl_ids = (
    df_chembl[df_chembl["Molecule type"] == "TBD"]["Molecule ChEMBL ID"]
    .dropna()
    .drop_duplicates()
    .tolist()
)

cache_path = "data/pubchem_peptide_inference_cache.csv"
if os.path.exists(cache_path):
    df_cache = pd.read_csv(cache_path)
    df_cache = df_cache.drop_duplicates("Molecule ChEMBL ID")
    cached_ids = set(df_cache["Molecule ChEMBL ID"])
else:
    df_cache = pd.DataFrame(columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
    cached_ids = set()

uncached_ids = [chembl_id for chembl_id in unique_chembl_ids if chembl_id not in cached_ids]
print(f"Total molecules to check: {len(uncached_ids)}")

# Function: Fetch CID by ChEMBL ID using PUG-REST name endpoint
def fetch_pubchem_cid_from_chembl(chembl_id):
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{chembl_id}/cids/JSON"
    try:
        r = requests.get(url, timeout=10)
        r.raise_for_status()
        return r.json()["IdentifierList"]["CID"][0]
    except Exception as e:
        print(f"CID fetch failed for ChEMBL ID {chembl_id} — {e}")
        return None

# Function: Check for "PEPTIDE" in HELM or record
def check_peptide_by_pubchem(cid):
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/{cid}/JSON"
    try:
        r = requests.get(url, timeout=10)
        r.raise_for_status()
        data = r.json()
        def deep_search(obj):
            if isinstance(obj, dict):
                for v in obj.values():
                    if deep_search(v):
                        return True
            elif isinstance(obj, list):
                for item in obj:
                    if deep_search(item):
                        return True
            elif isinstance(obj, str):
                if re.search(r'\bPEPTIDE\b', obj, re.IGNORECASE):
                    return True
            return False
        return deep_search(data.get("Record", {}).get("Section", []))
    except Exception as e:
        print(f"Peptide check failed for CID {cid} — {e}")
        return False

# Process uncached ChEMBL IDs
batch_size = 25
total_batches = (len(uncached_ids) + batch_size - 1) // batch_size
new_results = []
print(f"Total molecules to check: {len(uncached_ids)}")

for i in range(0, len(uncached_ids), batch_size):
    batch_number = i // batch_size + 1
    batch = uncached_ids[i:i + batch_size]
    print(f"Processing batch {batch_number} out of {total_batches} ({len(batch)} molecules)")
    for chembl_id in batch:
        cid = fetch_pubchem_cid_from_chembl(chembl_id)
        is_peptide = check_peptide_by_pubchem(cid) if cid else False
        timestamp = datetime.utcnow().isoformat()
        new_results.append((chembl_id, cid, is_peptide, timestamp))
        time.sleep(0.3)
    # Append to cache
    df_new = pd.DataFrame(new_results, columns=["Molecule ChEMBL ID", "PubChem CID", "Is Peptide", "Last Updated"])
    df_cache = pd.concat([df_cache, df_new], ignore_index=True).drop_duplicates("Molecule ChEMBL ID")
    df_cache.to_csv(cache_path, index=False)
    print(f"Added {len(df_new)} entries to cache.")
    new_results = []
print("PubChem peptide inference complete.")
# Out:
# /var/folders/y0/rzqb79d51rl7nd2k33qy2tww0000gn/T/ipykernel_9326/3652076326.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_chembl = pd.read_csv("data/df_chembl.csv")
# Total molecules to check: 119598
# Total molecules to check: 119598
# Processing batch 1 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 2 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 3 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL3559672 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3559672/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL5314343 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL5314343/cids/JSON
# Added 25 entries to cache.
# Processing batch 4 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 5 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2310886 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2310886/cids/JSON
# Added 25 entries to cache.
# Processing batch 6 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 7 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2304022 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2304022/cids/JSON
# Added 25 entries to cache.
# Processing batch 8 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL3138733 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3138733/cids/JSON
# Added 25 entries to cache.
# Processing batch 9 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 10 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL4630684 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4630684/cids/JSON
# Added 25 entries to cache.
# Processing batch 11 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL5483015 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL5483015/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL1201469 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL1201469/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL1909054 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL1909054/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL1909064 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL1909064/cids/JSON
# Added 25 entries to cache.
# Processing batch 12 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2012525 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012525/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012526 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012526/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012527 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012527/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012528 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012528/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012529 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012529/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012530 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012530/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012531 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012531/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012532 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012532/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012651 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012651/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012652 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012652/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012524 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012524/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012523 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012523/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2012653 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2012653/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2023841 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2023841/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2070373 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2070373/cids/JSON
# Added 25 entries to cache.
# Processing batch 13 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2070374 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2070374/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2070254 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2070254/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2259736 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2259736/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2314835 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2314835/cids/JSON
# Added 25 entries to cache.
# Processing batch 14 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2324207 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2324207/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2324952 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2324952/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2333163 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2333163/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2333164 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2333164/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2331673 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2331673/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2331674 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2331674/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2337012 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2337012/cids/JSON
# Added 25 entries to cache.
# Processing batch 15 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2337011 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2337011/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2337010 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2337010/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2337009 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2337009/cids/JSON
# Added 25 entries to cache.
# Processing batch 16 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2381409 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2381409/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2398169 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2398169/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2397077 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2397077/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2397076 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2397076/cids/JSON
# Added 25 entries to cache.
# Processing batch 17 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2397073 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2397073/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2419341 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2419341/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2430897 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2430897/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2430898 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2430898/cids/JSON
# Added 25 entries to cache.
# Processing batch 18 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2430899 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2430899/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2430900 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2430900/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2431721 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2431721/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2431718 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2431718/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2431720 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2431720/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2431719 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2431719/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440182 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440182/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440183 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440183/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440192 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440192/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440196 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440196/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440195 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440195/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440187 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440187/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440197 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440197/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440190 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440190/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440188 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440188/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440911 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440911/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440917 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440917/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440912 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440912/cids/JSON
# Added 25 entries to cache.
# Processing batch 19 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL2440898 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440898/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440927 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440927/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440928 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440928/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440915 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440915/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440925 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440925/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440926 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440926/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440914 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440914/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440899 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440899/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440913 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440913/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL2440916 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2440916/cids/JSON
# Added 25 entries to cache.
# Processing batch 20 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL3087927 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3087927/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3086851 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3086851/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3086852 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3086852/cids/JSON
# Added 25 entries to cache.
# Processing batch 21 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL3099721 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3099721/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3099722 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3099722/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3099723 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3099723/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3099727 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3099727/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3099726 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3099726/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3099725 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3099725/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3104112 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3104112/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3104111 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3104111/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3105020 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3105020/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3105019 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3105019/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3102931 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3102931/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL3102930 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL3102930/cids/JSON
# Added 25 entries to cache.
# Processing batch 22 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 23 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 24 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 25 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 26 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 27 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 28 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 29 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 30 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 31 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 32 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 33 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 34 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 35 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 36 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 37 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 38 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 39 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 40 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 41 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 42 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 43 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 44 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 45 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 46 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 47 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 48 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 49 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 50 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 51 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 52 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 53 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 54 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 55 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 56 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 57 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 58 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 59 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 60 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 61 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 62 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 63 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 64 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 65 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 66 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 67 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 68 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 69 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 70 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 71 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 72 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 73 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 74 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 75 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 76 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 77 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 78 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 79 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 80 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 81 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 82 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 83 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 84 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 85 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 86 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 87 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 88 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 89 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 90 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 91 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 92 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 93 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 94 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 95 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 96 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 97 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 98 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 99 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 100 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL4451940 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4451940/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4455202 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4455202/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4471448 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4471448/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4520619 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4520619/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4457980 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4457980/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4443125 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4443125/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4525614 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4525614/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4440617 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4440617/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4447241 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4447241/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4563026 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4563026/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4442043 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4442043/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4460717 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4460717/cids/JSON
# CID fetch failed for ChEMBL ID CHEMBL4516770 — 404 Client Error: PUGREST.NotFound for url: https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL4516770/cids/JSON
# Added 25 entries to cache.
# Processing batch 101 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 102 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 103 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 104 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 105 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 106 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 107 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 108 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 109 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 110 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 111 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 112 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 113 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 114 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 115 out of 4784 (25 molecules)
# Peptide check failed for CID 155516795 — HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Read timed out. (read timeout=10)
# Added 25 entries to cache.
# Processing batch 116 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 117 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 118 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 119 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 120 out of 4784 (25 molecules)
# CID fetch failed for ChEMBL ID CHEMBL4445725 — HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Read timed out. (read timeout=10)
# Added 25 entries to cache.
# Processing batch 121 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 122 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 123 out of 4784 (25 molecules)
# Peptide check failed for CID 155547422 — HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Read timed out. (read timeout=10)
# Added 25 entries to cache.
# Processing batch 124 out of 4784 (25 molecules)
# Peptide check failed for CID 155522174 — HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Read timed out. (read timeout=10)
# Added 25 entries to cache.
# Processing batch 125 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 126 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 127 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 128 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 129 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 130 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 131 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 132 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 133 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 134 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 135 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 136 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 137 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 138 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 139 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 140 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 141 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 142 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 143 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 144 out of 4784 (25 molecules)
# Peptide check failed for CID 155541524 — HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Read timed out. (read timeout=10)
# Added 25 entries to cache.
# Processing batch 145 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 146 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 147 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 148 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 149 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 150 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 151 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 152 out of 4784 (25 molecules)
# Peptide check failed for CID 155558720 — ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Added 25 entries to cache.
# Processing batch 153 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 154 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 155 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 156 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 157 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 158 out of 4784 (25 molecules)
# Peptide check failed for CID 155545992 — HTTPSConnectionPool(host='pubchem.ncbi.nlm.nih.gov', port=443): Read timed out.
# Added 25 entries to cache.
# Processing batch 159 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 160 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 161 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 162 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 163 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 164 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 165 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 166 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 167 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 168 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 169 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 170 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 171 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 172 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 173 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 174 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 175 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 176 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 177 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 178 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 179 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 180 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 181 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 182 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 183 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 184 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 185 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 186 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 187 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 188 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 189 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 190 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 191 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 192 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 193 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 194 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 195 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 196 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 197 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 198 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 199 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 200 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 201 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 202 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 203 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 204 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 205 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 206 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 207 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 208 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 209 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 210 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 211 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 212 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 213 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 214 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 215 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 216 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 217 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 218 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 219 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 220 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 221 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 222 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 223 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 224 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 225 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 226 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 227 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 228 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 229 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 230 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 231 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 232 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 233 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 234 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 235 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 236 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 237 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 238 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 239 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 240 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 241 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 242 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 243 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 244 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 245 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 246 out of 4784 (25 molecules)
# Added 25 entries to cache.
# Processing batch 247 out of 4784 (25 molecules)

# %%
tbd_ids = (df_chembl[df_chembl["Molecule type"] == "TBD"]["Molecule ChEMBL ID"].dropna().drop_duplicates().tolist())
quoted_ids = ", ".join(f"'{chembl_id}'" for chembl_id in tbd_ids)
sql_query = f"""
SELECT
    md.chembl_id AS "Molecule ChEMBL ID",
    cp.psa AS "PSA",
    cp.num_ro5_violations AS "NUM_RO5_VIOLATIONS",
    cp.cx_logp AS "CX_LOGP",
    cp.aromatic_rings AS "AROMATIC_RINGS",
    cp.heavy_atoms AS "HEAVY_ATOMS",
    cp.qed_weighted AS "QED_WEIGHTED",
    cp.np_likeness_score AS "NP_LIKENESS_SCORE"
FROM
    molecule_dictionary md
LEFT JOIN
    compound_properties cp ON md.molregno = cp.molregno
WHERE
    md.chembl_id IN ({quoted_ids})
ORDER BY
    md.chembl_id ASC
"""
df_props = chembl_downloader.query(sql_query)

tbd_df = (
    df_chembl[df_chembl["Molecule type"] == "TBD"]
    [["Molecule ChEMBL ID", "Molecular weight of full compound",
      "Molecular formula of full compound", "Preferred name", "Canonical SMILES"]]
    .dropna(subset=["Molecule ChEMBL ID"])
    .drop_duplicates(subset=["Molecule ChEMBL ID"])
    .sort_values(by="Molecule ChEMBL ID")
    .reset_index(drop=True)
)
tbd_df = tbd_df.merge(df_props, on="Molecule ChEMBL ID", how="left")
tbd_df.to_csv("tbd_molecules.csv", index=False)

# %%
df_pubchem_check

# %%
from sklearn.preprocessing import StandardScaler

# Define features of interest
descriptor_cols = [
    "Molecular weight of full compound",
    "PSA",
    "NUM_RO5_VIOLATIONS",
    "CX_LOGP",
    "AROMATIC_RINGS",
    "HEAVY_ATOMS",
    "QED_WEIGHTED",
    "NP_LIKENESS_SCORE"
]

# Prepare feature matrix
df = tbd_df.dropna(subset=descriptor_cols).copy()
X = df[descriptor_cols]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
import umap
from sklearn.manifold import TSNE

# PCA
pca = PCA(n_components=3)
df[["PC1", "PC2", "PC3"]] = pca.fit_transform(X_scaled)

# UMAP
reducer = umap.UMAP(n_components=3, random_state=42)
df[["UMAP1", "UMAP2", "UMAP3"]] = reducer.fit_transform(X_scaled)

# t-SNE
tsne = TSNE(n_components=3, random_state=42, perplexity=30, n_iter=500)
df[["TSNE1", "TSNE2", "TSNE3"]] = tsne.fit_transform(X_scaled)

from sklearn.cluster import DBSCAN, KMeans

# DBSCAN on UMAP
dbscan = DBSCAN(eps=1.2, min_samples=4)
df["DBSCAN_cluster"] = dbscan.fit_predict(df[["UMAP1", "UMAP2", "UMAP3"]])

# KMeans on PCA
kmeans = KMeans(n_clusters=4, random_state=42)
df["KMeans_cluster"] = kmeans.fit_predict(df[["PC1", "PC2", "PC3"]])

from scipy.stats import zscore

# Compute z-scores
z_scores = pd.DataFrame(X_scaled, columns=descriptor_cols)
z_scores["outlier_score"] = z_scores.abs().max(axis=1)
df["is_outlier"] = z_scores["outlier_score"] > 3  # flag as outlier

# Correlation matrix
corr_matrix = df[descriptor_cols].corr(method="pearson")
# Now you can visualize or inspect `corr_matrix` manually

summary_stats = df.groupby("KMeans_cluster")[descriptor_cols].agg(["mean", "std", "min", "max"])
# summary_stats contains cluster-wise aggregated feature values

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Basic 2D UMAP plot colored by KMeans cluster
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df,
    x="UMAP1", y="UMAP2",
    hue="KMeans_cluster",
    palette="tab10"
)
plt.title("2D UMAP projection of TBD molecules")
plt.legend(title="KMeans Cluster")
plt.show()

# %%
import plotly.express as px

fig = px.scatter_3d(
    df,
    x="PC1", y="PC2", z="PC3",
    color=df["KMeans_cluster"].astype(str),  # Ensure it's categorical
    hover_data=[
        "Molecule ChEMBL ID",
        "Preferred name",
        "Canonical SMILES",
        "QED_WEIGHTED"
    ],
    title="Interactive 3D PCA Projection (KMeans clusters)"
)

fig.update_traces(marker=dict(size=4, opacity=0.8))
fig.update_layout(
    width=1000,
    height=800,
    margin=dict(l=0, r=0, b=0, t=40)
)
fig.show()

# %%
import plotly.express as px

fig = px.scatter_3d(
    df, x="UMAP1", y="UMAP2", z="UMAP3",
    color=df["KMeans_cluster"].astype(str),
    hover_data=["Molecule ChEMBL ID", "Preferred name"],
    title="Interactive 3D UMAP (color: KMeans cluster)"
)
fig.show()

# %%
# Select fewer features for pairplot clarity
subset = df[["QED_WEIGHTED", "CX_LOGP", "PSA", "AROMATIC_RINGS", "KMeans_cluster"]]
sns.pairplot(subset, hue="KMeans_cluster", palette="tab10")
plt.suptitle("Pairplot of selected features by cluster", y=1.02)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[descriptor_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
